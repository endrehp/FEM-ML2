# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import random
import math
import time

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils import np_utils
from keras.optimizers import SGD
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
#%matplotlib notebook

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

from numpy.linalg import inv
from numpy import linalg as LA
from scipy import linalg
import random

from matplotlib import animation, rc
from IPython.display import HTML
# Out:
# Using TensorFlow backend.

# %%
def prepare_training_data(df_F, df_D, d):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F.shift(d-i).values, df_D.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values, df_D.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = df_D.values
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def train_test_split(DF, Dy, d, x_scaler, y_scaler):

    dim = np.shape(Dy)

    n_nodes = dim[1]
    x = np.linspace(0,1, n_nodes)

    #Scaling
    DFscaled = x_scaler.transform(DF)
    Dyscaled = y_scaler.transform(Dy)

    X_train = DFscaled
    Y_train = Dyscaled

    #Train test split
    train_portion = 0.8
    n_timesteps = len(X_train[:,0])
    x_train = X_train[0:int(n_timesteps*train_portion),:]
    x_test = X_train[int(n_timesteps*(train_portion)):,:]
    y_train = Y_train[0:int(n_timesteps*train_portion),:]
    y_test = Y_train[int(n_timesteps*(train_portion)):,:]

    n_features = int(x_train.shape[1]/d)
    x_train = x_train.reshape((x_train.shape[0], d, n_features))
    x_test = x_test.reshape((x_test.shape[0], d, n_features))

    return x_train, x_test, y_train, y_test, n_nodes, n_features, x

# %%
def initialize_model(n_units, x_train, y_train):
    model = Sequential()
    model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]),))
    model.add(Dense(len(y_train[0,:])))
    adam = Adam(lr=0.001)
    model.compile(loss='mae', optimizer=adam)
    
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=5, verbose=1, mode='auto')
    callback_list = [earlystop]
    return model, callback_list

# %%
def get_error(predictions, y_test):
    error = 0
    for i in range(len(predictions[:,0])):
        error += np.trapz((y_test[i,:] - predictions[i,:])**2, x)
    return error

# %%
def independent_predictions(x_test):

    input_i = np.copy(x_test[0,:,:])
    input_i_reshaped = input_i.reshape((1,d,n_features))

    #input_dim = x_test[0,:,:].shape

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_nodes])

    force = np.copy(x_test[:,:,:(n_nodes)])
    #model.reset_states()
    for i in range(future_timesteps): 
        pred = model.predict(input_i_reshaped)
        preds[i, :] = pred[0]

        input_i[0:d-1,:] = input_i[1:d,:]
        input_i[d-1,:n_nodes] = force[i+1,d-1,:]
        input_i[d-1,n_nodes:] = pred[0]

        input_i_reshaped = input_i.reshape((1,d,n_features))
        
    return preds

# %%
def get_scalers(DF, Dy):

    
    x_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    
    x_scaler.fit_transform(DF)
    y_scaler.fit_transform(Dy)
    
    return x_scaler, y_scaler

# %%
def get_batch_scalers(n_batches):
    
    #Simple version
    for i in range(n_batches):
        
        df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(i+1) + '.csv')
        df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(i+1) + '.csv')
        
        
        if i == 0:  
            x_range = df_D.values.max() - df_D.values.min()
            imax = i
        
        else:
            new_x_range = df_D.values.max() - df_D.values.min()
            
            if new_x_range > x_range:
                x_range = new_x_range
                imax = i
                
    df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(imax+1) + '.csv')
    df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(imax+1) + '.csv')
    
    DF, Dy = prepare_training_data(df_F, df_D, d)
    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    return x_scaler, y_scaler

# %%
######################### BATCH TRAINING ########################################

n_batches = 1
d = 5

t0 = time.time()

x_scaler, y_scaler = get_batch_scalers(n_batches)

for iteration in range(n_batches):

    df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(iteration+1) + '.csv')
    df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(iteration+1) + '.csv')

    DF, Dy = prepare_training_data(df_F, df_D, d)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    if iteration == 0:
        model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    model.fit(x_train, y_train, epochs=100, callbacks=None, batch_size=len(x_train), verbose=1, shuffle=False)
    
    training_time = time.time() - ts
    
    preds = y_scaler.inverse_transform(model.predict(x_test))
    y_test_u = y_scaler.inverse_transform(y_test)
    
    independent_preds = y_scaler.inverse_transform(independent_predictions(x_test))
    
    test_error = get_error(y_test_u, preds)
    independent_test_error = get_error(y_test_u[0:len(independent_preds[:,0]),:], independent_preds)
    
    total_time = time.time() - t0
    
    info = {'Iteration number': iteration+1, 'Test Error': test_error, 'Ind test error': independent_test_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# Epoch 1/100
# 23996/23996 [==============================] - 4s 154us/step - loss: 0.4076
# Epoch 2/100
# 23996/23996 [==============================] - 3s 109us/step - loss: 0.3545
# Epoch 3/100
# 23996/23996 [==============================] - 3s 111us/step - loss: 0.3057
# Epoch 4/100
# 23996/23996 [==============================] - 2s 100us/step - loss: 0.2559
# Epoch 5/100
# 23996/23996 [==============================] - 3s 109us/step - loss: 0.2077
# Epoch 6/100
# 23996/23996 [==============================] - 3s 132us/step - loss: 0.1640
# Epoch 7/100
# 23996/23996 [==============================] - 3s 120us/step - loss: 0.1332
# Epoch 8/100
# 23996/23996 [==============================] - 3s 112us/step - loss: 0.1177
# Epoch 9/100
# 23996/23996 [==============================] - 3s 128us/step - loss: 0.1081
# Epoch 10/100
# 23996/23996 [==============================] - 3s 118us/step - loss: 0.0970
# Epoch 11/100
# 23996/23996 [==============================] - 2s 104us/step - loss: 0.0839
# Epoch 12/100
# 23996/23996 [==============================] - 2s 101us/step - loss: 0.0682
# Epoch 13/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0592
# Epoch 14/100
# 23996/23996 [==============================] - 2s 102us/step - loss: 0.0583
# Epoch 15/100
# 23996/23996 [==============================] - 3s 126us/step - loss: 0.0609
# Epoch 16/100
# 23996/23996 [==============================] - 3s 115us/step - loss: 0.0614
# Epoch 17/100
# 23996/23996 [==============================] - 3s 106us/step - loss: 0.0600
# Epoch 18/100
# 23996/23996 [==============================] - 3s 104us/step - loss: 0.0568
# Epoch 19/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0531
# Epoch 20/100
# 23996/23996 [==============================] - 3s 116us/step - loss: 0.0495
# Epoch 21/100
# 23996/23996 [==============================] - 3s 105us/step - loss: 0.0468
# Epoch 22/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0448
# Epoch 23/100
# 23996/23996 [==============================] - 2s 104us/step - loss: 0.0438
# Epoch 24/100
# 23996/23996 [==============================] - 3s 104us/step - loss: 0.0424
# Epoch 25/100
# 23996/23996 [==============================] - 3s 115us/step - loss: 0.0407
# Epoch 26/100
# 23996/23996 [==============================] - 3s 120us/step - loss: 0.0383
# Epoch 27/100
# 23996/23996 [==============================] - 3s 128us/step - loss: 0.0356
# Epoch 28/100
# 23996/23996 [==============================] - 2s 101us/step - loss: 0.0339
# Epoch 29/100
# 23996/23996 [==============================] - 3s 108us/step - loss: 0.0332
# Epoch 30/100
# 23996/23996 [==============================] - 3s 129us/step - loss: 0.0325
# Epoch 31/100
# 23996/23996 [==============================] - 3s 116us/step - loss: 0.0319
# Epoch 32/100
# 23996/23996 [==============================] - 3s 121us/step - loss: 0.0317
# Epoch 33/100
# 23996/23996 [==============================] - 2s 102us/step - loss: 0.0317
# Epoch 34/100
# 23996/23996 [==============================] - 3s 108us/step - loss: 0.0313
# Epoch 35/100
# 23996/23996 [==============================] - 3s 122us/step - loss: 0.0301
# Epoch 36/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0280
# Epoch 37/100
# 23996/23996 [==============================] - 3s 112us/step - loss: 0.0256
# Epoch 38/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0239
# Epoch 39/100
# 23996/23996 [==============================] - 3s 134us/step - loss: 0.0241
# Epoch 40/100
# 23996/23996 [==============================] - 3s 110us/step - loss: 0.0248
# Epoch 41/100
# 23996/23996 [==============================] - 3s 111us/step - loss: 0.0254
# Epoch 42/100
# 23996/23996 [==============================] - 3s 123us/step - loss: 0.0248
# Epoch 43/100
# 23996/23996 [==============================] - 3s 134us/step - loss: 0.0230
# Epoch 44/100
# 23996/23996 [==============================] - 3s 114us/step - loss: 0.0217
# Epoch 45/100
# 23996/23996 [==============================] - 3s 105us/step - loss: 0.0212
# Epoch 46/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0211
# Epoch 47/100
# 23996/23996 [==============================] - 2s 104us/step - loss: 0.0209
# Epoch 48/100
# 23996/23996 [==============================] - 3s 107us/step - loss: 0.0200
# Epoch 49/100
# 23996/23996 [==============================] - 3s 106us/step - loss: 0.0192
# Epoch 50/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0191
# Epoch 51/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0189
# Epoch 52/100
# 23996/23996 [==============================] - 2s 102us/step - loss: 0.0183
# Epoch 53/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0177
# Epoch 54/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0174
# Epoch 55/100
# 23996/23996 [==============================] - 2s 104us/step - loss: 0.0171
# Epoch 56/100
# 23996/23996 [==============================] - 2s 104us/step - loss: 0.0165
# Epoch 57/100
# 23996/23996 [==============================] - 2s 104us/step - loss: 0.0159
# Epoch 58/100
# 23996/23996 [==============================] - 3s 108us/step - loss: 0.0158
# Epoch 59/100
# 23996/23996 [==============================] - 3s 124us/step - loss: 0.0157
# Epoch 60/100
# 23996/23996 [==============================] - 3s 109us/step - loss: 0.0153
# Epoch 61/100
# 23996/23996 [==============================] - 3s 125us/step - loss: 0.0148
# Epoch 62/100
# 23996/23996 [==============================] - 3s 135us/step - loss: 0.0145
# Epoch 63/100
# 23996/23996 [==============================] - 3s 117us/step - loss: 0.0141
# Epoch 64/100
# 23996/23996 [==============================] - 3s 130us/step - loss: 0.0138
# Epoch 65/100
# 23996/23996 [==============================] - 3s 133us/step - loss: 0.0136
# Epoch 66/100
# 23996/23996 [==============================] - 3s 115us/step - loss: 0.0134
# Epoch 67/100
# 23996/23996 [==============================] - 3s 104us/step - loss: 0.0130
# Epoch 68/100
# 23996/23996 [==============================] - 3s 107us/step - loss: 0.0129
# Epoch 69/100
# 23996/23996 [==============================] - 3s 108us/step - loss: 0.0127
# Epoch 70/100
# 23996/23996 [==============================] - 3s 108us/step - loss: 0.0124
# Epoch 71/100
# 23996/23996 [==============================] - 3s 109us/step - loss: 0.0121
# Epoch 72/100
# 23996/23996 [==============================] - 3s 106us/step - loss: 0.0120
# Epoch 73/100
# 23996/23996 [==============================] - 3s 106us/step - loss: 0.0119
# Epoch 74/100
# 23996/23996 [==============================] - 3s 105us/step - loss: 0.0117
# Epoch 75/100
# 23996/23996 [==============================] - 3s 105us/step - loss: 0.0115
# Epoch 76/100
# 23996/23996 [==============================] - 3s 107us/step - loss: 0.0114
# Epoch 77/100
# 23996/23996 [==============================] - 3s 109us/step - loss: 0.0112
# Epoch 78/100
# 23996/23996 [==============================] - 3s 107us/step - loss: 0.0111
# Epoch 79/100
# 23996/23996 [==============================] - 3s 104us/step - loss: 0.0110
# Epoch 80/100
# 23996/23996 [==============================] - 2s 104us/step - loss: 0.0109
# Epoch 81/100
# 23996/23996 [==============================] - 3s 105us/step - loss: 0.0107
# Epoch 82/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0106
# Epoch 83/100
# 23996/23996 [==============================] - 3s 124us/step - loss: 0.0105
# Epoch 84/100
# 23996/23996 [==============================] - 3s 127us/step - loss: 0.0104
# Epoch 85/100
# 23996/23996 [==============================] - 3s 110us/step - loss: 0.0103
# Epoch 86/100
# 23996/23996 [==============================] - 3s 115us/step - loss: 0.0102
# Epoch 87/100
# 23996/23996 [==============================] - 3s 123us/step - loss: 0.0101
# Epoch 88/100
# 23996/23996 [==============================] - 3s 106us/step - loss: 0.0100
# Epoch 89/100
# 23996/23996 [==============================] - 3s 112us/step - loss: 0.0100
# Epoch 90/100
# 23996/23996 [==============================] - 3s 118us/step - loss: 0.0099
# Epoch 91/100
# 23996/23996 [==============================] - 3s 110us/step - loss: 0.0098
# Epoch 92/100
# 23996/23996 [==============================] - 3s 105us/step - loss: 0.0098
# Epoch 93/100
# 23996/23996 [==============================] - 3s 107us/step - loss: 0.0097
# Epoch 94/100
# 23996/23996 [==============================] - 3s 106us/step - loss: 0.0096
# Epoch 95/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0096
# Epoch 96/100
# 23996/23996 [==============================] - 3s 107us/step - loss: 0.0095
# Epoch 97/100
# 23996/23996 [==============================] - 3s 110us/step - loss: 0.0095
# Epoch 98/100
# 23996/23996 [==============================] - 2s 103us/step - loss: 0.0094
# Epoch 99/100
# 23996/23996 [==============================] - 3s 116us/step - loss: 0.0094
# Epoch 100/100
# 23996/23996 [==============================] - 3s 105us/step - loss: 0.0093
# {'Iteration number': 1, 'Test Error': 0.0011008320357130494, 'Ind test error': 0.16397195370249576, 'Training time': 269.5731658935547, 'Total time': 276.2057247161865}

# %%
######################### BATCH TESTING ########################################

n_batches = 1
d = 5

t0 = time.time()
for iteration in range(n_batches):

    df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(iteration+1) + '.csv')
    df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(iteration+1) + '.csv')


    DF, Dy = prepare_training_data(df_F, df_D, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    #if i == 0:
    #    model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    preds = y_scaler.inverse_transform(model.predict(x_test))
    y_test_u = y_scaler.inverse_transform(y_test)
    
    independent_preds = independent_predictions(x_test)
    independent_preds_u = y_scaler.inverse_transform(independent_preds)
    
    plt.figure(figsize=(16,10))
    plt.plot(independent_preds_u[:,-1])
    plt.plot(preds[:,-1], 'x')
    plt.plot(y_test_u[:,-1])
    plt.show()
    
    test_error = get_error(y_test_u, preds)
    independent_test_error = get_error(y_test[0:len(independent_preds[:,0]),:], independent_preds)
    
    total_time = time.time() - t0
    
    info = {'Iteration number': iteration+1, 'Test Error': test_error, 'Ind test error': independent_test_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Test Error': 0.0011008320357130494, 'Ind test error': 81.205150765473931, 'Training time': 0.0, 'Total time': 5.77436900138855}

# %%
preds = y_scaler.inverse_transform(model.predict(x_train))
indenpendet_preds_u = y_scaler.inverse_transform(independent_predictions(x_train))

# %%
plt.figure(figsize=(16,10))
plt.plot(independent_preds_u[:,-1])
plt.plot(preds[:,-1], 'x')
y_train_u = y_scaler.inverse_transform(y_train)
plt.plot(y_train_u[:,-1])
plt.show()

# %%
#Export results
np.savetxt("predictions.csv", independent_preds_u, delimiter=",")
np.savetxt("preds.csv", preds, delimiter=",")
np.savetxt("y_test.csv", y_test_u, delimiter=",")
np.savetxt("y_train.csv", y_test_u, delimiter=",")

# %%
independent_preds_u.shape
# Out:
# (998, 21)

# %%
DF.shape
# Out:
# (4995, 205)

# %%
df_D.values.shape
# Out:
# (5000, 21)
