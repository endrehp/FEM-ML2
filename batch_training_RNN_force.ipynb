# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import random
import math
import time

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils import np_utils
from keras.optimizers import SGD
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
#%matplotlib notebook

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

from numpy.linalg import inv
from numpy import linalg as LA
from scipy import linalg
import random

from matplotlib import animation, rc
from IPython.display import HTML
# Out:
# Using TensorFlow backend.

# %%
def prepare_training_data(df_F, df_D, d):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = df_F.shift(d-i).values
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = df_D.values
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def train_test_split(DF, Dy, d, x_scaler, y_scaler):

    dim = np.shape(Dy)

    n_nodes = dim[1]
    x = np.linspace(0,1, n_nodes)

    #Scaling
    DFscaled = x_scaler.transform(DF)
    Dyscaled = y_scaler.transform(Dy)

    X_train = DFscaled
    Y_train = Dyscaled

    #Train test split
    train_portion = 0.8
    n_timesteps = len(X_train[:,0])
    x_train = X_train[0:int(n_timesteps*train_portion),:]
    x_test = X_train[int(n_timesteps*(train_portion)):,:]
    y_train = Y_train[0:int(n_timesteps*train_portion),:]
    y_test = Y_train[int(n_timesteps*(train_portion)):,:]

    n_features = int(x_train.shape[1]/d)
    x_train = x_train.reshape((x_train.shape[0], d, n_features))
    x_test = x_test.reshape((x_test.shape[0], d, n_features))

    return x_train, x_test, y_train, y_test, n_nodes, n_features, x

# %%
def initialize_model(n_units, x_train, y_train):
    model = Sequential()
    model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]),))
    model.add(Dense(len(y_train[0,:])))
    adam = Adam(lr=0.001)
    model.compile(loss='mae', optimizer=adam)
    
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=5, verbose=1, mode='auto')
    callback_list = [earlystop]
    return model, callback_list

# %%
def initialize_model_stateful(n_units, x_train, y_train):
    model = Sequential()
    model.add(LSTM(n_units, batch_input_shape=(1, x_train.shape[1], x_train.shape[2]), stateful=True))
    model.add(Dense(len(y_train[0,:])))
    adam = Adam(lr=0.001)
    model.compile(loss='mae', optimizer=adam)
    
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=5, verbose=1, mode='auto')
    callback_list = [earlystop]
    return model, callback_list

# %%
def get_error(predictions, y_test):
    error = 0
    for i in range(len(predictions[:,0])):
        error += np.trapz((y_test[i,:] - predictions[i,:])**2, x)
    return error

# %%
def independent_predictions(x_test):

    input_i = np.copy(x_test[0,:,:])
    input_i_reshaped = input_i.reshape((1,d,n_features))

    #input_dim = x_test[0,:,:].shape

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_nodes])

    force = np.copy(x_test[:,:,:(n_nodes)])
    #model.reset_states()
    for i in range(future_timesteps): 
        pred = model.predict(input_i_reshaped)
        preds[i, :] = pred[0]

        input_i[0:d-1,:] = input_i[1:d,:]
        input_i[d-1,:n_nodes] = force[i+1,d-1,:]
        input_i[d-1,n_nodes:] = pred[0]

        input_i_reshaped = input_i.reshape((1,d,n_features))
        
    return preds

# %%
def get_scalers(DF, Dy):

    
    x_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    
    x_scaler.fit_transform(DF)
    y_scaler.fit_transform(Dy)
    
    return x_scaler, y_scaler

# %%
def get_batch_scalers(n_batches):
    
    #Simple version
    for i in range(n_batches):
        
        df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(i+1) + '.csv')
        df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(i+1) + '.csv')
        
        
        if i == 0:  
            x_range = df_D.values.max() - df_D.values.min()
            imax = i
        
        else:
            new_x_range = df_D.values.max() - df_D.values.min()
            
            if new_x_range > x_range:
                x_range = new_x_range
                imax = i
                
    df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(imax+1) + '.csv')
    df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(imax+1) + '.csv')
    
    DF, Dy = prepare_training_data(df_F, df_D, d)
    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    return x_scaler, y_scaler

# %%
######################### BATCH TRAINING ########################################

n_batches = 1
d = 5

t0 = time.time()

x_scaler, y_scaler = get_batch_scalers(n_batches)

for i in range(n_batches):

    df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(i+1) + '.csv')
    df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(i+1) + '.csv')

    DF, Dy = prepare_training_data(df_F, df_D, d)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    if i == 0:
        model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    model.fit(x_train, y_train, epochs=100, callbacks=None, batch_size=len(x_train), verbose=1, shuffle=False)
    
    training_time = time.time() - ts
    
    preds = y_scaler.inverse_transform(model.predict(x_test))
    y_test_u = y_scaler.inverse_transform(y_test)
    
    test_error = get_error(y_test_u, preds)
    
    total_time = time.time() - t0
    
    info = {'Iteration number': i+1, 'Test Error': test_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# Epoch 1/100
# 3996/3996 [==============================] - 1s 232us/step - loss: 0.5340
# Epoch 2/100
# 3996/3996 [==============================] - 0s 87us/step - loss: 0.5080
# Epoch 3/100
# 3996/3996 [==============================] - 0s 85us/step - loss: 0.4758
# Epoch 4/100
# 3996/3996 [==============================] - 0s 89us/step - loss: 0.4472
# Epoch 5/100
# 3996/3996 [==============================] - 0s 86us/step - loss: 0.4225
# Epoch 6/100
# 3996/3996 [==============================] - 0s 89us/step - loss: 0.4016
# Epoch 7/100
# 3996/3996 [==============================] - 0s 87us/step - loss: 0.3841
# Epoch 8/100
# 3996/3996 [==============================] - 0s 85us/step - loss: 0.3698
# Epoch 9/100
# 3996/3996 [==============================] - 0s 87us/step - loss: 0.3584
# Epoch 10/100
# 3996/3996 [==============================] - 0s 86us/step - loss: 0.3496
# Epoch 11/100
# 3996/3996 [==============================] - 0s 103us/step - loss: 0.3429
# Epoch 12/100
# 3996/3996 [==============================] - 0s 102us/step - loss: 0.3381
# Epoch 13/100
# 3996/3996 [==============================] - 0s 117us/step - loss: 0.3345
# Epoch 14/100
# 3996/3996 [==============================] - 0s 89us/step - loss: 0.3318
# Epoch 15/100
# 3996/3996 [==============================] - 0s 83us/step - loss: 0.3298
# Epoch 16/100
# 3996/3996 [==============================] - 0s 86us/step - loss: 0.3282
# Epoch 17/100
# 3996/3996 [==============================] - 0s 83us/step - loss: 0.3268
# Epoch 18/100
# 3996/3996 [==============================] - 0s 86us/step - loss: 0.3256
# Epoch 19/100
# 3996/3996 [==============================] - 0s 89us/step - loss: 0.3244
# Epoch 20/100
# 3996/3996 [==============================] - 0s 87us/step - loss: 0.3233
# Epoch 21/100
# 3996/3996 [==============================] - 0s 91us/step - loss: 0.3222
# Epoch 22/100
# 3996/3996 [==============================] - 0s 82us/step - loss: 0.3211
# Epoch 23/100
# 3996/3996 [==============================] - 0s 88us/step - loss: 0.3199
# Epoch 24/100
# 3996/3996 [==============================] - 0s 87us/step - loss: 0.3187
# Epoch 25/100
# 3996/3996 [==============================] - 0s 86us/step - loss: 0.3174
# Epoch 26/100
# 3996/3996 [==============================] - 0s 90us/step - loss: 0.3161
# Epoch 27/100
# 3996/3996 [==============================] - 0s 86us/step - loss: 0.3147
# Epoch 28/100
# 3996/3996 [==============================] - 0s 91us/step - loss: 0.3134
# Epoch 29/100
# 3996/3996 [==============================] - 0s 89us/step - loss: 0.3120
# Epoch 30/100
# 3996/3996 [==============================] - 0s 88us/step - loss: 0.3107
# Epoch 31/100
# 3996/3996 [==============================] - 0s 88us/step - loss: 0.3094
# Epoch 32/100
# 3996/3996 [==============================] - 0s 85us/step - loss: 0.3081
# Epoch 33/100
# 3996/3996 [==============================] - 0s 86us/step - loss: 0.3069
# Epoch 34/100
# 3996/3996 [==============================] - 0s 88us/step - loss: 0
100
# 3996/3996 [==============================] - 0s 97us/step - loss: 0.2782
# Epoch 81/100
# 3996/3996 [==============================] - 0s 116us/step - loss: 0.2781
# Epoch 82/100
# 3996/3996 [==============================] - 0s 113us/step - loss: 0.2779
# Epoch 83/100
# 3996/3996 [==============================] - 0s 98us/step - loss: 0.2778
# Epoch 84/100
# 3996/3996 [==============================] - 0s 97us/step - loss: 0.2776
# Epoch 85/100
# 3996/3996 [==============================] - 0s 109us/step - loss: 0.2775
# Epoch 86/100
# 3996/3996 [==============================] - 0s 101us/step - loss: 0.2774
# Epoch 87/100
# 3996/3996 [==============================] - 0s 98us/step - loss: 0.2773
# Epoch 88/100
# 3996/3996 [==============================] - 0s 120us/step - loss: 0.2771
# Epoch 89/100
# 3996/3996 [==============================] - 0s 101us/step - loss: 0.2770
# Epoch 90/100
# 3996/3996 [==============================] - 0s 122us/step - loss: 0.2769
# Epoch 91/100
# 3996/3996 [==============================] - 0s 113us/step - loss: 0.2768
# Epoch 92/100
# 3996/3996 [==============================] - 0s 103us/step - loss: 0.2767
# Epoch 93/100
# 3996/3996 [==============================] - 0s 113us/step - loss: 0.2766
# Epoch 94/100
# 3996/3996 [==============================] - 0s 101us/step - loss: 0.2765
# Epoch 95/100
# 3996/3996 [==============================] - 0s 100us/step - loss: 0.2765
# Epoch 96/100
# 3996/3996 [==============================] - 0s 102us/step - loss: 0.2764
# Epoch 97/100
# 3996/3996 [==============================] - 0s 114us/step - loss: 0.2763
# Epoch 98/100
# 3996/3996 [==============================] - 0s 119us/step - loss: 0.2763
# Epoch 99/100
# 3996/3996 [==============================] - 0s 96us/step - loss: 0.2762
# Epoch 100/100
# 3996/3996 [==============================] - 0s 101us/step - loss: 0.2761
# {'Iteration number': 1, 'Test Error': 0.00033094376136755976, 'Training time': 39.60844421386719, 'Total time': 40.04290318489075}

# %%
######################### BATCH TESTING ########################################

n_batches = 1
d = 5

t0 = time.time()
for i in range(n_batches):

    df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(i+1) + '.csv')
    df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(i+1) + '.csv')


    DF, Dy = prepare_training_data(df_F, df_D, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    #if i == 0:
    #    model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    #new_model, new_callback_list = initialize_model_stateful(100, x_train, y_train)
    
    #new_model.set_weights(model.get_weights())
    
    #s_preds = new_model.predict(x_train, batch_size=1)
    #s_preds = new_model.predict(x_test, batch_size=1)
    
    #s_preds_u = y_scaler.inverse_transform(s_preds)
    
    
    preds_u = y_scaler.inverse_transform(model.predict(x_test))
    y_test_u = y_scaler.inverse_transform(y_test)
    
    
    plt.figure(figsize=(16,10))
    #plt.plot(s_preds_u[:,-1])
    plt.plot(preds_u[:,-1], 'x')
    plt.plot(y_test_u[:,-1])
    plt.show()
    
    test_error = get_error(y_test_u, preds)
    
    
    total_time = time.time() - t0
    
    info = {'Iteration number': i+1, 'Test Error': test_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Test Error': 0.00033094376136755976, 'Training time': 0.0, 'Total time': 0.30043649673461914}

# %%
preds = y_scaler.inverse_transform(model.predict(x_train))
#indenpendet_preds_u = y_scaler.inverse_transform(independent_predictions(x_train))

# %%
plt.figure(figsize=(16,10))
#plt.plot(independent_preds_u[:,-1])
plt.plot(preds[:,-1], 'x')
y_train_u = y_scaler.inverse_transform(y_train)
plt.plot(y_train_u[:,-1])
plt.show()

# %%
#Export results
np.savetxt("predictions.csv", independent_preds_u, delimiter=",")
np.savetxt("preds.csv", preds, delimiter=",")
np.savetxt("y_test.csv", y_test_u, delimiter=",")
np.savetxt("y_train.csv", y_test_u, delimiter=",")

# %%
independent_preds_u.shape
# Out:
# (998, 21)

# %%
DF.shape
# Out:
# (4995, 205)

# %%
df_D.values.shape
# Out:
# (5000, 21)
