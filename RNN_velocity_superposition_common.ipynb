# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import random
import math
import time

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.utils import np_utils
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping, History, Callback, ReduceLROnPlateau, ModelCheckpoint

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# %%
def prepare_training_data(df_F, df_D, df_Dt, d):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = np.concatenate((df_D.values, df_Dt.values), axis=1)
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def prepare_training_data_node_specific(df_F, df_D, df_Dt, d, node):
    
    DF = []
    
    node_col = df_F.values[:,node]
    df_F_n = pd.DataFrame(np.zeros(df_F.values.shape))
    df_F_n.values[:, node] = node_col
    
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F_n.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F_n.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = np.concatenate((df_D.values, df_Dt.values), axis=1)
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def train_test_split(DF, Dy, d, x_scaler, y_scaler):

    dim = np.shape(Dy)

    n_nodes = int(dim[1]/2)
    n_y = dim[1]
    x = np.linspace(0,1, n_nodes)

    #Scaling
    DFscaled = x_scaler.transform(DF)
    Dyscaled = y_scaler.transform(Dy)

    X_train = DFscaled
    Y_train = Dyscaled

    #Train test split
    train_portion = 0.8
    n_timesteps = len(X_train[:,0])
    x_train = X_train[0:int(n_timesteps*train_portion),:]
    x_test = X_train[int(n_timesteps*(train_portion)):,:]
    y_train = Y_train[0:int(n_timesteps*train_portion),:]
    y_test = Y_train[int(n_timesteps*(train_portion)):,:]

    n_features = int(x_train.shape[1]/d)
    
    #Reshape training data into 3D array as required by the LSTM layer
    #Input shape is: (n_timesteps, d, n_features)
    x_train = x_train.reshape((x_train.shape[0], d, n_features))
    x_test = x_test.reshape((x_test.shape[0], d, n_features))

    return x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x

# %%
def initialize_model(n_units, x_train, y_train, lr, n_layers):
    model = Sequential()
    
    #Add hidden layers, return_sequences=True if next layer is LSTM, False otherwise
    if n_layers == 1:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=False))
        
    elif n_layers == 2:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        model.add(LSTM(n_units))
    else: 
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        for layer in range(n_layers-1):
            model.add(LSTM(n_units, return_sequences = True))
        model.add(LSTM(n_units))
    
    
    #model.add(Dropout(0.1))
    
    model.add(Dense(len(y_train[0,:]))) #Output Layer
    adam = Adam(lr=lr)
    model.compile(loss='mae', optimizer=adam)
    
    #Define callbacks
    history = History()
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
    callback_list = [earlystop, history]
    return model, callback_list

# %%
def get_error(predictions, y_test):
    #Squared error is integrated numerically in space for each timestep and summed
    error = 0
    for i in range(len(predictions[:,0])):
        error += np.trapz((y_test[i,:] - predictions[i,:])**2, x)
    return error

# %%
def independent_predictions(x_test, my_model):

    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known
    for i in range(future_timesteps): 
        pred = my_model.predict(input_i_reshaped) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        input_i[d-1,:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
        input_i[d-1,n_nodes:] = pred[0] #Fill in values that we just predicted

        input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
        
    return preds

# %%
def independent_batch(x_batch):

    input_i = np.copy(x_batch[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_batch[:,0,0])

    force = np.copy(x_batch[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known
    
    ind_batch = np.zeros([future_timesteps, d, n_features])
    ind_batch[0] = input_i_reshaped[0]
    
    for i in range(future_timesteps): 
        pred = model.predict(input_i_reshaped) #Predict next timestep
        
        if i < future_timesteps - 1:
            input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
            input_i[d-1,:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
            input_i[d-1,n_nodes:] = pred[0] #Fill in values that we just predicted

            input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
            ind_batch[i+1] = input_i_reshaped[0]
        
    return ind_batch

# %%
def get_scalers(DF, Dy):
    
    x_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    
    x_scaler.fit_transform(DF)
    y_scaler.fit_transform(Dy)
    
    return x_scaler, y_scaler

# %%
def get_batch_scalers(n_batches, training_set):
    
    #Simple version
    for i in range(n_batches):
        
        df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(i+1) + '.csv')
        df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(i+1) + '.csv')
        df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(i+1) + '.csv')
        
        if i == 0:  
            x_range = df_D.values.max() - df_D.values.min()
            imax = i
        
        else:
            new_x_range = df_D.values.max() - df_D.values.min()
            
            if new_x_range > x_range:
                x_range = new_x_range
                imax = i
                
    df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(imax+1) + '.csv')
    df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(imax+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(imax+1) + '.csv')
    
    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    return x_scaler, y_scaler

# %%
#columns = ['training set', 'n_layers', 'height', 'epochs', 'batch size', 'learning rate', 'early stopping', 'stop loss', 'Training Error', 'Test Error',
#           'Ind test error', 'Ind train error', 'Training time', 'Total time']
#df = pd.DataFrame(columns = columns)

#df.to_csv('../results/RNN_velocity_results.csv')

# %%
def get_batch(x_train, y_train, batch_size):
    
    start = random.randint(0,len(x_train)-batch_size)
    
    x_batch = x_train[start:start+batch_size]
    y_batch = y_train[start:start+batch_size]
    
    return x_batch, y_batch

# %%
random.randint(0,100)
# Out:
# 50

# %%
#Select training set
training_set = 'rr'
iteration = 0
d = 10

#Import training data
df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(iteration+1) + '.csv')
df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(iteration+1) + '.csv')
df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(iteration+1) + '.csv')

DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)

x_scaler, y_scaler = get_scalers(DF, Dy) #Get global scalers

# %%
######################### BATCH TRAINING ########################################

n_batches = 1
d = 10

#Hyperparameter settings
epochs = 100
layers = 1
height = 50
batch_size = 1000
lr = 0.001
u_errors_matrix = []
c_errors_matrix =[]

# %%
u_model = Sequential()
#model.add(LSTM(height, batch_input_shape=(None, d, n_features), return_sequences=True))
u_model.add(LSTM(height, input_shape=(d, n_features), return_sequences=False))
#model.add(Dropout(0.1))
u_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
u_model.compile(loss='mae', optimizer=adam)
#Define callbacks
ind_pred = Ind_pred()
u_ind_errors = []
history = History()
earlystop = EarlyStopping(monitor='loss', min_delta=0.001, patience=30, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=15, min_lr=0.0001, mode='min', verbose=1)
model_cp = ModelCheckpoint('../results/model_checkpoint.h5', monitor='ind_error', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)
#hist = u_model.fit(x_train, y_train, epochs=epochs, callbacks=[ind_pred, history, earlystop, reduce_lr, model_cp], batch_size=batch_size, 
#                   verbose=1, shuffle=False)
#earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
#callback_list = [earlystop, history]
#u_errors_matrix.append(u_ind_errors)

# %%
#node = 19
n_nodes = 5
training_sets = []
preds_during = [] 

training_set = 'indv_'
for node in range(n_nodes):
    
    df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(node+1) + '.csv')
    df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(node+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(node+1) + '.csv')
    #Prepare training data
    #DF, Dy = prepare_training_data_node_specific(df_F, df_D, df_Dt, d, node)
    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)

    #Split into train and test set
    x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    training_sets.append([x_train, x_test, y_train, y_test])

    hist = u_model.fit(x_train, y_train, epochs=epochs, callbacks=[history, earlystop, reduce_lr], batch_size=batch_size, 
                       verbose=1, shuffle=False)

    pred_ind_all = independent_predictions(x_test, u_model)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])
    info = {'node': node+1, 'ind_error': ind_error}
    print(info)
    preds_during.append(pred_ind)
# Out:
# Epoch 1/100
# 23992/23992 [==============================] - 3s 111us/step - loss: 0.2495
# Epoch 2/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0286
# Epoch 3/100
# 23992/23992 [==============================] - 1s 58us/step - loss: 0.0102
# Epoch 4/100
# 23992/23992 [==============================] - 1s 57us/step - loss: 0.0076
# Epoch 5/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0065
# Epoch 6/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0058
# Epoch 7/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0054
# Epoch 8/100
# 23992/23992 [==============================] - 1s 58us/step - loss: 0.0052
# Epoch 9/100
# 23992/23992 [==============================] - 1s 54us/step - loss: 0.0051
# Epoch 10/100
# 23992/23992 [==============================] - 1s 56us/step - loss: 0.0057
# Epoch 11/100
# 23992/23992 [==============================] - 1s 53us/step - loss: 0.0060
# Epoch 12/100
# 23992/23992 [==============================] - 1s 58us/step - loss: 0.0048
# Epoch 13/100
# 23992/23992 [==============================] - 1s 54us/step - loss: 0.0045
# Epoch 14/100
# 23992/23992 [==============================] - 1s 58us/step - loss: 0.0047
# Epoch 15/100
# 23992/23992 [==============================] - 1s 59us/step - loss: 0.0046
# Epoch 16/100
# 23992/23992 [==============================] - 2s 67us/step - loss: 0.0045
# Epoch 17/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0047
# Epoch 18/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0049
# Epoch 19/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0044
# Epoch 20/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0047
# Epoch 21/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0048
# Epoch 22/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0045
# Epoch 23/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0045
# Epoch 24/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0047
# Epoch 25/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0045
# Epoch 26/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0044
# Epoch 27/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0047
# Epoch 28/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0048: 0s - los
# Epoch 29/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0050
# Epoch 30/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0055
# Epoch 31/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0054
# Epoch 32/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0052
# Epoch 33/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0055
# Epoch 34/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0046
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 35/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0043
# Epoch 36/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0040
# Epoch 37/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0039
# Epoch 38/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0039
# Epoch 39/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0039
# Epoch 40/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0039
# Epoch 41/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0039
# Epoch 42/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0039
# Epoch 43/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0039
# Epoch 44/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0039
# Epoch 45/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0039
# Epoch 46/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0039
# Epoch 47/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0039
# Epoch 48/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0039
# Epoch 49/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0039
# Epoch 50/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0039
# Epoch 51/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0039
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 52/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0040
# Epoch 53/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0045: 0s - loss:
# Epoch 54/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0045
# Epoch 55/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0043:
# Epoch 56/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0044
# Epoch 57/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0043
# Epoch 58/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0043
# Epoch 59/100
# 23992/23992 [==============================] - 2s 67us/step - loss: 0.0043
# Epoch 60/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0043
# Epoch 61/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0042
# Epoch 62/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0042
# Epoch 63/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0042
# Epoch 64/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0042
# Epoch 65/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0042
# Epoch 00065: early stopping
# {'node': 1, 'ind_error': 0.14279102993223983}
# Epoch 1/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0112
# Epoch 2/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0110: 0s -
# Epoch 3/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0109
# Epoch 4/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0108: 0s - loss:
# Epoch 5/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0107: 0s - loss: 0.0 - ETA: 0s - los
# Epoch 6/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0106:
# Epoch 7/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0105
# Epoch 8/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0104
# Epoch 9/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0103
# Epoch 10/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0102
# Epoch 11/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0101
# Epoch 12/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0100
# Epoch 13/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0099: 0s - lo
# Epoch 14/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0098
# Epoch 15/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0098
# Epoch 16/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0097: 0s - loss: 0.
# Epoch 17/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0096
# Epoch 18/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0095
# Epoch 19/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0095
# Epoch 20/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0094
# Epoch 21/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0093
# Epoch 22/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0093
# Epoch 23/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0092
# Epoch 24/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0091:
# Epoch 25/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0091
# Epoch 26/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0090
# Epoch 27/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0090
# Epoch 28/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0089
# Epoch 29/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0089
# Epoch 30/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0088
# Epoch 31/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0088
# Epoch 32/100
# 23992/23992 [==============================] - 2s 68us/step - loss: 0.0087
# Epoch 33/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0087
# Epoch 34/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0087
# Epoch 35/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0086
# Epoch 36/100
# 23992/23992 [==============================] - 1s 59us/step - loss: 0.0086
# Epoch 37/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0085
# Epoch 38/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0085
# Epoch 39/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0084
# Epoch 40/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0084
# Epoch 41/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0084
# Epoch 42/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0083
# Epoch 43/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0083
# Epoch 44/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0082
# Epoch 45/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0082
# Epoch 46/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0081: 0s - los
# Epoch 47/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0081
# Epoch 48/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0081
# Epoch 49/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0080
# Epoch 50/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0080: 0s - loss: 0.00
# Epoch 51/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0079
# Epoch 52/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0079
# Epoch 53/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0079
# Epoch 54/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0078
# Epoch 55/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0078
# Epoch 56/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0077
# Epoch 57/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0077: 0s
# Epoch 58/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0076
# Epoch 59/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0076
# Epoch 60/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0076
# Epoch 61/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0075
# Epoch 62/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0075
# Epoch 63/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0074
# Epoch 64/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0074
# Epoch 65/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0073
# Epoch 66/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0073
# Epoch 67/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0072
# Epoch 68/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0072
# Epoch 69/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0071
# Epoch 70/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0071
# Epoch 71/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0070
# Epoch 72/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0070
# Epoch 73/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0070
# Epoch 74/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0069
# Epoch 75/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0069
# Epoch 76/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0068
# Epoch 77/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0068: 0s
# Epoch 78/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0067
# Epoch 79/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0067
# Epoch 80/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0066
# Epoch 81/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0066
# Epoch 82/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0065
# Epoch 83/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0065
# Epoch 84/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0065
# Epoch 85/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0064
# Epoch 86/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0064
# Epoch 87/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0064
# Epoch 88/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0063
# Epoch 89/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0063: 0s - loss: 0.0
# Epoch 90/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0062
# Epoch 91/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0062
# Epoch 92/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0062
# Epoch 93/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0061
# Epoch 94/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0061
# Epoch 95/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0061
# Epoch 96/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0061
# Epoch 97/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0060
# Epoch 98/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0060
# Epoch 99/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0060
# Epoch 100/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0060: 0
# {'node': 2, 'ind_error': 1.5198018505342825}
# Epoch 1/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0110
# Epoch 2/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0105
# Epoch 3/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0101
# Epoch 4/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0098
# Epoch 5/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0095
# Epoch 6/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0092
# Epoch 7/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0089
# Epoch 8/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0087
# Epoch 9/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0085
# Epoch 10/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0083
# Epoch 11/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0081
# Epoch 12/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0079
# Epoch 13/100
# 23992/23992 [==============================] - ETA: 0s - loss: 0.007 - 2s 63us/step - loss: 0.0078
# Epoch 14/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0076
# Epoch 15/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0075
# Epoch 16/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0073
# Epoch 17/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0072
# Epoch 18/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0071
# Epoch 19/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0069
# Epoch 20/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0068
# Epoch 21/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0067: 0s - lo
# Epoch 22/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0066
# Epoch 23/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0065
# Epoch 24/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0064
# Epoch 25/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0063
# Epoch 26/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0062
# Epoch 27/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0061
# Epoch 28/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0061
# Epoch 29/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0060
# Epoch 30/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0059
# Epoch 31/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0058
# Epoch 32/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0057:
# Epoch 33/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0056
# Epoch 34/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0056
# Epoch 35/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0055
# Epoch 36/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0054
# Epoch 37/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0053
# Epoch 38/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0052
# Epoch 39/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0051
# Epoch 40/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0051: 0s - l
# Epoch 41/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0050
# Epoch 42/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0049
# Epoch 43/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0048
# Epoch 44/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0047
# Epoch 45/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0046
# Epoch 46/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0046: 0s - los
# Epoch 47/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0045
# Epoch 48/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0044
# Epoch 49/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0043
# Epoch 50/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0042
# Epoch 51/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0042
# Epoch 52/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0041
# Epoch 53/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0040
# Epoch 54/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0040: 0s
# Epoch 55/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0039: 0s -
# Epoch 56/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0039
# Epoch 57/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0038
# Epoch 58/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0038
# Epoch 59/100
# 23992/23992 [==============================] - ETA: 0s - loss: 0.003 - 1s 62us/step - loss: 0.0037
# Epoch 60/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0037
# Epoch 61/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0037
# Epoch 62/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0037
# Epoch 63/100
# 23992/23992 [==============================] - 1s 59us/step - loss: 0.0037
# Epoch 64/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0036: 0s - lo
# Epoch 65/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0036
# Epoch 66/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0035
# Epoch 67/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0035
# Epoch 68/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0035
# Epoch 69/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0035
# Epoch 70/100
# 23992/23992 [==============================] - 1s 59us/step - loss: 0.0034
# Epoch 71/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0034
# Epoch 72/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0034
# Epoch 73/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0034
# Epoch 74/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0034
# Epoch 75/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0033
# Epoch 76/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0033
# Epoch 77/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0033
# Epoch 78/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0033
# Epoch 79/100
# 23992/23992 [==============================] - 1s 59us/step - loss: 0.0033: 0s -
# Epoch 80/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0032
# Epoch 81/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0032
# Epoch 82/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0032
# Epoch 83/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0032
# Epoch 84/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0032: 0s - loss: 0.0
# Epoch 85/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0032
# Epoch 86/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0032
# Epoch 87/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0032
# Epoch 88/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0032
# Epoch 89/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0032
# Epoch 90/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0032
# Epoch 91/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0031
# Epoch 92/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0031
# Epoch 93/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0031
# Epoch 94/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0031
# Epoch 95/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0031: 0s - loss: 0.
# Epoch 96/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0031
# Epoch 97/100
# 23992/23992 [==============================] - 1s 59us/step - loss: 0.0031
# Epoch 98/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0031
# Epoch 99/100
# 23992/23992 [==============================] - 1s 59us/step - loss: 0.0031: 0s - loss: 0
# Epoch 00099: early stopping
# {'node': 3, 'ind_error': 1.706056960692125}
# Epoch 1/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0092
# Epoch 2/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0085
# Epoch 3/100
# 23992/23992 [==============================] - 1s 59us/step - loss: 0.0079
# Epoch 4/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0074
# Epoch 5/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0069: 0s -
# Epoch 6/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0065
# Epoch 7/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0061
# Epoch 8/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0058
# Epoch 9/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0055
# Epoch 10/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0052
# Epoch 11/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0049
# Epoch 12/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0047
# Epoch 13/100
# 23992/23992 [==============================] - 2s 68us/step - loss: 0.0044
# Epoch 14/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0042: 0s - l
# Epoch 15/100
# 23992/23992 [==============================] - 2s 68us/step - loss: 0.0040
# Epoch 16/100
# 23992/23992 [==============================] - 2s 67us/step - loss: 0.0038
# Epoch 17/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0036
# Epoch 18/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0034
# Epoch 19/100
# 23992/23992 [==============================] - 2s 67us/step - loss: 0.0033
# Epoch 20/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0032
# Epoch 21/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0030
# Epoch 22/100
# 23992/23992 [==============================] - 2s 67us/step - loss: 0.0029
# Epoch 23/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0028
# Epoch 24/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0028:
# Epoch 25/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0027
# Epoch 26/100
# 23992/23992 [==============================] - 2s 69us/step - loss: 0.0026
# Epoch 27/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0026
# Epoch 28/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0025
# Epoch 29/100
# 23992/23992 [==============================] - 2s 67us/step - loss: 0.0025
# Epoch 30/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0024
# Epoch 31/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0024
# Epoch 32/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0023
# Epoch 33/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0023
# Epoch 34/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0023: 0s - loss: 0.00
# Epoch 35/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0022
# Epoch 36/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0023: 0s - loss
# Epoch 37/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0023
# Epoch 38/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0022
# Epoch 39/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0022
# Epoch 40/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0021
# Epoch 41/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0021:
# Epoch 42/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0021
# Epoch 43/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0021
# Epoch 44/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0021
# Epoch 45/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0021
# Epoch 46/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0020
# Epoch 47/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0020
# Epoch 48/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0020
# Epoch 49/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0020
# Epoch 50/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0020
# Epoch 51/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0020
# Epoch 52/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0019
# Epoch 53/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0019
# Epoch 54/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0019
# Epoch 55/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0019
# Epoch 56/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0019
# Epoch 57/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0019
# Epoch 58/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0019
# Epoch 59/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0019
# Epoch 60/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0019: 0s - loss
# Epoch 61/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0020: 0s - l - ETA: 0s - loss: 0.002
# Epoch 00061: early stopping
# {'node': 4, 'ind_error': 1.8969469834339887}
# Epoch 1/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0141
# Epoch 2/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0135
# Epoch 3/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0129
# Epoch 4/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0122
# Epoch 5/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0115
# Epoch 6/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0108
# Epoch 7/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0102
# Epoch 8/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0097:
# Epoch 9/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0092
# Epoch 10/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0088
# Epoch 11/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0084
# Epoch 12/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0081
# Epoch 13/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0078
# Epoch 14/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0075
# Epoch 15/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0072
# Epoch 16/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0070
# Epoch 17/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0067
# Epoch 18/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0065
# Epoch 19/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0064
# Epoch 20/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0062: 0
# Epoch 21/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0061
# Epoch 22/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0060
# Epoch 23/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0059
# Epoch 24/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0058
# Epoch 25/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0057
# Epoch 26/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0057: 0s - loss
# Epoch 27/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0056
# Epoch 28/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0055: 0s - loss:
# Epoch 29/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0055
# Epoch 30/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0054
# Epoch 31/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0053
# Epoch 32/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0053
# Epoch 33/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0052: 0s - los
# Epoch 34/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0052
# Epoch 35/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0051
# Epoch 36/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0051
# Epoch 37/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0050
# Epoch 38/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0050
# Epoch 39/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0050
# Epoch 40/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0049
# Epoch 41/100
# 23992/23992 [==============================] - 2s 66us/step - loss: 0.0049
# Epoch 42/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0049: 0s - loss
# Epoch 43/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0048
# Epoch 44/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0048
# Epoch 45/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0048
# Epoch 46/100
# 23992/23992 [==============================] - 2s 67us/step - loss: 0.0048
# Epoch 47/100
# 23992/23992 [==============================] - 2s 65us/step - loss: 0.0048
# Epoch 48/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0047
# Epoch 49/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0047
# Epoch 50/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0047: 1
# Epoch 51/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0047
# Epoch 52/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0047
# Epoch 53/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0046
# Epoch 54/100
# 23992/23992 [==============================] - 2s 63us/step - loss: 0.0046
# Epoch 55/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0046
# Epoch 56/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0046
# Epoch 57/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0046
# Epoch 58/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0046
# Epoch 59/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0045
# Epoch 60/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0045
# Epoch 61/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0045
# Epoch 62/100
# 23992/23992 [==============================] - 1s 59us/step - loss: 0.0045
# Epoch 63/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0045: 0
# Epoch 64/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0045
# Epoch 65/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0045: 0s - loss: 0.0
# Epoch 66/100
# 23992/23992 [==============================] - 2s 64us/step - loss: 0.0044
# Epoch 67/100
# 23992/23992 [==============================] - 1s 62us/step - loss: 0.0044: 0s - loss: 0.00
# Epoch 68/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0044
# Epoch 69/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0044
# Epoch 70/100
# 23992/23992 [==============================] - 1s 61us/step - loss: 0.0044
# Epoch 71/100
# 23992/23992 [==============================] - 1s 60us/step - loss: 0.0044
# Epoch 00071: early stopping
# {'node': 5, 'ind_error': 5.5166367497172777}

# %%
#Shuffle training sets

# %%
total_response_during = np.zeros(preds_during[0].shape)

for node in range(n_nodes):
    total_response_during += preds_during[node]

# %%
ind_responses = []
#training_set = ''
for node in range(n_nodes):
    
    x_test = training_sets[node][1]
    
    ind_responses.append(independent_predictions(x_test, u_model))

# %%
total_response = np.zeros([len(ind_responses[0][:,0]), n_nodes])

for node in range(n_nodes):
    total_response += ind_responses[node][:,0:n_nodes]

# %%
training_set = 'rr'
node = 0
df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(node+1) + '.csv')
df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(node+1) + '.csv')
df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(node+1) + '.csv')
#Prepare training data
#DF, Dy = prepare_training_data_node_specific(df_F, df_D, df_Dt, d, node)
DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)

#Split into train and test set
x_train, x_test, y_train, y_test_f, n_nodes, n_features, n_y, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
full_pred = independent_predictions(x_test, u_model)[:,0:n_nodes]
full_ind_error = get_error(full_pred, y_test[0:len(full_pred[:,0]),0:n_nodes])

# %%
print(full_ind_error)
# Out:
# 21.7006496248

# %%
#pred_ind = pred_ind_all[:, 0:n_nodes]
ind_error = get_error(total_response-2, y_test[0:len(total_response[:,0]),0:n_nodes])
print(ind_error)
# Out:
# 37.6537837357

# %%
#pred_ind = pred_ind_all[:, 0:n_nodes]
ind_error = get_error(total_response_during-2, y_test[0:len(total_response[:,0]),0:n_nodes])
print(ind_error)
# Out:
# 12.0809287777

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(total_response[:,n_nodes-1]-2)
#plt.plot(total_response_during[:,n_nodes-1]-2)
plt.plot(full_pred[:,n_nodes-1])
plt.plot(y_test_f[:, n_nodes-1])
plt.show()

# %%
class Ind_pred(Callback):
    
    def on_epoch_end(self, epoch, logs={}):

        input_i = np.copy(x_test[0,:,:]) #Initial conditions
        input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

        future_timesteps = len(x_test[:,0,0])-1
        preds = np.zeros([future_timesteps, n_y])

        force = np.copy(x_test[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known
        
        for i in range(future_timesteps): 
            pred = self.model.predict(input_i_reshaped) #Predict next timestep
            preds[i, :] = pred[0] 

            input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
            input_i[d-1,:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
            input_i[d-1,n_nodes:] = pred[0] #Fill in values that we just predicted

            input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

        
        error = 0
        for i in range(len(preds[:,0])):
            error += np.trapz((y_test[i,:n_nodes] - preds[i,:n_nodes])**2, x)
        
        info = {'ind error': error}
        u_ind_errors.append(error)
        
        logs['ind_error'] = error
            
        print(info)
    
    #def on_batch_end(self, batch, logs={}):
    #    print(batch)

# %%
u_model = Sequential()
#model.add(LSTM(height, batch_input_shape=(None, d, n_features), return_sequences=True))
u_model.add(LSTM(height, input_shape=(d, n_features), return_sequences=False))
#model.add(Dropout(0.1))
u_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
u_model.compile(loss='mae', optimizer=adam)
#Define callbacks
ind_pred = Ind_pred()
u_ind_errors = []
history = History()
earlystop = EarlyStopping(monitor='ind_error', min_delta=0.001, patience=10, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='ind_error', factor=0.2, patience=4, min_lr=0.0001, mode='min', verbose=1)
model_cp = ModelCheckpoint('../results/model_checkpoint.h5', monitor='ind_error', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)
hist = u_model.fit(x_train, y_train, epochs=epochs, callbacks=[ind_pred, history, earlystop, reduce_lr, model_cp], batch_size=batch_size, 
                   verbose=1, shuffle=False)
#earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
#callback_list = [earlystop, history]
u_errors_matrix.append(u_ind_errors)
# Out:
# Epoch 1/100
# 23992/23992 [==============================] - 10s 417us/step - loss: 0.1329
# {'ind error': 198.47272849866749}
#
# Epoch 00001: ind_error improved from inf to 198.47273, saving model to ../results/model_checkpoint.h5
# Epoch 2/100
# 23992/23992 [==============================] - 9s 394us/step - loss: 0.0451
# {'ind error': 302.78107024409707}
#
# Epoch 00002: ind_error did not improve from 198.47273
# Epoch 3/100
# 23992/23992 [==============================] - 11s 442us/step - loss: 0.0303
# {'ind error': 201.75329902984925}
#
# Epoch 00003: ind_error did not improve from 198.47273
# Epoch 4/100
# 23992/23992 [==============================] - 10s 399us/step - loss: 0.0268
# {'ind error': 127.79318699855902}
#
# Epoch 00004: ind_error improved from 198.47273 to 127.79319, saving model to ../results/model_checkpoint.h5
# Epoch 5/100
# 23992/23992 [==============================] - 9s 395us/step - loss: 0.0242
# {'ind error': 184.5814695385248}
#
# Epoch 00005: ind_error did not improve from 127.79319
# Epoch 6/100
# 23992/23992 [==============================] - 9s 394us/step - loss: 0.0242
# {'ind error': 76.772469416178666}
#
# Epoch 00006: ind_error improved from 127.79319 to 76.77247, saving model to ../results/model_checkpoint.h5
# Epoch 7/100
# 23992/23992 [==============================] - 10s 397us/step - loss: 0.0215
# {'ind error': 212.90160306673556}
#
# Epoch 00007: ind_error did not improve from 76.77247
# Epoch 8/100
# 23992/23992 [==============================] - 10s 410us/step - loss: 0.0198
# {'ind error': 122.08814691562543}
#
# Epoch 00008: ind_error did not improve from 76.77247
# Epoch 9/100
# 23992/23992 [==============================] - 9s 390us/step - loss: 0.0192
# {'ind error': 118.08709660578579}
#
# Epoch 00009: ind_error did not improve from 76.77247
# Epoch 10/100
# 23992/23992 [==============================] - 10s 406us/step - loss: 0.0194
# {'ind error': 96.984340834770805}
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 00010: ind_error did not improve from 76.77247
# Epoch 11/100
# 23992/23992 [==============================] - 10s 428us/step - loss: 0.0155
# {'ind error': 37.501165204123872}
#
# Epoch 00011: ind_error improved from 76.77247 to 37.50117, saving model to ../results/model_checkpoint.h5
# Epoch 12/100
# 23992/23992 [==============================] - 11s 454us/step - loss: 0.0139
# {'ind error': 36.364982745653982}
#
# Epoch 00012: ind_error improved from 37.50117 to 36.36498, saving model to ../results/model_checkpoint.h5
# Epoch 13/100
# 23992/23992 [==============================] - 10s 409us/step - loss: 0.0136
# {'ind error': 39.163240237103999}
#
# Epoch 00013: ind_error did not improve from 36.36498
# Epoch 14/100
# 23992/23992 [==============================] - 9s 393us/step - loss: 0.0135
# {'ind error': 42.459594990922362}
#
# Epoch 00014: ind_error did not improve from 36.36498
# Epoch 15/100
# 23992/23992 [==============================] - 10s 407us/step - loss: 0.0134
# {'ind error': 46.444555615616366}
#
# Epoch 00015: ind_error did not improve from 36.36498
# Epoch 16/100
# 23992/23992 [==============================] - 10s 398us/step - loss: 0.0133
# {'ind error': 52.206858211468479}
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00016: ind_error did not improve from 36.36498
# Epoch 17/100
# 23992/23992 [==============================] - 10s 420us/step - loss: 0.0131
# {'ind error': 25.221352497761398}
#
# Epoch 00017: ind_error improved from 36.36498 to 25.22135, saving model to ../results/model_checkpoint.h5
# Epoch 18/100
# 23992/23992 [==============================] - 10s 398us/step - loss: 0.0129
# {'ind error': 24.334887867673519}
#
# Epoch 00018: ind_error improved from 25.22135 to 24.33489, saving model to ../results/model_checkpoint.h5
# Epoch 19/100
# 23992/23992 [==============================] - 10s 407us/step - loss: 0.0129
# {'ind error': 24.194202279888213}
#
# Epoch 00019: ind_error improved from 24.33489 to 24.19420, saving model to ../results/model_checkpoint.h5
# Epoch 20/100
# 23992/23992 [==============================] - 11s 470us/step - loss: 0.0128
# {'ind error': 24.548766737343097}
#
# Epoch 00020: ind_error did not improve from 24.19420
# Epoch 21/100
# 23992/23992 [==============================] - 9s 389us/step - loss: 0.0128
# {'ind error': 23.640507143550437}
#
# Epoch 00021: ind_error improved from 24.19420 to 23.64051, saving model to ../results/model_checkpoint.h5
# Epoch 22/100
# 23992/23992 [==============================] - 9s 387us/step - loss: 0.0127
# {'ind error': 23.172526325357268}
#
# Epoch 00022: ind_error improved from 23.64051 to 23.17253, saving model to ../results/model_checkpoint.h5
# Epoch 23/100
# 23992/23992 [==============================] - 11s 451us/step - loss: 0.0127
# {'ind error': 22.854105267034551}
#
# Epoch 00023: ind_error improved from 23.17253 to 22.85411, saving model to ../results/model_checkpoint.h5
# Epoch 24/100
# 23992/23992 [==============================] - 9s 395us/step - loss: 0.0126
# {'ind error': 22.529438779671988}
#
# Epoch 00024: ind_error improved from 22.85411 to 22.52944, saving model to ../results/model_checkpoint.h5
# Epoch 25/100
# 23992/23992 [==============================] - 9s 379us/step - loss: 0.0126
# {'ind error': 21.458130912193731}
#
# Epoch 00025: ind_error improved from 22.52944 to 21.45813, saving model to ../results/model_checkpoint.h5
# Epoch 26/100
# 23992/23992 [==============================] - 9s 385us/step - loss: 0.0125
# {'ind error': 21.36564084907479}
#
# Epoch 00026: ind_error improved from 21.45813 to 21.36564, saving model to ../results/model_checkpoint.h5
# Epoch 27/100
# 23992/23992 [==============================] - 9s 385us/step - loss: 0.0125
# {'ind error': 19.434985910458273}
#
# Epoch 00027: ind_error improved from 21.36564 to 19.43499, saving model to ../results/model_checkpoint.h5
# Epoch 28/100
# 23992/23992 [==============================] - 9s 379us/step - loss: 0.0124
# {'ind error': 20.446367202309801}
#
# Epoch 00028: ind_error did not improve from 19.43499
# Epoch 29/100
# 23992/23992 [==============================] - 9s 379us/step - loss: 0.0124
# {'ind error': 19.417767787274009}
#
# Epoch 00029: ind_error improved from 19.43499 to 19.41777, saving model to ../results/model_checkpoint.h5
# Epoch 30/100
# 23992/23992 [==============================] - 11s 445us/step - loss: 0.0123
# {'ind error': 19.973978274881187}
#
# Epoch 00030: ind_error did not improve from 19.41777
# Epoch 31/100
# 23992/23992 [==============================] - 9s 387us/step - loss: 0.0124
# {'ind error': 17.793885569109356}
#
# Epoch 00031: ind_error improved from 19.41777 to 17.79389, saving model to ../results/model_checkpoint.h5
# Epoch 32/100
# 23992/23992 [==============================] - 10s 409us/step - loss: 0.0122
# {'ind error': 19.013771830158749}
#
# Epoch 00032: ind_error did not improve from 17.79389
# Epoch 33/100
# 23992/23992 [==============================] - 10s 408us/step - loss: 0.0122
# {'ind error': 18.444609797247445}
#
# Epoch 00033: ind_error did not improve from 17.79389
# Epoch 34/100
# 23992/23992 [==============================] - 9s 391us/step - loss: 0.0122
# {'ind error': 17.876462181528478}
#
# Epoch 00034: ind_error did not improve from 17.79389
# Epoch 35/100
# 23992/23992 [==============================] - 9s 380us/step - loss: 0.0121
# {'ind error': 17.773348370319439}
#
# Epoch 00035: ind_error improved from 17.79389 to 17.77335, saving model to ../results/model_checkpoint.h5
# Epoch 36/100
# 23992/23992 [==============================] - 9s 379us/step - loss: 0.0121
# {'ind error': 17.447138983192716}
#
# Epoch 00036: ind_error improved from 17.77335 to 17.44714, saving model to ../results/model_checkpoint.h5
# Epoch 37/100
# 23992/23992 [==============================] - 9s 384us/step - loss: 0.0120
# {'ind error': 17.672596193657036}
#
# Epoch 00037: ind_error did not improve from 17.44714
# Epoch 38/100
# 23992/23992 [==============================] - 9s 382us/step - loss: 0.0120
# {'ind error': 17.306666276553354}
#
# Epoch 00038: ind_error improved from 17.44714 to 17.30667, saving model to ../results/model_checkpoint.h5
# Epoch 39/100
# 23992/23992 [==============================] - 9s 383us/step - loss: 0.0119
# {'ind error': 17.117908554527084}
#
# Epoch 00039: ind_error improved from 17.30667 to 17.11791, saving model to ../results/model_checkpoint.h5
# Epoch 40/100
# 23992/23992 [==============================] - 9s 382us/step - loss: 0.0118
# {'ind error': 17.553533793900993}
#
# Epoch 00040: ind_error did not improve from 17.11791
# Epoch 41/100
# 23992/23992 [==============================] - 11s 447us/step - loss: 0.0118
# {'ind error': 16.497118808463377}
#
# Epoch 00041: ind_error improved from 17.11791 to 16.49712, saving model to ../results/model_checkpoint.h5
# Epoch 42/100
# 23992/23992 [==============================] - 10s 400us/step - loss: 0.0117
# {'ind error': 17.099669667376077}
#
# Epoch 00042: ind_error did not improve from 16.49712
# Epoch 43/100
# 23992/23992 [==============================] - 9s 388us/step - loss: 0.0117
# {'ind error': 16.381604537480321}
#
# Epoch 00043: ind_error improved from 16.49712 to 16.38160, saving model to ../results/model_checkpoint.h5
# Epoch 44/100
# 23992/23992 [==============================] - 9s 389us/step - loss: 0.0116
# {'ind error': 16.451513525489666}
#
# Epoch 00044: ind_error did not improve from 16.38160
# Epoch 45/100
# 23992/23992 [==============================] - 9s 388us/step - loss: 0.0115
# {'ind error': 15.671208043147358}
#
# Epoch 00045: ind_error improved from 16.38160 to 15.67121, saving model to ../results/model_checkpoint.h5
# Epoch 46/100
# 23992/23992 [==============================] - 9s 395us/step - loss: 0.0115
# {'ind error': 15.446174883740154}
#
# Epoch 00046: ind_error improved from 15.67121 to 15.44617, saving model to ../results/model_checkpoint.h5
# Epoch 47/100
# 23992/23992 [==============================] - 9s 388us/step - loss: 0.0115
# {'ind error': 14.477729729441077}
#
# Epoch 00047: ind_error improved from 15.44617 to 14.47773, saving model to ../results/model_checkpoint.h5
# Epoch 48/100
# 23992/23992 [==============================] - 9s 395us/step - loss: 0.0113
# {'ind error': 14.865873668354032}
#
# Epoch 00048: ind_error did not improve from 14.47773
# Epoch 49/100
# 23992/23992 [==============================] - 9s 390us/step - loss: 0.0112
# {'ind error': 14.633103014810017}
#
# Epoch 00049: ind_error did not improve from 14.47773
# Epoch 50/100
# 23992/23992 [==============================] - 9s 389us/step - loss: 0.0111
# {'ind error': 13.012242791194351}
#
# Epoch 00050: ind_error improved from 14.47773 to 13.01224, saving model to ../results/model_checkpoint.h5
# Epoch 51/100
# 23992/23992 [==============================] - 9s 390us/step - loss: 0.0110
# {'ind error': 12.616462563375272}
#
# Epoch 00051: ind_error improved from 13.01224 to 12.61646, saving model to ../results/model_checkpoint.h5
# Epoch 52/100
# 23992/23992 [==============================] - 9s 389us/step - loss: 0.0109
# {'ind error': 12.772701380630712}
#
# Epoch 00052: ind_error did not improve from 12.61646
# Epoch 53/100
# 23992/23992 [==============================] - 10s 412us/step - loss: 0.0108
# {'ind error': 12.561606500611019}
#
# Epoch 00053: ind_error improved from 12.61646 to 12.56161, saving model to ../results/model_checkpoint.h5
# Epoch 54/100
# 23992/23992 [==============================] - 9s 389us/step - loss: 0.0108
# {'ind error': 12.147048332542564}
#
# Epoch 00054: ind_error improved from 12.56161 to 12.14705, saving model to ../results/model_checkpoint.h5
# Epoch 55/100
# 23992/23992 [==============================] - 10s 397us/step - loss: 0.0107
# {'ind error': 11.684709417434293}
#
# Epoch 00055: ind_error improved from 12.14705 to 11.68471, saving model to ../results/model_checkpoint.h5
# Epoch 56/100
# 23992/23992 [==============================] - 9s 392us/step - loss: 0.0106
# {'ind error': 11.02101559386797}
#
# Epoch 00056: ind_error improved from 11.68471 to 11.02102, saving model to ../results/model_checkpoint.h5
# Epoch 57/100
# 23992/23992 [==============================] - 9s 391us/step - loss: 0.0106
# {'ind error': 10.745204501610329}
#
# Epoch 00057: ind_error improved from 11.02102 to 10.74520, saving model to ../results/model_checkpoint.h5
# Epoch 58/100
# 23992/23992 [==============================] - 10s 404us/step - loss: 0.0105
# {'ind error': 10.394741394628614}
#
# Epoch 00058: ind_error improved from 10.74520 to 10.39474, saving model to ../results/model_checkpoint.h5
# Epoch 59/100
# 23992/23992 [==============================] - 9s 393us/step - loss: 0.0104
# {'ind error': 9.8592693009197845}
#
# Epoch 00059: ind_error improved from 10.39474 to 9.85927, saving model to ../results/model_checkpoint.h5
# Epoch 60/100
# 23992/23992 [==============================] - 10s 398us/step - loss: 0.0104
# {'ind error': 9.5324720561196834}
#
# Epoch 00060: ind_error improved from 9.85927 to 9.53247, saving model to ../results/model_checkpoint.h5
# Epoch 61/100
# 23992/23992 [==============================] - 9s 388us/step - loss: 0.0103
# {'ind error': 9.1744511793217978}
#
# Epoch 00061: ind_error improved from 9.53247 to 9.17445, saving model to ../results/model_checkpoint.h5
# Epoch 62/100
# 23992/23992 [==============================] - 11s 462us/step - loss: 0.0102
# {'ind error': 8.9047652572101921}
#
# Epoch 00062: ind_error improved from 9.17445 to 8.90477, saving model to ../results/model_checkpoint.h5
# Epoch 63/100
# 23992/23992 [==============================] - 9s 380us/step - loss: 0.0102
# {'ind error': 9.7378379669470903}
#
# Epoch 00063: ind_error did not improve from 8.90477
# Epoch 64/100
# 23992/23992 [==============================] - 9s 393us/step - loss: 0.0102
# {'ind error': 8.5739300368800624}
#
# Epoch 00064: ind_error improved from 8.90477 to 8.57393, saving model to ../results/model_checkpoint.h5
# Epoch 65/100
# 23992/23992 [==============================] - 10s 413us/step - loss: 0.0101
# {'ind error': 7.8317309754532785}
#
# Epoch 00065: ind_error improved from 8.57393 to 7.83173, saving model to ../results/model_checkpoint.h5
# Epoch 66/100
# 23992/23992 [==============================] - 9s 393us/step - loss: 0.0100
# {'ind error': 8.8361280920789369}
#
# Epoch 00066: ind_error did not improve from 7.83173
# Epoch 67/100
# 23992/23992 [==============================] - 10s 407us/step - loss: 0.0100
# {'ind error': 7.3121624829556415}
#
# Epoch 00067: ind_error improved from 7.83173 to 7.31216, saving model to ../results/model_checkpoint.h5
# Epoch 68/100
# 23992/23992 [==============================] - 12s 502us/step - loss: 0.0099
# {'ind error': 8.4436352011656854}
#
# Epoch 00068: ind_error did not improve from 7.31216
# Epoch 69/100
# 23992/23992 [==============================] - 10s 396us/step - loss: 0.0098
# {'ind error': 8.0791624738976253}
#
# Epoch 00069: ind_error did not improve from 7.31216
# Epoch 70/100
# 23992/23992 [==============================] - 9s 385us/step - loss: 0.0098
# {'ind error': 7.9477401252705935}
#
# Epoch 00070: ind_error did not improve from 7.31216
# Epoch 71/100
# 23992/23992 [==============================] - 9s 387us/step - loss: 0.0098
# {'ind error': 8.5306170282800569}
#
# Epoch 00071: ind_error did not improve from 7.31216
# Epoch 72/100
# 23992/23992 [==============================] - 11s 479us/step - loss: 0.0098
# {'ind error': 6.7356098977471062}
#
# Epoch 00072: ind_error improved from 7.31216 to 6.73561, saving model to ../results/model_checkpoint.h5
# Epoch 73/100
# 23992/23992 [==============================] - 10s 424us/step - loss: 0.0096
# {'ind error': 6.3587859541261826}
#
# Epoch 00073: ind_error improved from 6.73561 to 6.35879, saving model to ../results/model_checkpoint.h5
# Epoch 74/100
# 23992/23992 [==============================] - 12s 517us/step - loss: 0.0096
# {'ind error': 8.3004991975886693}
#
# Epoch 00074: ind_error did not improve from 6.35879
# Epoch 75/100
# 23992/23992 [==============================] - 10s 435us/step - loss: 0.0095
# {'ind error': 7.5482280343944472}
#
# Epoch 00075: ind_error did not improve from 6.35879
# Epoch 76/100
# 23992/23992 [==============================] - 10s 411us/step - loss: 0.0095
# {'ind error': 7.2425598022900193}
#
# Epoch 00076: ind_error did not improve from 6.35879
# Epoch 77/100
# 23992/23992 [==============================] - 12s 516us/step - loss: 0.0095
# {'ind error': 7.232441678491643}
#
# Epoch 00077: ind_error did not improve from 6.35879
# Epoch 78/100
# 23992/23992 [==============================] - 11s 439us/step - loss: 0.0095
# {'ind error': 6.9670754144540439}
#
# Epoch 00078: ind_error did not improve from 6.35879
# Epoch 79/100
# 23992/23992 [==============================] - 11s 458us/step - loss: 0.0093
# {'ind error': 6.8041898002253305}
#
# Epoch 00079: ind_error did not improve from 6.35879
# Epoch 80/100
# 23992/23992 [==============================] - 10s 426us/step - loss: 0.0093
# {'ind error': 6.4905885742361269}
#
# Epoch 00080: ind_error did not improve from 6.35879
# Epoch 81/100
# 23992/23992 [==============================] - 10s 433us/step - loss: 0.0093
# {'ind error': 6.7235707977341175}
#
# Epoch 00081: ind_error did not improve from 6.35879
# Epoch 82/100
# 23992/23992 [==============================] - 10s 402us/step - loss: 0.0092
# {'ind error': 6.4770786941144127}
#
# Epoch 00082: ind_error did not improve from 6.35879
# Epoch 83/100
# 23992/23992 [==============================] - 11s 476us/step - loss: 0.0092
# {'ind error': 6.8202423903743838}
#
# Epoch 00083: ind_error did not improve from 6.35879
# Epoch 00083: early stopping

# %%
hist.history
# Out:
# {'loss': [0.44939304901663962, 0.42343738024216487],
#  'ind_error': [1069.4005560467238, 1042.7223205914377]}

# %%
c_model = Sequential()
#model.add(LSTM(height, batch_input_shape=(None, d, n_features), return_sequences=True))
c_model.add(LSTM(height, batch_input_shape=(None, d, n_features), return_sequences=False))
#model.add(Dropout(0.1))
c_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
c_model.compile(loss='mae', optimizer=adam)

c_ind_errors = []
n_batches = 23

for epoch in range(epochs):

    for n in range(n_batches):
        x_batch, y_batch = get_batch(x_train, y_train, batch_size)
        c_model.train_on_batch(x_batch, y_batch)
        #if n == 1:

         #   model.train_on_batch(x_batch, y_batch)
        #else:
            #x_batch = independent_batch(x_batch)

            #model.train_on_batch(x_batch, y_batch)

    pred_ind_all = independent_predictions(x_test, c_model)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])
    
    c_ind_error.append(ind_error)
    
    info = {'epoch': epoch, 'ind_error': ind_error}
    print(info)
    
c_errors_matrix.append(c_ind_errors)
# Out:
# {'epoch': 0, 'ind_error': 1390.3703770038869}
# {'epoch': 1, 'ind_error': 999.84833213132822}
# {'epoch': 2, 'ind_error': 424.48596463447439}
# {'epoch': 3, 'ind_error': 109.39424424353902}
# {'epoch': 4, 'ind_error': 89.09841495509842}
# {'epoch': 5, 'ind_error': 82.502843878941306}
# {'epoch': 6, 'ind_error': 62.670841288877462}
# {'epoch': 7, 'ind_error': 56.963819012467418}
# {'epoch': 8, 'ind_error': 33.931442149364045}
# {'epoch': 9, 'ind_error': 33.573747532668662}
# {'epoch': 10, 'ind_error': 25.07587854483819}
# {'epoch': 11, 'ind_error': 25.069191203895418}
# {'epoch': 12, 'ind_error': 27.149475929723067}
# {'epoch': 13, 'ind_error': 28.594334616427172}
# {'epoch': 14, 'ind_error': 35.065252676896336}
# {'epoch': 15, 'ind_error': 28.689676618161766}
# {'epoch': 16, 'ind_error': 26.551119325875867}
# {'epoch': 17, 'ind_error': 21.888354407324567}
# {'epoch': 18, 'ind_error': 20.694100000437462}
# {'epoch': 19, 'ind_error': 18.365003062107611}
# {'epoch': 20, 'ind_error': 16.780369629964973}
# {'epoch': 21, 'ind_error': 14.82278419887894}
# {'epoch': 22, 'ind_error': 14.074147653019182}
# {'epoch': 23, 'ind_error': 15.576613933936548}
# {'epoch': 24, 'ind_error': 12.074545593899739}
# {'epoch': 25, 'ind_error': 13.544339330699685}
# {'epoch': 26, 'ind_error': 12.265720869127676}
# {'epoch': 27, 'ind_error': 12.437508413901879}
# {'epoch': 28, 'ind_error': 11.445511454550298}
# {'epoch': 29, 'ind_error': 12.252021955346699}
# {'epoch': 30, 'ind_error': 17.189933089678121}
# {'epoch': 31, 'ind_error': 11.800483229868913}
# {'epoch': 32, 'ind_error': 20.376983096614122}
# {'epoch': 33, 'ind_error': 19.100336569909249}
# {'epoch': 34, 'ind_error': 18.668618805557315}
# {'epoch': 35, 'ind_error': 8.897117689548466}
# {'epoch': 36, 'ind_error': 11.048987462881589}
# {'epoch': 37, 'ind_error': 10.487494285998782}
# {'epoch': 38, 'ind_error': 11.260341600022802}
# {'epoch': 39, 'ind_error': 9.9044855851827407}

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
plt.plot(u_errors_matrix[0])
#plt.plot(c_ind_error)
plt.show()

# %%
np.array(u_errors_matrix)
# Out:
# array([[ 120.50553849,   69.33300448,   39.23126048,   24.56743535,
#          114.73446446,   18.97193509,   24.54977661,   15.2157244 ,
#           16.55055742,   18.74317989,   12.0495602 ,   11.95710951,
#           11.00162658,   12.82591794,    9.41836339,   13.99090467,
#           12.59388701,    8.16901013,    9.01311162,    8.83940604,
#            8.57435572,    8.63230778,    8.64802911,    8.65123094,
#            8.67079743,    8.69655673,    8.71869399,    8.74382999]])

# %%
pred_ind_all = independent_predictions(x_test, u_model)

# %%
pred_ind = pred_ind_all[:, 0:n_nodes]
ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])

# %%
print(ind_error)
# Out:
# 6.82024239037

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
plt.plot(pred_ind[:,n_nodes-1])
plt.plot(y_test[:, n_nodes-1])
plt.show()

# %%
def generate_export(my_model):
    pred_train_all = my_model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]

    pred_test_all = my_model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]

    pred_ind_all = independent_predictions(x_test, my_model)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]

    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    #Export results
    np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
    np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
    np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
    np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
generate_export(u_model)

# %%
#Export results
np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-8516659a0563> in <module>()
#       1 #Export results
# ----> 2 np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
#       3 np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
#       4 np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
#       5 np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")
#
# NameError: name 'pred_test_u' is not defined

# %%
# one layer, height 500, gives lowest error around 9, but this is while its heavily overfitting
# one layer, height 100, on gr_set1 goes down to about 6 at epoch 40, then starts overfitting
# same, but with height 200 starts oscillating around batch 20, then the ind error is around 9. 
# With dropout 0.1 the results are bad


#df = df.drop(columns=df.columns[0])
#df.to_csv('../results/RNN_velocity_results.csv')

# %%
#pd.read_csv('../results/RNN_velocity_results.csv', index_col=0)
# Out:
#   training set  n_layers  height  epochs  batch size  learning rate  \
# 0           rr         2     100     500        1000         0.0005
# 1           rr         2     100     500        1000         0.0001
# 2           rr         3      50     500        1000         0.0005
#
#    early stopping  stop loss  Training Error  Test Error  Ind test error  \
# 0             115   0.005931        0.428430    0.102271        4.126604
# 1              36   0.005536        0.457434    0.111018       18.604378
# 2             160   0.013542        0.497549    0.108562       11.480535
#
#    Ind train error  Training time   Total time
# 0        19.038270    2173.341693  2263.469776
# 1        96.249718     707.928417   803.638126
# 2        70.656266    5234.750504  5392.588225

# %%
#save best model
#trained on= gr_set1

#model.save('../models/RNN_gr_set1.h5')

#### CONTINUE TRAINING ####
#model = load_model('beam_model.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
######################### BATCH TESTING ########################################

n_batches = 1
#d = 8

t0 = time.time()
for iteration in range(n_batches):

    df_D = pd.read_csv('../training_batches/rrD' + str(iteration+1) + '.csv')
    df_F = pd.read_csv('../training_batches/rrF' + str(iteration+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/rrDt' + str(iteration+1) + '.csv')

    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    #if i == 0:
    #    model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    pred_train_all = model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]
    
    pred_test_all = model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]
    
    pred_ind_all = independent_predictions(x_test)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]
    
    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    training_error = get_error(pred_train, y_train[:,0:n_nodes])
    test_error = get_error(pred_test, y_test[:,0:n_nodes])
    ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])
    
    plt.figure(figsize=(16,10))
    #plt.plot(pred_test[:,n_nodes-1], 'x')
    plt.plot(pred_ind[:,n_nodes-1])
    plt.plot(y_test[:, n_nodes-1])
    plt.show()

    
    total_time = time.time() - t0
    
    info = {'Iteration number': iteration+1, 'Training Error': training_error, 'Test Error': test_error, 'Ind test error': ind_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Training Error': 1.7276860353577641, 'Test Error': 0.29846556877570002, 'Ind test error': 18.855915684260651, 'Training time': 0.0, 'Total time': 34.77224016189575}

# %%
#Export results
np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
pred_ind_all = independent_predictions(x_train)
pred_ind = pred_ind_all[:, 0:n_nodes]

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
plt.plot(pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.show()

# %%
DF.shape
# Out:
# (4995, 205)

# %%
df_D.values.shape
# Out:
# (5000, 21)

# %%
plt.plot(y_test_u[50,:])
