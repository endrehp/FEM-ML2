# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
import math
import time

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.utils import np_utils
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping, History, Callback, ReduceLROnPlateau, ModelCheckpoint

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
def prepare_training_data(df_F, df_D, df_Dt, d):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = np.concatenate((df_D.values, df_Dt.values), axis=1)
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def train_test_split(DF, Dy, d, x_scaler, y_scaler, train_portion):

    dim = np.shape(Dy)

    n_nodes = int(dim[1]/2)
    n_y = dim[1]
    x = np.linspace(0,1, n_nodes)

    #Scaling
    DFscaled = x_scaler.transform(DF)
    Dyscaled = y_scaler.transform(Dy)

    X_train = DFscaled
    Y_train = Dyscaled

    #Train test split
    #train_portion = 0.8
    n_timesteps = len(X_train[:,0])
    x_train = X_train[0:int(n_timesteps*train_portion),:]
    x_test = X_train[int(n_timesteps*(train_portion)):,:]
    y_train = Y_train[0:int(n_timesteps*train_portion),:]
    y_test = Y_train[int(n_timesteps*(train_portion)):,:]

    n_features = int(x_train.shape[1]/d)
    
    #Reshape training data into 3D array as required by the LSTM layer
    #Input shape is: (n_timesteps, d, n_features)
    x_train = x_train.reshape((x_train.shape[0], d, n_features))
    x_test = x_test.reshape((x_test.shape[0], d, n_features))

    return x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x

# %%
def initialize_model(n_units, x_train, y_train, lr, n_layers):
    model = Sequential()
    
    #Add hidden layers, return_sequences=True if next layer is LSTM, False otherwise
    if n_layers == 1:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=False))
        
    elif n_layers == 2:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        model.add(LSTM(n_units))
    else: 
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        for layer in range(n_layers-1):
            model.add(LSTM(n_units, return_sequences = True))
        model.add(LSTM(n_units))
    
    
    #model.add(Dropout(0.1))
    
    model.add(Dense(len(y_train[0,:]))) #Output Layer
    adam = Adam(lr=lr)
    model.compile(loss='mae', optimizer=adam)
    
    #Define callbacks
    history = History()
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
    callback_list = [earlystop, history]
    return model, callback_list

# %%
def get_error(predictions, y_test):
    #Squared error is integrated numerically in space for each timestep and summed
    error = 0
    for i in range(len(predictions)):
        error += (y_test[i] - predictions[i])**2
    return error

# %%
def independent_predictions(x_test, my_model):

    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known
    for i in range(future_timesteps): 
        pred = my_model.predict(input_i_reshaped) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        input_i[d-1,0] = force[i+1,d-1] #Fill in force for next timestep
        input_i[d-1,1:] = pred[0] #Fill in values that we just predicted

        input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
        
    return preds

# %%
def independent_batch(x_batch):

    input_i = np.copy(x_batch[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_batch[:,0,0])

    force = np.copy(x_batch[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known
    
    ind_batch = np.zeros([future_timesteps, d, n_features])
    ind_batch[0] = input_i_reshaped[0]
    
    for i in range(future_timesteps): 
        pred = model.predict(input_i_reshaped) #Predict next timestep
        
        if i < future_timesteps - 1:
            input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
            input_i[d-1,:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
            input_i[d-1,n_nodes:] = pred[0] #Fill in values that we just predicted

            input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
            ind_batch[i+1] = input_i_reshaped[0]
        
    return ind_batch

# %%
def get_scalers(DF, Dy):
    
    x_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    
    x_scaler.fit_transform(DF)
    y_scaler.fit_transform(Dy)
    
    return x_scaler, y_scaler

# %%
def get_batch_scalers(n_batches, training_set):
    
    #Simple version
    for i in range(n_batches):
        
        df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(i+1) + '.csv')
        df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(i+1) + '.csv')
        df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(i+1) + '.csv')
        
        if i == 0:  
            x_range = df_D.values.max() - df_D.values.min()
            imax = i
        
        else:
            new_x_range = df_D.values.max() - df_D.values.min()
            
            if new_x_range > x_range:
                x_range = new_x_range
                imax = i
                
    df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(imax+1) + '.csv')
    df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(imax+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(imax+1) + '.csv')
    
    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    return x_scaler, y_scaler

# %%
#columns = ['training set', 'n_layers', 'height', 'epochs', 'batch size', 'learning rate', 'early stopping', 'stop loss', 'Training Error', 'Test Error',
#           'Ind test error', 'Ind train error', 'Training time', 'Total time']
#df = pd.DataFrame(columns = columns)

#df.to_csv('../results/RNN_velocity_results.csv')

# %%
def get_batch(x_train, y_train, batch_size):
    
    start = random.randint(0,len(x_train)-batch_size)
    
    x_batch = x_train[start:start+batch_size]
    y_batch = y_train[start:start+batch_size]
    
    return x_batch, y_batch

# %%
class Ind_pred(Callback):
    
    def on_epoch_end(self, epoch, logs={}):
        
        error = 0
        if epoch > 400 or epoch%20 == 0:
            

            input_i = np.copy(x_test[0,:,:]) #Initial conditions
            input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

            future_timesteps = len(x_test[:,0,0])-1
            preds = np.zeros([future_timesteps, n_y])

            force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known
            for i in range(future_timesteps): 
                
                pred = self.model.predict(input_i_reshaped) #Predict next timestep
                preds[i, :] = pred[0] 

                input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
                input_i[d-1,0] = force[i+1,d-1] #Fill in force for next timestep
                input_i[d-1,1:] = pred[0] #Fill in values that we just predicted

                input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer



            error = 0
            for i in range(len(preds[:,0])):
                error += (y_test[i,0] - preds[i,0])**2

        info = {'ind error': error}

        logs['ind_error'] = error

        print(info)
    
    #def on_batch_end(self, batch, logs={}):
    #    print(batch)

# %%
f_model.predict(x_train[0,:].reshape([1,d,n_features]))
# Out:
# array([[-0.03850845,  0.43545601]], dtype=float32)

# %%
def independent_predictions_pca(x_test, my_model):        
    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    #input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known

    new_step = np.zeros(len(x_test[0,0,:]))
    input_shape = input_i.shape

    for i in range(future_timesteps): 

        input_i_pca = pca.transform(input_i.reshape([input_shape[0], input_shape[1]]))

        pred = my_model.predict(input_i_pca.reshape([1,d,n_features])) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        new_step[0] = force[i+1,d-1] #Fill in force for next timestep
        new_step[1:] = pred[0] #Fill in values that we just predicted


        input_i[d-1,:] = new_step.reshape([1,len(new_step)])
        
    return preds

# %%
#Select training set
training_set = 'mass'
iteration = 3
d = 10
train_portion = 0.85

#Import training data
df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(iteration) + '.csv')
df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(iteration) + '.csv')
df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(iteration) + '.csv')

#Prepare training data
DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)

#Get global scalers
x_scaler, y_scaler = get_scalers(DF[:,n_nodes-1::n_nodes], Dy[:,n_nodes-1::n_nodes])

#Split into train and test set
x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF[:,n_nodes-1::n_nodes], Dy[:,n_nodes-1::n_nodes], d, x_scaler, y_scaler, train_portion)

# %%
x_train[0,0,:]
# Out:
# array([ 0.72313711,  0.51812133,  0.50413708])

# %%
#X = x_train[:,0,:]
#df = pd.DataFrame(X)

#correlation = df.corr()
#plt.figure(figsize=(20,20))
#sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

#plt.title('Correlation between different fearures')

# %%
######################### BATCH TRAINING ########################################

n_batches = 1
d = 10

#Hyperparameter settings
epochs = 180
layers = 1
height = 50
batch_size = 1000
lr = 0.001
u_errors_matrix = []
c_errors_matrix =[]

# %%
#n_features = sh1[1]

# %%
############## Model.fit #####################
t0 = time.time()
f_model = Sequential()
#f_model.add(LSTM(height, input_shape=(d, n_features), return_sequences=True))
#f_model.add(LSTM(height, return_sequences=False))
f_model.add(LSTM(height, input_shape=(d, n_features), return_sequences=False))
#model.add(Dropout(0.1))
f_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
f_model.compile(loss='mae', optimizer=adam)

u_ind_errors = []
#Define callbacks
ind_pred = Ind_pred()
history = History()
earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=30, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=5, min_lr=0.0001, mode='min', verbose=1)
model_cp = ModelCheckpoint('../results/f_model_checkpoint.h5', monitor='ind_error', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)
hist = f_model.fit(x_train, y_train, epochs=epochs, callbacks=[ind_pred, history, reduce_lr], batch_size=batch_size, 
                   verbose=1, shuffle=False)

#hist = f_model.fit(x_train_pca, y_train, epochs=epochs, callbacks=[reduce_lr], batch_size=batch_size, 
#                   verbose=1, shuffle=False)

print({'total time': time.time()-t0})
# Out:
# Epoch 1/180
# 42491/42491 [==============================] - 3s 76us/step - loss: 0.1503
# {'ind error': 118.51046483486765}
# Epoch 2/180
# 42491/42491 [==============================] - 2s 49us/step - loss: 0.0399: 1s - loss: 0. - ETA: 1
# {'ind error': 0}
# Epoch 3/180
# 42491/42491 [==============================] - 2s 49us/step - loss: 0.0155
# {'ind error': 0}
# Epoch 4/180
# 42491/42491 [==============================] - 2s 51us/step - loss: 0.0055
# {'ind error': 0}
# Epoch 5/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0044
# {'ind error': 0}
# Epoch 6/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0056
# {'ind error': 0}
# Epoch 7/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 8/180
# 42491/42491 [==============================] - 3s 61us/step - loss: 0.0065
# {'ind error': 0}
# Epoch 9/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 0.0049
# {'ind error': 0}
# Epoch 10/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 0.0024
# {'ind error': 0}
# Epoch 11/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 0.0033
# {'ind error': 0}
# Epoch 12/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 0.0047
# {'ind error': 0}
# Epoch 13/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 0.0049
# {'ind error': 0}
# Epoch 14/180
# 42491/42491 [==============================] - 3s 60us/step - loss: 0.0045
# {'ind error': 0}
# Epoch 15/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 0.0045
# {'ind error': 0}
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 16/180
# 42491/42491 [==============================] - 3s 61us/step - loss: 0.0023: 0s - loss: 0.0
# {'ind error': 0}
# Epoch 17/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 0.0014
# {'ind error': 0}
# Epoch 18/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0014
# {'ind error': 0}
# Epoch 19/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0013
# {'ind error': 0}
# Epoch 20/180
# 42491/42491 [==============================] - 2s 59us/step - loss: 0.0013
# {'ind error': 0}
# Epoch 21/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0014
# {'ind error': 2.1266865840641258}
# Epoch 22/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0014
# {'ind error': 0}
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 23/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0013: 0s - loss: 0.001
# {'ind error': 0}
# Epoch 24/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0013
# {'ind error': 0}
# Epoch 25/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0013
# {'ind error': 0}
# Epoch 26/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 0.0013: 0s - loss
# {'ind error': 0}
# Epoch 27/180
# 42491/42491 [==============================] - 2s 59us/step - loss: 0.0013
# {'ind error': 0}
# Epoch 28/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 29/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 30/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 31/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 32/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 33/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 34/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 35/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 36/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 37/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 38/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 39/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 40/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 41/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0012
# {'ind error': 1.629603265338573}
# Epoch 42/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 43/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 44/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 45/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 46/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 47/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 48/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 49/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 50/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 0.0012
# {'ind error': 0}
# Epoch 51/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 52/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 53/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 54/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 55/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 56/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0011: 0s - loss: 0.0
# {'ind error': 0}
# Epoch 57/180
# 42491/42491 [==============================] - 2s 52us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 58/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 59/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 60/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 61/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 0.0010
# {'ind error': 1.6598829307594307}
# Epoch 62/180
# 42491/42491 [==============================] - ETA: 0s - loss: 0.001 - 2s 54us/step - loss: 0.0011
# {'ind error': 0}
# Epoch 63/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0010
# {'ind error': 0}
# Epoch 64/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0010
# {'ind error': 0}
# Epoch 65/180
# 42491/42491 [==============================] - 2s 52us/step - loss: 0.0010
# {'ind error': 0}
# Epoch 66/180
# 42491/42491 [==============================] - 2s 52us/step - loss: 0.0010
# {'ind error': 0}
# Epoch 67/180
# 42491/42491 [==============================] - 2s 52us/step - loss: 0.0010
# {'ind error': 0}
# Epoch 68/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 0.0010
# {'ind error': 0}
# Epoch 69/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 0.0010
# {'ind error': 0}
# Epoch 70/180
# 42491/42491 [==============================] - 2s 52us/step - loss: 9.7000e-04
# {'ind error': 0}
# Epoch 71/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 9.9339e-04
# {'ind error': 0}
# Epoch 72/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 9.9225e-04
# {'ind error': 0}
# Epoch 73/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 9.8824e-04
# {'ind error': 0}
# Epoch 74/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 9.8375e-04
# {'ind error': 0}
# Epoch 75/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 9.7085e-04
# {'ind error': 0}
# Epoch 76/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 9.6365e-04
# {'ind error': 0}
# Epoch 77/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 9.5697e-04
# {'ind error': 0}
# Epoch 78/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 9.5153e-04
# {'ind error': 0}
# Epoch 79/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 9.4093e-04
# {'ind error': 0}
# Epoch 80/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 9.4217e-04
# {'ind error': 0}
# Epoch 81/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 9.2315e-04
# {'ind error': 1.3315347287432377}
# Epoch 82/180
# 42491/42491 [==============================] - 3s 61us/step - loss: 9.3337e-04
# {'ind error': 0}
# Epoch 83/180
# 42491/42491 [==============================] - 3s 60us/step - loss: 8.9659e-04
# {'ind error': 0}
# Epoch 84/180
# 42491/42491 [==============================] - 3s 63us/step - loss: 9.2727e-04
# {'ind error': 0}
# Epoch 85/180
# 42491/42491 [==============================] - 3s 62us/step - loss: 9.1546e-04
# {'ind error': 0}
# Epoch 86/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 9.2207e-04
# {'ind error': 0}
# Epoch 87/180
# 42491/42491 [==============================] - 3s 61us/step - loss: 9.1226e-04
# {'ind error': 0}
# Epoch 88/180
# 42491/42491 [==============================] - 3s 60us/step - loss: 9.1407e-04
# {'ind error': 0}
# Epoch 89/180
# 42491/42491 [==============================] - 3s 62us/step - loss: 9.2725e-04
# {'ind error': 0}
# Epoch 90/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 9.0017e-04
# {'ind error': 0}
# Epoch 91/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 8.9299e-04
# {'ind error': 0}
# Epoch 92/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 8.6607e-04
# {'ind error': 0}
# Epoch 93/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 9.1407e-04
# {'ind error': 0}
# Epoch 94/180
# 42491/42491 [==============================] - 3s 60us/step - loss: 8.9042e-04
# {'ind error': 0}
# Epoch 95/180
# 42491/42491 [==============================] - 3s 61us/step - loss: 8.6905e-04
# {'ind error': 0}
# Epoch 96/180
# 42491/42491 [==============================] - 3s 60us/step - loss: 8.5816e-04
# {'ind error': 0}
# Epoch 97/180
# 42491/42491 [==============================] - 3s 60us/step - loss: 8.7086e-04
# {'ind error': 0}
# Epoch 98/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 8.5816e-04
# {'ind error': 0}
# Epoch 99/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 8.7009e-04
# {'ind error': 0}
# Epoch 100/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 8.6194e-04
# {'ind error': 0}
# Epoch 101/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 8.7783e-04
# {'ind error': 1.2618559522297981}
# Epoch 102/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 8.7123e-04
# {'ind error': 0}
# Epoch 103/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 8.5256e-04
# {'ind error': 0}
# Epoch 104/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 8.2109e-04
# {'ind error': 0}
# Epoch 105/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 8.6782e-04
# {'ind error': 0}
# Epoch 106/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 8.1145e-04
# {'ind error': 0}
# Epoch 107/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 8.5852e-04
# {'ind error': 0}
# Epoch 108/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 8.6544e-04
# {'ind error': 0}
# Epoch 109/180
# 42491/42491 [==============================] - 3s 60us/step - loss: 8.2678e-04
# {'ind error': 0}
# Epoch 110/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 8.1140e-04
# {'ind error': 0}
# Epoch 111/180
# 42491/42491 [==============================] - 3s 62us/step - loss: 8.0305e-04
# {'ind error': 0}
# Epoch 112/180
# 42491/42491 [==============================] - 3s 60us/step - loss: 8.2098e-04: 2s - loss: - ET
# {'ind error': 0}
# Epoch 113/180
# 42491/42491 [==============================] - 2s 59us/step - loss: 7.9620e-04
# {'ind error': 0}
# Epoch 114/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 7.8222e-04
# {'ind error': 0}
# Epoch 115/180
# 42491/42491 [==============================] - 2s 59us/step - loss: 7.9681e-04
# {'ind error': 0}
# Epoch 116/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 8.3082e-04
# {'ind error': 0}
# Epoch 117/180
# 42491/42491 [==============================] - 3s 61us/step - loss: 7.9357e-04: 0s - loss
# {'ind error': 0}
# Epoch 118/180
# 42491/42491 [==============================] - 3s 61us/step - loss: 7.9763e-04
# {'ind error': 0}
# Epoch 119/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 7.9877e-04
# {'ind error': 0}
# Epoch 120/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 7.6711e-04: 0s - loss: 7.6487e-0
# {'ind error': 0}
# Epoch 121/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 7.9270e-04
# {'ind error': 1.0978347852899211}
# Epoch 122/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.8690e-04
# {'ind error': 0}
# Epoch 123/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.5599e-04
# {'ind error': 0}
# Epoch 124/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.5070e-04
# {'ind error': 0}
# Epoch 125/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.5763e-04
# {'ind error': 0}
# Epoch 126/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 7.7819e-04
# {'ind error': 0}
# Epoch 127/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 8.1866e-04
# {'ind error': 0}
# Epoch 128/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 8.0369e-04
# {'ind error': 0}
# Epoch 129/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.5277e-04
# {'ind error': 0}
# Epoch 130/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 7.5325e-04
# {'ind error': 0}
# Epoch 131/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 7.3938e-04
# {'ind error': 0}
# Epoch 132/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 7.3139e-04
# {'ind error': 0}
# Epoch 133/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 7.3384e-04
# {'ind error': 0}
# Epoch 134/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.4456e-04
# {'ind error': 0}
# Epoch 135/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.2016e-04: 0s - loss: 6
# {'ind error': 0}
# Epoch 136/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 7.4795e-04
# {'ind error': 0}
# Epoch 137/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 7.6541e-04
# {'ind error': 0}
# Epoch 138/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.2266e-04
# {'ind error': 0}
# Epoch 139/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.4565e-04
# {'ind error': 0}
# Epoch 140/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 7.0094e-04
# {'ind error': 0}
# Epoch 141/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 7.2071e-04
# {'ind error': 1.1234895446909068}
# Epoch 142/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 7.3567e-04
# {'ind error': 0}
# Epoch 143/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 7.3140e-04
# {'ind error': 0}
# Epoch 144/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 7.5525e-04
# {'ind error': 0}
# Epoch 145/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 7.1989e-04
# {'ind error': 0}
# Epoch 146/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 7.0568e-04
# {'ind error': 0}
# Epoch 147/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 7.1030e-04
# {'ind error': 0}
# Epoch 148/180
# 42491/42491 [==============================] - 2s 53us/step - loss: 7.5290e-04
# {'ind error': 0}
# Epoch 149/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 6.9162e-04
# {'ind error': 0}
# Epoch 150/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 7.2680e-04
# {'ind error': 0}
# Epoch 151/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 6.9326e-04
# {'ind error': 0}
# Epoch 152/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 6.8353e-04: 0s - l
# {'ind error': 0}
# Epoch 153/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 6.8884e-04
# {'ind error': 0}
# Epoch 154/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 6.7290e-04
# {'ind error': 0}
# Epoch 155/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 7.4182e-04
# {'ind error': 0}
# Epoch 156/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 8.0431e-04
# {'ind error': 0}
# Epoch 157/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 6.7988e-04
# {'ind error': 0}
# Epoch 158/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 6.6321e-04
# {'ind error': 0}
# Epoch 159/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 7.0923e-04: 0s - loss: 7.0847e-0
# {'ind error': 0}
# Epoch 160/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 7.1109e-04
# {'ind error': 0}
# Epoch 161/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 6.3496e-04
# {'ind error': 0.93942991032858825}
# Epoch 162/180
# 42491/42491 [==============================] - 3s 61us/step - loss: 6.9259e-04
# {'ind error': 0}
# Epoch 163/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 7.7409e-04
# {'ind error': 0}
# Epoch 164/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 6.4517e-04
# {'ind error': 0}
# Epoch 165/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 6.7872e-04
# {'ind error': 0}
# Epoch 166/180
# 42491/42491 [==============================] - 3s 65us/step - loss: 6.6344e-04
# {'ind error': 0}
# Epoch 167/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 6.6637e-04
# {'ind error': 0}
# Epoch 168/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 6.5965e-04
# {'ind error': 0}
# Epoch 169/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 6.8664e-04
# {'ind error': 0}
# Epoch 170/180
# 42491/42491 [==============================] - 2s 57us/step - loss: 6.3412e-04
# {'ind error': 0}
# Epoch 171/180
# 42491/42491 [==============================] - 3s 59us/step - loss: 6.5890e-04
# {'ind error': 0}
# Epoch 172/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 6.6277e-04
# {'ind error': 0}
# Epoch 173/180
# 42491/42491 [==============================] - 2s 56us/step - loss: 6.7363e-04
# {'ind error': 0}
# Epoch 174/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 7.1283e-04
# {'ind error': 0}
# Epoch 175/180
# 42491/42491 [==============================] - 2s 58us/step - loss: 7.3558e-04
# {'ind error': 0}
# Epoch 176/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 6.3274e-04
# {'ind error': 0}
# Epoch 177/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 6.3540e-04
# {'ind error': 0}
# Epoch 178/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 6.7750e-04
# {'ind error': 0}
# Epoch 179/180
# 42491/42491 [==============================] - 2s 54us/step - loss: 6.7535e-04
# {'ind error': 0}
# Epoch 180/180
# 42491/42491 [==============================] - 2s 55us/step - loss: 6.6334e-04
# {'ind error': 0}
# {'total time': 503.19482040405273}

# %%
f_pred_ind_all = independent_predictions(x_train, f_model)
f_pred_ind = f_pred_ind_all[:, 0:n_nodes]
#bt_pred_ind_all = independent_predictions_pca(x_test, bt_model)

# %%
f_pred_ind = f_pred_ind_all[:, 0]

# %%
f_ind_error = get_error(f_pred_ind, y_train[0:len(f_pred_ind),0])
print(f_ind_error)
# Out:
# 24.6795365811

# %%
#bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
#bt_ind_error = get_error(bt_pred_ind, y_test[0:len(bt_pred_ind[:,0]),0:n_nodes])
#print(bt_ind_error)

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])

plt.plot(y_train[:,0])
plt.plot(f_pred_ind[:])

plt.show()

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])
#plt.plot(f_pred_ind[:,n_nodes-1])
plt.plot(y_test[:, n_nodes-1])
plt.show()

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])
#plt.plot(f_pred_ind[:,n_nodes-1])
plt.plot(x_test[:,-1,0])
plt.show()

# %%
y_train[0:10,0]
# Out:
# array([ 0.52983856,  0.53072355,  0.53150517,  0.53219584,  0.53282808,
#         0.53340882,  0.53395595,  0.5344567 ,  0.53490266,  0.53525549])

# %%
#save best model
#trained on= rr_set1

#u_model.save('../models/pca_RNN_gr_set1.h5')

#### CONTINUE TRAINING ####
#model = load_model('../models/RNN_gr_set1.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
def generate_export(my_model):
    pred_train_all = my_model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]

    pred_test_all = my_model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]

    pred_ind_all = independent_predictions(x_test, my_model)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]

    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    #Export results
    np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
    np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
    np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
    np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
generate_export(u_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-c444d0737e2c> in <module>()
# ----> 1 generate_export(u_model)
#
# <ipython-input-136-50e79082a532> in generate_export(my_model)
#       1 def generate_export(my_model):
# ----> 2     pred_train_all = my_model.predict(x_train)
#       3     pred_train = pred_train_all[:, 0:n_nodes]
#       4     pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/keras/models.py in predict(self, x, batch_size, verbose, steps)
#    1023             self.build()
#    1024         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1025                                   steps=steps)
#    1026
#    1027     def predict_on_batch(self, x):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1815         x = _standardize_input_data(x, self._feed_input_names,
#    1816                                     self._feed_input_shapes,
# -> 1817                                     check_batch_axis=False)
#    1818         if self.stateful:
#    1819             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     121                             ': expected ' + names[i] + ' to have shape ' +
#     122                             str(shape) + ' but got array with shape ' +
# --> 123                             str(data_shape))
#     124     return data
#     125
#
# ValueError: Error when checking : expected lstm_18_input to have shape (4, 1) but got array with shape (10, 60)

# %%
y_test_u = y_scaler.inverse_transform(y_train)[:, 0:n_nodes]
f_pred_ind_u = y_scaler.inverse_transform(f_pred_ind_all)[:, 0:n_nodes]

# %%
y_test_u[0:10,0]
# Out:
# array([ 0.00033145,  0.00035568,  0.00037708,  0.00039599,  0.0004133 ,
#         0.0004292 ,  0.00044418,  0.00045789,  0.0004701 ,  0.00047976])

# %%
#Export results
#np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", f_pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
#np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
# one layer, height 500, gives lowest error around 9, but this is while its heavily overfitting
# one layer, height 100, on gr_set1 goes down to about 6 at epoch 40, then starts overfitting
# same, but with height 200 starts oscillating around batch 20, then the ind error is around 9. 
# With dropout 0.1 the results are bad


#df = df.drop(columns=df.columns[0])
#df.to_csv('../results/RNN_velocity_results.csv')

# %%
#pd.read_csv('../results/RNN_velocity_results.csv', index_col=0)
# Out:
#   training set  n_layers  height  epochs  batch size  learning rate  \
# 0           rr         2     100     500        1000         0.0005
# 1           rr         2     100     500        1000         0.0001
# 2           rr         3      50     500        1000         0.0005
#
#    early stopping  stop loss  Training Error  Test Error  Ind test error  \
# 0             115   0.005931        0.428430    0.102271        4.126604
# 1              36   0.005536        0.457434    0.111018       18.604378
# 2             160   0.013542        0.497549    0.108562       11.480535
#
#    Ind train error  Training time   Total time
# 0        19.038270    2173.341693  2263.469776
# 1        96.249718     707.928417   803.638126
# 2        70.656266    5234.750504  5392.588225

# %%
#save best model
#trained on= gr_set1

u_model.save('../models/RNN_rr_set3_5e.h5')

#### CONTINUE TRAINING ####
#model = load_model('beam_model.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
######################### BATCH TESTING ########################################

n_batches = 1
#d = 8

t0 = time.time()
for iteration in range(n_batches):

    df_D = pd.read_csv('../training_batches/rrD' + str(iteration+1) + '.csv')
    df_F = pd.read_csv('../training_batches/rrF' + str(iteration+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/rrDt' + str(iteration+1) + '.csv')

    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    #if i == 0:
    #    model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    pred_train_all = model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]
    
    pred_test_all = model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]
    
    pred_ind_all = independent_predictions(x_test)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]
    
    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    training_error = get_error(pred_train, y_train[:,0:n_nodes])
    test_error = get_error(pred_test, y_test[:,0:n_nodes])
    ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])
    
    plt.figure(figsize=(16,10))
    #plt.plot(pred_test[:,n_nodes-1], 'x')
    plt.plot(pred_ind[:,n_nodes-1])
    plt.plot(y_test[:, n_nodes-1])
    plt.show()

    
    total_time = time.time() - t0
    
    info = {'Iteration number': iteration+1, 'Training Error': training_error, 'Test Error': test_error, 'Ind test error': ind_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Training Error': 1.7276860353577641, 'Test Error': 0.29846556877570002, 'Ind test error': 18.855915684260651, 'Training time': 0.0, 'Total time': 34.77224016189575}

# %%
#Export results
np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
pred_ind_all = independent_predictions(x_train)
pred_ind = pred_ind_all[:, 0:n_nodes]

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
plt.plot(pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.show()

# %%
DF.shape
# Out:
# (4995, 205)

# %%
df_D.values.shape
# Out:
# (5000, 21)

# %%
plt.plot(y_test_u[50,:])
