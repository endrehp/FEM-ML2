# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import random
import math
import time

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils import np_utils
from keras.optimizers import SGD
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
#%matplotlib notebook

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

from numpy.linalg import inv
from numpy import linalg as LA
from scipy import linalg
import random

from matplotlib import animation, rc
from IPython.display import HTML

# %%
def prepare_training_data(df_F, df_D, d):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F.shift(d-i).values, df_D.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values, df_D.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = df_D.values
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def train_test_split(DF, Dy, d, x_scaler, y_scaler):

    dim = np.shape(Dy)

    n_nodes = dim[1]
    x = np.linspace(0,1, n_nodes)

    #Scaling
    DFscaled = x_scaler.transform(DF)
    Dyscaled = y_scaler.transform(Dy)

    X_train = DFscaled
    Y_train = Dyscaled

    #Train test split
    train_portion = 0.8
    n_timesteps = len(X_train[:,0])
    x_train = X_train[0:int(n_timesteps*train_portion),:]
    x_test = X_train[int(n_timesteps*(train_portion)):,:]
    y_train = Y_train[0:int(n_timesteps*train_portion),:]
    y_test = Y_train[int(n_timesteps*(train_portion)):,:]

    n_features = int(x_train.shape[1]/d)
    x_train = x_train.reshape((x_train.shape[0], d, n_features))
    x_test = x_test.reshape((x_test.shape[0], d, n_features))

    return x_train, x_test, y_train, y_test, n_nodes, n_features, x

# %%
def initialize_model(n_units, x_train, y_train):
    model = Sequential()
    model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]),))
    model.add(Dense(len(y_train[0,:])))
    adam = Adam(lr=0.0001)
    model.compile(loss='mae', optimizer=adam)
    
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=5, verbose=1, mode='auto')
    callback_list = [earlystop]
    return model, callback_list

# %%
def get_error(predictions, y_test):
    error = 0
    for i in range(len(predictions[:,0])):
        error += np.trapz((y_test[i,:] - predictions[i,:])**2, x)
    return error

# %%
def independent_predictions(x_test):

    input_i = np.copy(x_test[0,:,:])
    input_i_reshaped = input_i.reshape((1,d,n_features))

    #input_dim = x_test[0,:,:].shape

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_nodes])

    force = np.copy(x_test[:,:,:(n_nodes)])
    #model.reset_states()
    for i in range(future_timesteps): 
        pred = model.predict(input_i_reshaped)
        preds[i, :] = pred[0]

        input_i[0:d-1,:] = input_i[1:d,:]
        input_i[d-1,:n_nodes] = force[i+1,d-1,:]
        input_i[d-1,n_nodes:] = pred[0]

        input_i_reshaped = input_i.reshape((1,d,n_features))
        
    return preds

# %%
def get_scalers(DF, Dy):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F.shift(d-i).values, df_D.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values, df_D.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = df_D.values
    Dy = Dy[d:,:]
    
    x_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    
    x_scaler.fit_transform(DF)
    y_scaler.fit_transform(Dy)
    
    return x_scaler, y_scaler

# %%
def get_batch_scalers(n_batches):
    
    #Simple version
    for i in range(n_batches):
        
        df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(i+1) + '.csv')
        df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(i+1) + '.csv')
        
        
        if i == 0:  
            x_range = df_D.values.max() - df_D.values.min()
            imax = i
        
        else:
            new_x_range = df_D.values.max() - df_D.values.min()
            
            if new_x_range > x_range:
                x_range = new_x_range
                imax = i
                
    df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(imax+1) + '.csv')
    df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(imax+1) + '.csv')
    
    DF, Dy = prepare_training_data(df_F, df_D, d)
    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    return x_scaler, y_scaler

# %%
######################### BATCH TRAINING ########################################

n_batches = 10
d = 5

t0 = time.time()

x_scaler, y_scaler = get_batch_scalers(n_batches)

for i in range(n_batches):

    df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(i+1) + '.csv')
    df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(i+1) + '.csv')

    DF, Dy = prepare_training_data(df_F, df_D, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    if i == 0:
        model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    model.fit(x_train, y_train, epochs=100, callbacks=None, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    preds = y_scaler.inverse_transform(model.predict(x_test))
    y_test_u = y_scaler.inverse_transform(y_test)
    
    independent_preds = y_scaler.inverse_transform(independent_predictions(x_test))
    
    test_error = get_error(y_test_u, preds)
    independent_test_error = get_error(y_test_u[0:len(independent_preds[:,0]),:], independent_preds)
    
    total_time = time.time() - t0
    
    info = {'Iteration number': i+1, 'Test Error': test_error, 'Ind test error': independent_test_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Test Error': 0.0002032043484915667, 'Ind test error': 0.00032093628034558916, 'Training time': 39.7158088684082, 'Total time': 41.823463439941406}
# {'Iteration number': 2, 'Test Error': 7.5078111456368539e-08, 'Ind test error': 5.3271816275311226e-07, 'Training time': 38.550238609313965, 'Total time': 81.4365484714508}
# {'Iteration number': 3, 'Test Error': 1.2343700643515565e-05, 'Ind test error': 0.00013927575022238501, 'Training time': 40.556612730026245, 'Total time': 123.51423406600952}
# {'Iteration number': 4, 'Test Error': 2.6104502274779825e-08, 'Ind test error': 1.246541861944645e-05, 'Training time': 43.17261719703674, 'Total time': 167.81687808036804}
# {'Iteration number': 5, 'Test Error': 6.2775569613707604e-07, 'Ind test error': 6.0807836624584012e-05, 'Training time': 38.25344443321228, 'Total time': 207.12514734268188}
# {'Iteration number': 6, 'Test Error': 1.528828294787258e-05, 'Ind test error': 0.00016914473728355504, 'Training time': 40.79424858093262, 'Total time': 249.07448863983154}
# {'Iteration number': 7, 'Test Error': 1.2101888080750845e-07, 'Ind test error': 3.9574303888306992e-05, 'Training time': 38.713675022125244, 'Total time': 288.8470015525818}
# {'Iteration number': 8, 'Test Error': 1.1369002829121229e-08, 'Ind test error': 2.5464248488154287e-05, 'Training time': 38.4589958190918, 'Total time': 328.38388228416443}
# {'Iteration number': 9, 'Test Error': 1.4528512662990553e-09, 'Ind test error': 2.4593147189964484e-05, 'Training time': 38.639281272888184, 'Total time': 368.37076568603516}
# {'Iteration number': 10, 'Test Error': 1.8135221957278028e-08, 'Ind test error': 3.3648779946905162e-07, 'Training time': 38.87587809562683, 'Total time': 408.4368095397949}

# %%
######################### BATCH TESTING ########################################

n_batches = 10
d = 5

t0 = time.time()
for i in range(n_batches):

    df_D = pd.read_csv('C:/Users/endrep/Documents/training_batches/D' + str(i+1) + '.csv')
    df_F = pd.read_csv('C:/Users/endrep/Documents/training_batches/F' + str(i+1) + '.csv')


    DF, Dy = prepare_training_data(df_F, df_D, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    #if i == 0:
    #    model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    preds = y_scaler.inverse_transform(model.predict(x_test))
    y_test_u = y_scaler.inverse_transform(y_test)
    
    independent_preds = independent_predictions(x_test)
    independent_preds_u = y_scaler.inverse_transform(independent_preds)
    
    plt.figure(figsize=(8,5))
    plt.plot(independent_preds_u[:,-1])
    plt.plot(preds[:,-1], 'x')
    plt.plot(y_test_u[:,-1])
    plt.show()
    
    test_error = get_error(y_test_u, preds)
    independent_test_error = get_error(y_test[0:len(independent_preds[:,0]),:], independent_preds)
    
    total_time = time.time() - t0
    
    info = {'Iteration number': i+1, 'Test Error': test_error, 'Ind test error': independent_test_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Test Error': 0.00011736600901973795, 'Ind test error': 25786.089778681151, 'Training time': 0.0, 'Total time': 1.0618741512298584}
# {'Iteration number': 2, 'Test Error': 6.2498460393916903e-08, 'Ind test error': 1656.3052340206839, 'Training time': 0.0, 'Total time': 2.150747299194336}
# {'Iteration number': 3, 'Test Error': 1.4798152422324387e-05, 'Ind test error': 6381.6230985578159, 'Training time': 0.0, 'Total time': 3.4241490364074707}
# {'Iteration number': 4, 'Test Error': 1.116388549107043e-06, 'Ind test error': 571.17255323243137, 'Training time': 0.0, 'Total time': 4.48197603225708}
# {'Iteration number': 5, 'Test Error': 6.4868025008841019e-07, 'Ind test error': 1987.8821900060441, 'Training time': 0.0, 'Total time': 5.536805868148804}
# {'Iteration number': 6, 'Test Error': 1.8018693814485979e-05, 'Ind test error': 8677.9788510843828, 'Training time': 0.0, 'Total time': 6.730983734130859}
# {'Iteration number': 7, 'Test Error': 9.9274714674066632e-07, 'Ind test error': 2482.1031993040442, 'Training time': 0.0, 'Total time': 8.360342025756836}
# {'Iteration number': 8, 'Test Error': 1.4628891111962534e-07, 'Ind test error': 1678.1436157496121, 'Training time': 0.0, 'Total time': 9.78413987159729}
# {'Iteration number': 9, 'Test Error': 4.4263964336482383e-08, 'Ind test error': 1709.4983521086344, 'Training time': 0.0, 'Total time': 11.334315299987793}
# {'Iteration number': 10, 'Test Error': 1.8135221957278028e-08, 'Ind test error': 24.650546962384958, 'Training time': 0.0, 'Total time': 12.437227964401245}

# %%
#Export results
np.savetxt("predictions.csv", independent_preds_u, delimiter=",")
np.savetxt("preds.csv", preds, delimiter=",")
np.savetxt("y_test.csv", y_test_u, delimiter=",")
np.savetxt("y_train.csv", y_test_u, delimiter=",")

# %%
independent_preds_u.shape
# Out:
# (998, 21)

# %%
DF.shape
# Out:
# (4995, 205)

# %%
df_D.values.shape
# Out:
# (5000, 21)
