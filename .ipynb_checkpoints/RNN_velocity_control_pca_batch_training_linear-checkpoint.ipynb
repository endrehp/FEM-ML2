# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
import math
import time

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.utils import np_utils
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping, History, Callback, ReduceLROnPlateau, ModelCheckpoint

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
def prepare_training_data(df_F, df_D, df_Dt, d):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = np.concatenate((df_D.values, df_Dt.values), axis=1)
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def train_test_split(DF, Dy, d, x_scaler, y_scaler):

    dim = np.shape(Dy)

    n_nodes = int(dim[1]/2)
    n_y = dim[1]
    x = np.linspace(0,1, n_nodes)

    #Scaling
    DFscaled = x_scaler.transform(DF)
    Dyscaled = y_scaler.transform(Dy)

    X_train = DFscaled
    Y_train = Dyscaled

    #Train test split
    train_portion = 0.8
    n_timesteps = len(X_train[:,0])
    x_train = X_train[0:int(n_timesteps*train_portion),:]
    x_test = X_train[int(n_timesteps*(train_portion)):,:]
    y_train = Y_train[0:int(n_timesteps*train_portion),:]
    y_test = Y_train[int(n_timesteps*(train_portion)):,:]

    n_features = int(x_train.shape[1]/d)
    
    #Reshape training data into 3D array as required by the LSTM layer
    #Input shape is: (n_timesteps, d, n_features)
    x_train = x_train.reshape((x_train.shape[0], d, n_features))
    x_test = x_test.reshape((x_test.shape[0], d, n_features))

    return x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x

# %%
def initialize_model(n_units, x_train, y_train, lr, n_layers):
    model = Sequential()
    
    #Add hidden layers, return_sequences=True if next layer is LSTM, False otherwise
    if n_layers == 1:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=False))
        
    elif n_layers == 2:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        model.add(LSTM(n_units))
    else: 
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        for layer in range(n_layers-1):
            model.add(LSTM(n_units, return_sequences = True))
        model.add(LSTM(n_units))
    
    
    #model.add(Dropout(0.1))
    
    model.add(Dense(len(y_train[0,:]))) #Output Layer
    adam = Adam(lr=lr)
    model.compile(loss='mae', optimizer=adam)
    
    #Define callbacks
    history = History()
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
    callback_list = [earlystop, history]
    return model, callback_list

# %%
def get_error(predictions, y_test):
    #Squared error is integrated numerically in space for each timestep and summed
    error = 0
    for i in range(len(predictions[:,0])):
        error += np.trapz((y_test[i,:] - predictions[i,:])**2, x)
    return error

# %%
def independent_predictions(x_test, my_model):

    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known
    for i in range(future_timesteps): 
        pred = my_model.predict(input_i_reshaped) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        input_i[d-1,:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
        input_i[d-1,n_nodes:] = pred[0] #Fill in values that we just predicted

        input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
        
    return preds

# %%
def independent_batch(x_batch):

    input_i = np.copy(x_batch[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_batch[:,0,0])

    force = np.copy(x_batch[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known
    
    ind_batch = np.zeros([future_timesteps, d, n_features])
    ind_batch[0] = input_i_reshaped[0]
    
    for i in range(future_timesteps): 
        pred = model.predict(input_i_reshaped) #Predict next timestep
        
        if i < future_timesteps - 1:
            input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
            input_i[d-1,:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
            input_i[d-1,n_nodes:] = pred[0] #Fill in values that we just predicted

            input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
            ind_batch[i+1] = input_i_reshaped[0]
        
    return ind_batch

# %%
def get_scalers(DF, Dy):
    
    x_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    
    x_scaler.fit_transform(DF)
    y_scaler.fit_transform(Dy)
    
    return x_scaler, y_scaler

# %%
def get_batch_scalers(n_batches, training_set):
    
    #Simple version
    for i in range(n_batches):
        
        df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(i+1) + '.csv')
        df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(i+1) + '.csv')
        df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(i+1) + '.csv')
        
        if i == 0:  
            x_range = df_D.values.max() - df_D.values.min()
            imax = i
        
        else:
            new_x_range = df_D.values.max() - df_D.values.min()
            
            if new_x_range > x_range:
                x_range = new_x_range
                imax = i
                
    df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(imax+1) + '.csv')
    df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(imax+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(imax+1) + '.csv')
    
    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    return x_scaler, y_scaler

# %%
#columns = ['training set', 'n_layers', 'height', 'epochs', 'batch size', 'learning rate', 'early stopping', 'stop loss', 'Training Error', 'Test Error',
#           'Ind test error', 'Ind train error', 'Training time', 'Total time']
#df = pd.DataFrame(columns = columns)

#df.to_csv('../results/RNN_velocity_results.csv')

# %%
def get_batch(x_train, y_train, batch_size):
    
    start = random.randint(0,len(x_train)-batch_size)
    
    x_batch = x_train[start:start+batch_size]
    y_batch = y_train[start:start+batch_size]
    
    return x_batch, y_batch

# %%
class Ind_pred(Callback):
    
    def on_epoch_end(self, epoch, logs={}):
        
        error = 0
        if epoch > 400 or epoch%20 == 0:
            input_i = np.copy(x_test[0,:,:]) #Initial conditions
            #input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

            future_timesteps = len(x_test[:,0,0])-1
            preds = np.zeros([future_timesteps, n_y])

            force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known

            new_step = np.zeros(len(x_test[0,0,:]))
            input_shape = input_i.shape

            for i in range(future_timesteps): 

                input_i_pca = pca.transform(input_i.reshape([input_shape[0], input_shape[1]]))

                pred = self.model.predict(input_i_pca.reshape([1,d,n_features])) #Predict next timestep
                preds[i, :] = pred[0] 

                input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
                new_step[0] = force[i+1,d-1] #Fill in force for next timestep
                new_step[1:] = pred[0] #Fill in values that we just predicted


                input_i[d-1,:] = new_step.reshape([1,len(new_step)])


            error = 0
            for i in range(len(preds[:,0])):
                error += np.trapz((y_test[i,:n_nodes] - preds[i,:n_nodes])**2, x)

        info = {'ind error': error}
        u_ind_errors.append(error)

        logs['ind_error'] = error

        print(info)
    
    #def on_batch_end(self, batch, logs={}):
    #    print(batch)

# %%
def independent_predictions_pca(x_test, my_model):        
    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    #input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known

    new_step = np.zeros(len(x_test[0,0,:]))
    input_shape = input_i.shape

    for i in range(future_timesteps): 

        input_i_pca = pca.transform(input_i.reshape([input_shape[0], input_shape[1]]))

        pred = my_model.predict(input_i_pca.reshape([1,d,n_features])) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        new_step[0] = force[i+1,d-1] #Fill in force for next timestep
        new_step[1:] = pred[0] #Fill in values that we just predicted


        input_i[d-1,:] = new_step.reshape([1,len(new_step)])
        
    return preds

# %%
#Select training set
training_set = 'lin1'
iteration = 0
d = 10

#Import training data
df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(iteration) + '.csv')
df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(iteration) + '.csv')
df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(iteration) + '.csv')

#Prepare training data
DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)

#Get global scalers
x_scaler, y_scaler = get_scalers(DF, Dy)

#Split into train and test set
x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF[:,:], Dy[:,:], d, x_scaler, y_scaler)

# %%
#X = x_train[:,0,:]
#df = pd.DataFrame(X)

#correlation = df.corr()
#plt.figure(figsize=(20,20))
#sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

#plt.title('Correlation between different fearures')

# %%
####Method 1####
train_shape = x_train.shape
test_shape = x_test.shape

# %%
x_train2 = x_train.reshape([train_shape[0]*train_shape[1],train_shape[2]])
x_test2 = x_test.reshape([test_shape[0]*test_shape[1],test_shape[2]])

# %%
pca = PCA(n_components=8)
pca.fit(x_train2)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0,0.5,'Cumulative explained variance')

# %%
NCOMPONENTS = 3

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(x_train2)
X_pca_test = pca.transform(x_test2)
pca_std = np.std(X_pca_train)

print(x_train2.shape)
print(X_pca_train.shape)
# Out:
# (799910, 21)
# (799910, 3)

# %%
sh1 = X_pca_train.shape
sh2 = X_pca_test.shape
x_train_pca = X_pca_train.reshape([int(sh1[0]/d),d,sh1[1]])
x_test_pca = X_pca_test.reshape([int(sh2[0]/d),d,sh2[1]])

# %%
######################### BATCH TRAINING ########################################

n_batches = 1
d = 10

#Hyperparameter settings
epochs = 500
layers = 1
height = 50
batch_size = 1000
lr = 0.001
u_errors_matrix = []
c_errors_matrix =[]

# %%
n_features = sh1[1]

# %%
############## Model.fit #####################
t0 = time.time()
f_model = Sequential()
#u_model.add(LSTM(height, input_shape=(sh1[1], n_features), return_sequences=True))
#u_model.add(LSTM(height, return_sequences=False))
f_model.add(LSTM(height, input_shape=(d, n_features), return_sequences=False))
#model.add(Dropout(0.1))
f_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
f_model.compile(loss='mae', optimizer=adam)

u_ind_errors = []
#Define callbacks
ind_pred = Ind_pred()
history = History()
earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=30, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=12, min_lr=0.0001, mode='min', verbose=1)
model_cp = ModelCheckpoint('../results/f_model_checkpoint.h5', monitor='ind_error', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)
hist = f_model.fit(x_train_pca, y_train, epochs=epochs, callbacks=[ind_pred, history, reduce_lr], batch_size=batch_size, 
                   verbose=1, shuffle=False)

#hist = f_model.fit(x_train_pca, y_train, epochs=epochs, callbacks=[reduce_lr], batch_size=batch_size, 
#                   verbose=1, shuffle=False)

print({'total time': time.time()-t0})
# Out:
# Epoch 1/500
# 79991/79991 [==============================] - 5s 63us/step - loss: 0.2290
# {'ind error': 1095.7462047590873}
# Epoch 2/500
# 79991/79991 [==============================] - 5s 58us/step - loss: 0.0119
# {'ind error': 0}
# Epoch 3/500
# 79991/79991 [==============================] - 5s 57us/step - loss: 0.0074
# {'ind error': 0}
# Epoch 4/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0065
# {'ind error': 0}
# Epoch 5/500
# 79991/79991 [==============================] - 5s 57us/step - loss: 0.0064
# {'ind error': 0}
# Epoch 6/500
# 79991/79991 [==============================] - 5s 57us/step - loss: 0.0060
# {'ind error': 0}
# Epoch 7/500
# 79991/79991 [==============================] - 5s 57us/step - loss: 0.0058
# {'ind error': 0}
# Epoch 8/500
# 79991/79991 [==============================] - 5s 60us/step - loss: 0.0058
# {'ind error': 0}
# Epoch 9/500
# 79991/79991 [==============================] - 5s 61us/step - loss: 0.0053
# {'ind error': 0}
# Epoch 10/500
# 79991/79991 [==============================] - 5s 63us/step - loss: 0.0056
# {'ind error': 0}
# Epoch 11/500
# 79991/79991 [==============================] - 4s 56us/step - loss: 0.0054
# {'ind error': 0}
# Epoch 12/500
# 79991/79991 [==============================] - 5s 58us/step - loss: 0.0056
# {'ind error': 0}
# Epoch 13/500
# 79991/79991 [==============================] - 5s 66us/step - loss: 0.0054
# {'ind error': 0}
# Epoch 14/500
# 79991/79991 [==============================] - 6s 70us/step - loss: 0.0056
# {'ind error': 0}
# Epoch 15/500
# 79991/79991 [==============================] - 5s 59us/step - loss: 0.0053
# {'ind error': 0}
# Epoch 16/500
# 79991/79991 [==============================] - 7s 91us/step - loss: 0.0054
# {'ind error': 0}
# Epoch 17/500
# 79991/79991 [==============================] - 8s 99us/step - loss: 0.0052
# {'ind error': 0}
# Epoch 18/500
# 79991/79991 [==============================] - 7s 83us/step - loss: 0.0050
# {'ind error': 0}
# Epoch 19/500
# 79991/79991 [==============================] - 5s 66us/step - loss: 0.0051
# {'ind error': 0}
# Epoch 20/500
# 79991/79991 [==============================] - 6s 80us/step - loss: 0.0048
# {'ind error': 0}
# Epoch 21/500
# 79991/79991 [==============================] - 5s 57us/step - loss: 0.0056
# {'ind error': 1130.4543355465937}
# Epoch 22/500
# 79991/79991 [==============================] - 5s 60us/step - loss: 0.0052
# {'ind error': 0}
# Epoch 23/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0052
# {'ind error': 0}
# Epoch 24/500
# 79991/79991 [==============================] - 5s 56us/step - loss: 0.0050
# {'ind error': 0}
# Epoch 25/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0053
# {'ind error': 0}
# Epoch 26/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0056: 1s
# {'ind error': 0}
# Epoch 27/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0050
# {'ind error': 0}
# Epoch 28/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0046
# {'ind error': 0}
# Epoch 29/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0048
# {'ind error': 0}
# Epoch 30/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0048
# {'ind error': 0}
# Epoch 31/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0059
# {'ind error': 0}
# Epoch 32/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0051
# {'ind error': 0}
# Epoch 33/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0048
# {'ind error': 0}
# Epoch 34/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0046
# {'ind error': 0}
# Epoch 35/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0048
# {'ind error': 0}
# Epoch 36/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0048
# {'ind error': 0}
# Epoch 37/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0050
# {'ind error': 0}
# Epoch 38/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0046
# {'ind error': 0}
# Epoch 39/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0046
# {'ind error': 0}
# Epoch 40/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0048
# {'ind error': 0}
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 41/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0040
# {'ind error': 1522.8276384615115}
# Epoch 42/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 43/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 44/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 45/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 46/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 47/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 48/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 49/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 50/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 51/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 52/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0039
# {'ind error': 0}
# Epoch 53/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0039
# {'ind error': 0}
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 54/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 55/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 56/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 57/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 58/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 59/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 60/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 61/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 433.03786492660345}
# Epoch 62/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 63/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 64/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 65/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 66/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 67/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 68/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 69/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 70/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 71/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 72/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 73/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 74/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 75/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 76/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 77/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 78/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 79/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 80/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 81/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0038
# {'ind error': 986.29447575445295}
# Epoch 82/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 83/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 84/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 85/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 86/500
# 79991/79991 [==============================] - 4s 56us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 87/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 88/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 89/500
# 79991/79991 [==============================] - 5s 57us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 90/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 91/500
# 79991/79991 [==============================] - 5s 57us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 92/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 93/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 94/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 95/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 96/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 97/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 98/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 99/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 100/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0038
# {'ind error': 0}
# Epoch 101/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 1080.6365876571738}
# Epoch 102/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 103/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 104/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 105/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 106/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 107/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 108/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 109/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 110/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 111/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 112/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 113/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 114/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 115/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 116/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 117/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 118/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 119/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 120/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 121/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 749.86880847885357}
# Epoch 122/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 123/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 124/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 125/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 126/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 127/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 128/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 129/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 130/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 131/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 132/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 133/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 134/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 135/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 136/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 137/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 138/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 139/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 140/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 141/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 593.67372294955146}
# Epoch 142/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 143/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 144/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 145/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 146/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 147/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 148/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 149/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 150/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 151/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 152/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 153/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 154/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 155/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 156/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 157/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 158/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 159/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 160/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0037: 0s - los
# {'ind error': 0}
# Epoch 161/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 886.78616489888532}
# Epoch 162/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 163/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 164/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 165/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 166/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 167/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0037
# {'ind error': 0}
# Epoch 168/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 169/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 170/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 171/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 172/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 173/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 174/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 175/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0036: 2s
# {'ind error': 0}
# Epoch 176/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 177/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 178/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 179/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 180/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 181/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 543.22745289813679}
# Epoch 182/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 183/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 184/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 185/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 186/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 187/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 188/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 189/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 190/500
# 79991/79991 [==============================] - 4s 51us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 191/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 192/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 193/500
# 79991/79991 [==============================] - 4s 50us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 194/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 195/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 196/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 197/500
# 79991/79991 [==============================] - 4s 52us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 198/500
# 79991/79991 [==============================] - 4s 53us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 199/500
# 79991/79991 [==============================] - 4s 55us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 200/500
# 79991/79991 [==============================] - 4s 54us/step - loss: 0.0036
# {'ind error': 0}
# Epoch 201/500
# 72000/79991 [==========================>...] - ETA: 0s - loss: 0.0036
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-110-bfdb7f8c264a> in <module>()
#      18 model_cp = ModelCheckpoint('../results/f_model_checkpoint.h5', monitor='ind_error', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)
#      19 hist = f_model.fit(x_train_pca, y_train, epochs=epochs, callbacks=[ind_pred, history, reduce_lr], batch_size=batch_size,
# ---> 20                    verbose=1, shuffle=False)
#      21
#      22 #hist = f_model.fit(x_train_pca, y_train, epochs=epochs, callbacks=[reduce_lr], batch_size=batch_size,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
############## train_on_batch #####################
t0 = time.time()
bt_model = Sequential()
#u_model.add(LSTM(height, input_shape=(sh1[1], n_features), return_sequences=True))
#u_model.add(LSTM(height, return_sequences=False))
bt_model.add(LSTM(height, batch_input_shape=(None, d, n_features), return_sequences=False))
#model.add(Dropout(0.1))
bt_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
bt_model.compile(loss='mae', optimizer=adam)
#Define callbacks
ind_pred = Ind_pred()
history = History()
earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=15, min_lr=0.0001, mode='min', verbose=1)
model_cp = ModelCheckpoint('../results/model_checkpoint.h5', monitor='ind_error', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)
#hist = u_model.fit(x_train_pca, y_train, epochs=epochs, callbacks=[ind_pred, history, earlystop, reduce_lr, model_cp], batch_size=batch_size, 
#                   verbose=1, shuffle=False)

bt_ind_errors = []

training_sets = 1
batch_iterations = int(len(x_train)/batch_size)
lowest = 1
since_lowest = 0
patience = 15
losses = np.zeros(batch_iterations)
for tr_set in range(training_sets):
    for epoch in range(epochs):
        for bi in range(batch_iterations):
            x_train_pca_batch, y_train_batch = get_batch(x_train_pca, y_train, batch_size)
            hist = bt_model.train_on_batch(x_train_pca_batch, y_train_batch)
            
            losses[bi] = hist
            
        
        avg_loss = losses.mean()
        
        if epoch > 200:
            bt_pred_ind_all = independent_predictions_pca(x_test, bt_model)
            bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
            bt_ind_error = get_error(bt_pred_ind, y_test[0:len(bt_pred_ind[:,0]),0:n_nodes])

            bt_ind_errors.append(bt_ind_error)
        elif epoch%10 == 0:
            bt_pred_ind_all = independent_predictions_pca(x_test, bt_model)
            bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
            bt_ind_error = get_error(bt_pred_ind, y_test[0:len(bt_pred_ind[:,0]),0:n_nodes])

            bt_ind_errors.append(bt_ind_error)
        else:
            bt_ind_error = 0

        if avg_loss < lowest:
            lowest = avg_loss
            reduce = 'no'
            since_lowest = 0
        else: 
            if since_lowest == patience:
                
                if lr >= 0.00005:
                    lr *= 0.2
                    K.set_value(bt_model.optimizer.lr, lr)
                    reduce = 'yes'
                    since_lowest = 0
                elif lr > 0.00001:
                    K.set_value(bt_model.optimizer.lr, 0.00001)
                    lr = 0.00001
                    reduce = 'yes'
                    since_lowest = 0
            else:
                since_lowest += 1
                reduce = 'no' 
        
        info = {'epoch':epoch, 'loss': avg_loss, 'lr': lr, 'reduce': reduce, 'since_lowest': since_lowest}
        print(info)
        print({'ind_error': bt_ind_error})
        
        
#earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
#callback_list = [earlystop, history]
print({'total time': time.time()-t0})
# Out:
# {'epoch': 0, 'loss': 0.47562563160191412, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 1009.6545870570226}
# {'epoch': 1, 'loss': 0.25518077547135559, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 2, 'loss': 0.068310423551694213, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 3, 'loss': 0.039071296544178673, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 4, 'loss': 0.024408425973809284, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 5, 'loss': 0.017687788800052975, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 6, 'loss': 0.015189908444881439, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 7, 'loss': 0.014418680180350075, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 8, 'loss': 0.013175156817811987, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 9, 'loss': 0.013190944922035154, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 10, 'loss': 0.012740902157257433, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 90.379817548856025}
# {'epoch': 11, 'loss': 0.011387312946760136, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 12, 'loss': 0.012205596770281378, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 13, 'loss': 0.011421921784463137, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 14, 'loss': 0.011397382608898308, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 15, 'loss': 0.01075628185239823, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 16, 'loss': 0.0098562000886253682, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 17, 'loss': 0.010767027735710144, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 18, 'loss': 0.0096086673438549042, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 19, 'loss': 0.0095105321429993801, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 20, 'loss': 0.0089234248127626342, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 23.361425172531689}
# {'epoch': 21, 'loss': 0.0093725062906742096, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 22, 'loss': 0.0093302780802807083, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 23, 'loss': 0.0089720216701212139, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 24, 'loss': 0.0093355892307084541, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 25, 'loss': 0.0081601775575267238, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 26, 'loss': 0.0083925723017233868, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 27, 'loss': 0.0086662998099042016, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 28, 'loss': 0.008812828050197466, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 29, 'loss': 0.0084531943556731166, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 30, 'loss': 0.0088251360044207267, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 51.502660135121921}
# {'epoch': 31, 'loss': 0.0082288698455237827, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 6}
# {'ind_error': 0}
# {'epoch': 32, 'loss': 0.0086919444046266708, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 7}
# {'ind_error': 0}
# {'epoch': 33, 'loss': 0.0079871001855834674, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 34, 'loss': 0.0079645695488737983, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 35, 'loss': 0.0073496884180475836, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 36, 'loss': 0.0070583355086653128, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 37, 'loss': 0.0082772168452325077, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 38, 'loss': 0.0086800661747870236, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 39, 'loss': 0.0078521091895906829, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 40, 'loss': 0.0082193120666172199, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 86.667006667991089}
# {'epoch': 41, 'loss': 0.0070617502028851404, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 42, 'loss': 0.0069235278819890127, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 43, 'loss': 0.0068767615189046965, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 44, 'loss': 0.0069118065597570458, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 45, 'loss': 0.0067860004492104053, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 46, 'loss': 0.0066704447583659839, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 47, 'loss': 0.0069327245101980543, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 48, 'loss': 0.0071429970228801603, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 49, 'loss': 0.006756116737328146, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 50, 'loss': 0.0064748467715538063, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 18.811295712983899}
# {'epoch': 51, 'loss': 0.007399091395832922, 'lr': 0.001, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch':
 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 186, 'loss': 0.0022777910647994799, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 6}
# {'ind_error': 0}
# {'epoch': 187, 'loss': 0.0022254744747086711, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 7}
# {'ind_error': 0}
# {'epoch': 188, 'loss': 0.0022439669827809153, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 8}
# {'ind_error': 0}
# {'epoch': 189, 'loss': 0.0021855181346283011, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 9}
# {'ind_error': 0}
# {'epoch': 190, 'loss': 0.0022096844724096036, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 10}
# {'ind_error': 10.102733033839719}
# {'epoch': 191, 'loss': 0.0022196877778143339, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 11}
# {'ind_error': 0}
# {'epoch': 192, 'loss': 0.0022078819987971497, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 12}
# {'ind_error': 0}
# {'epoch': 193, 'loss': 0.0022531153340621486, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 13}
# {'ind_error': 0}
# {'epoch': 194, 'loss': 0.0022317389198376432, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 14}
# {'ind_error': 0}
# {'epoch': 195, 'loss': 0.0020975586350845256, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 196, 'loss': 0.0020795285691628637, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 197, 'loss': 0.0022491897284255729, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 198, 'loss': 0.0022091446343161488, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 199, 'loss': 0.0021462939456915078, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 200, 'loss': 0.0021692304669514947, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 6.3921968575533112}
# {'epoch': 201, 'loss': 0.0021697227671013579, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 8.174066430280801}
# {'epoch': 202, 'loss': 0.0021192723399271135, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 6}
# {'ind_error': 7.0307307462384347}
# {'epoch': 203, 'loss': 0.0021822766410996733, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 7}
# {'ind_error': 8.9075248562251268}
# {'epoch': 204, 'loss': 0.002217181244581614, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 8}
# {'ind_error': 9.5703490687496373}
# {'epoch': 205, 'loss': 0.0022583947182916427, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 9}
# {'ind_error': 14.019770120620846}
# {'epoch': 206, 'loss': 0.0021755432092544179, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 10}
# {'ind_error': 11.400808933605195}
# {'epoch': 207, 'loss': 0.0021426314285591893, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 11}
# {'ind_error': 11.153224011795396}
# {'epoch': 208, 'loss': 0.0022073026048019528, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 12}
# {'ind_error': 8.6254661311518301}
# {'epoch': 209, 'loss': 0.0022198209873117184, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 13}
# {'ind_error': 8.9917663190956372}
# {'epoch': 210, 'loss': 0.0021443202048945036, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 14}
# {'ind_error': 9.6024100462032358}
# {'epoch': 211, 'loss': 0.0022212028017510538, 'lr': 0.0002, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.0550011314925349}
# {'epoch': 212, 'loss': 0.0022041853061755714, 'lr': 4e-05, 'reduce': 'yes', 'since_lowest': 0}
# {'ind_error': 8.208332384182528}
# {'epoch': 213, 'loss': 0.0020794360949050474, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 7.2017452806444737}
# {'epoch': 214, 'loss': 0.0020274018929542408, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 9.1469199464693816}
# {'epoch': 215, 'loss': 0.0020735698559766879, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 7.8074587510249875}
# {'epoch': 216, 'loss': 0.0021285148408344908, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 8.4360309903903179}
# {'epoch': 217, 'loss': 0.0021155600223447318, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 9.99444647710731}
# {'epoch': 218, 'loss': 0.0020929546824291997, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 7.0909685912855318}
# {'epoch': 219, 'loss': 0.0021020891853486714, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 8.2101110485121698}
# {'epoch': 220, 'loss': 0.002062847518928997, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 6}
# {'ind_error': 7.4206707846522564}
# {'epoch': 221, 'loss': 0.0021083917235955596, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 7}
# {'ind_error': 6.9785321745238145}
# {'epoch': 222, 'loss': 0.0020533566990786271, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 8}
# {'ind_error': 8.6212322916461659}
# {'epoch': 223, 'loss': 0.0019929870436696901, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 10.194965605837899}
# {'epoch': 224, 'loss': 0.0020840665902537498, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 8.5662068006714041}
# {'epoch': 225, 'loss': 0.0021793819994301252, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 8.9713917388616302}
# {'epoch': 226, 'loss': 0.0019980330202404571, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 9.5002609763042631}
# {'epoch': 227, 'loss': 0.0020465119944318481, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 8.9001283916749951}
# {'epoch': 228, 'loss': 0.002123233654698276, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 7.8205528707425227}
# {'epoch': 229, 'loss': 0.0020736375793247767, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 6}
# {'ind_error': 10.143628866484269}
# {'epoch': 230, 'loss': 0.0021182130465445957, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 7}
# {'ind_error': 7.0173433618347492}
# {'epoch': 231, 'loss': 0.0020473738828592973, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 8}
# {'ind_error': 7.3893260424866956}
# {'epoch': 232, 'loss': 0.0021163145859685283, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 9}
# {'ind_error': 10.838404727629523}
# {'epoch': 233, 'loss': 0.0021069894301826539, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 10}
# {'ind_error': 8.1453259198967523}
# {'epoch': 234, 'loss': 0.0021395334903069811, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 11}
# {'ind_error': 8.3450142447851938}
# {'epoch': 235, 'loss': 0.0020367719141928396, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 12}
# {'ind_error': 9.3394192710656547}
# {'epoch': 236, 'loss': 0.0021568499859827366, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 13}
# {'ind_error': 6.6430474366649221}
# {'epoch': 237, 'loss': 0.0020674923991622486, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 14}
# {'ind_error': 7.7094260499054128}
# {'epoch': 238, 'loss': 0.0020871282828485837, 'lr': 4e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.5956883593068403}
# {'epoch': 239, 'loss': 0.0020167672672592426, 'lr': 1e-05, 'reduce': 'yes', 'since_lowest': 0}
# {'ind_error': 11.894105751067892}
# {'epoch': 240, 'loss': 0.0020707879752001686, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 8.9674314959643286}
# {'epoch': 241, 'loss': 0.0020774937558757224, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 7.9385228260986853}
# {'epoch': 242, 'loss': 0.001998799377242508, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 9.8545784937401812}
# {'epoch': 243, 'loss': 0.0021393595506315646, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 7.3001461498687892}
# {'epoch': 244, 'loss': 0.0021072609765131188, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 8.321812167232606}
# {'epoch': 245, 'loss': 0.0021714824757984152, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 6}
# {'ind_error': 8.9691726503575939}
# {'epoch': 246, 'loss': 0.0021014697849750519, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 7}
# {'ind_error': 8.2365132253032094}
# {'epoch': 247, 'loss': 0.0021652889529081144, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 8}
# {'ind_error': 7.700061167397501}
# {'epoch': 248, 'loss': 0.0020212650946948838, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 9}
# {'ind_error': 9.7890750390726797}
# {'epoch': 249, 'loss': 0.0021732061514225993, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 10}
# {'ind_error': 9.1900829834773283}
# {'epoch': 250, 'loss': 0.0020671937432464051, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 11}
# {'ind_error': 7.9799745106098836}
# {'epoch': 251, 'loss': 0.0021399491385597248, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 12}
# {'ind_error': 8.4285353820695263}
# {'epoch': 252, 'loss': 0.0021706359845626612, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 13}
# {'ind_error': 7.9305888167193341}
# {'epoch': 253, 'loss': 0.002023140282329658, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 14}
# {'ind_error': 9.4725739857688538}
# {'epoch': 254, 'loss': 0.002073055123100462, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.3982168870620111}
# {'epoch': 255, 'loss': 0.0020265718314634719, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.7665444528026946}
# {'epoch': 256, 'loss': 0.0021140825195723901, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.7900204852021666}
# {'epoch': 257, 'loss': 0.0021724021922715979, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.3647873261200232}
# {'epoch': 258, 'loss': 0.0020995777373647561, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.2630722776290728}
# {'epoch': 259, 'loss': 0.001990105511377687, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 8.7231233119116123}
# {'epoch': 260, 'loss': 0.0020385174303437057, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 8.6721539009342692}
# {'epoch': 261, 'loss': 0.0020321715451048121, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 8.3409991282474962}
# {'epoch': 262, 'loss': 0.0020902823130397692, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 7.6539917245606244}
# {'epoch': 263, 'loss': 0.0020795708886631155, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 9.8486349684740784}
# {'epoch': 264, 'loss': 0.0021675107545097885, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 7.191803423250299}
# {'epoch': 265, 'loss': 0.0021721805729295897, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 6}
# {'ind_error': 7.6588157017119745}
# {'epoch': 266, 'loss': 0.0021076599621902342, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 7}
# {'ind_error': 8.438583129426064}
# {'epoch': 267, 'loss': 0.0021360930328702798, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 8}
# {'ind_error': 7.6742780220121887}
# {'epoch': 268, 'loss': 0.0021602876696978574, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 9}
# {'ind_error': 7.5596445628611137}
# {'epoch': 269, 'loss': 0.0021278209852702594, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 10}
# {'ind_error': 7.1610039874521947}
# {'epoch': 270, 'loss': 0.0021797176298644881, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 11}
# {'ind_error': 7.1923078166649574}
# {'epoch': 271, 'loss': 0.0020003782980063038, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 12}
# {'ind_error': 8.5255974033980504}
# {'epoch': 272, 'loss': 0.0020637370838338265, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 13}
# {'ind_error': 8.766563672382734}
# {'epoch': 273, 'loss': 0.002140375213576076, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 14}
# {'ind_error': 8.3184303396660475}
# {'epoch': 274, 'loss': 0.0021123104809742908, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.2097596766224683}
# {'epoch': 275, 'loss': 0.0021048902898378992, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.7640243660488828}
# {'epoch': 276, 'loss': 0.0020011990310867195, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.6472905058016334}
# {'epoch': 277, 'loss': 0.0021534932665931788, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.9739096829537885}
# {'epoch': 278, 'loss': 0.0020417475607246161, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.3223990209143368}
# {'epoch': 279, 'loss': 0.0021500228398034105, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.3616817866182007}
# {'epoch': 280, 'loss': 0.0020829223389939771, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.779396579201193}
# {'epoch': 281, 'loss': 0.0020787836882569218, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.5659020735113938}
# {'epoch': 282, 'loss': 0.0020199087245956712, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.9203232726113661}
# {'epoch': 283, 'loss': 0.002079950205212378, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.9498453688016149}
# {'epoch': 284, 'loss': 0.0020479484228417277, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.8202840908490039}
# {'epoch': 285, 'loss': 0.0021052416869560661, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.0379618550558032}
# {'epoch': 286, 'loss': 0.0020747575959514666, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.0139650368148985}
# {'epoch': 287, 'loss': 0.0021216512718440399, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 7.5375322904917308}
# {'epoch': 288, 'loss': 0.0020487661392468472, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.3619586786352329}
# {'epoch': 289, 'loss': 0.0019959302507745829, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 15}
# {'ind_error': 8.574392673509287}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-190-f1799eb6bd37> in <module>()
#      38
#      39         if epoch > 200:
# ---> 40             bt_pred_ind_all = independent_predictions_pca(x_test, bt_model)
#      41             bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
#      42             bt_ind_error = get_error(bt_pred_ind, y_test[0:len(bt_pred_ind[:,0]),0:n_nodes])
#
# <ipython-input-188-8687153c29d2> in independent_predictions_pca(x_test, my_model)
#      15         input_i_pca = pca.transform(input_i.reshape([input_shape[0], input_shape[1]]))
#      16
# ---> 17         pred = my_model.predict(input_i_pca.reshape([1,d,n_features])) #Predict next timestep
#      18         preds[i, :] = pred[0]
#      19
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\models.py in predict(self, x, batch_size, verbose, steps)
#    1062             self.build()
#    1063         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1064                                   steps=steps)
#    1065
#    1066     def predict_on_batch(self, x):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1833         f = self.predict_function
#    1834         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1835                                   verbose=verbose, steps=steps)
#    1836
#    1837     def train_on_batch(self, x, y,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1329                     ins_batch[i] = ins_batch[i].toarray()
#    1330
# -> 1331                 batch_outs = f(ins_batch)
#    1332                 if not isinstance(batch_outs, list):
#    1333                     batch_outs = [batch_outs]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
plt.plot(bt_ind_errors)

# %%
K.get_value(bt_model.optimizer.lr)
# Out:
# 0.001

# %%
f_pred_ind_all = independent_predictions_pca(x_train, f_model)
#bt_pred_ind_all = independent_predictions_pca(x_test, bt_model)

# %%
f_pred_ind = f_pred_ind_all[:, 0:n_nodes]
#f_ind_error = get_error(f_pred_ind, y_test[0:len(f_pred_ind[:,0]),0:n_nodes])
#print(f_ind_error)

# %%
#bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
#bt_ind_error = get_error(bt_pred_ind, y_test[0:len(bt_pred_ind[:,0]),0:n_nodes])
#print(bt_ind_error)

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.plot(f_pred_ind[:,n_nodes-1])
plt.show()

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])
#plt.plot(f_pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.show()

# %%
#save best model
#trained on= rr_set1

#u_model.save('../models/pca_RNN_gr_set1.h5')

#### CONTINUE TRAINING ####
#model = load_model('../models/RNN_gr_set1.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
def generate_export(my_model):
    pred_train_all = my_model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]

    pred_test_all = my_model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]

    pred_ind_all = independent_predictions(x_test, my_model)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]

    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    #Export results
    np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
    np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
    np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
    np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
generate_export(u_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-c444d0737e2c> in <module>()
# ----> 1 generate_export(u_model)
#
# <ipython-input-136-50e79082a532> in generate_export(my_model)
#       1 def generate_export(my_model):
# ----> 2     pred_train_all = my_model.predict(x_train)
#       3     pred_train = pred_train_all[:, 0:n_nodes]
#       4     pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/keras/models.py in predict(self, x, batch_size, verbose, steps)
#    1023             self.build()
#    1024         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1025                                   steps=steps)
#    1026
#    1027     def predict_on_batch(self, x):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1815         x = _standardize_input_data(x, self._feed_input_names,
#    1816                                     self._feed_input_shapes,
# -> 1817                                     check_batch_axis=False)
#    1818         if self.stateful:
#    1819             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     121                             ': expected ' + names[i] + ' to have shape ' +
#     122                             str(shape) + ' but got array with shape ' +
# --> 123                             str(data_shape))
#     124     return data
#     125
#
# ValueError: Error when checking : expected lstm_18_input to have shape (4, 1) but got array with shape (10, 60)

# %%
y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
f_pred_ind_u = y_scaler.inverse_transform(f_pred_ind_all)[:, 0:n_nodes]

# %%
#Export results
#np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", f_pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
#np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
# one layer, height 500, gives lowest error around 9, but this is while its heavily overfitting
# one layer, height 100, on gr_set1 goes down to about 6 at epoch 40, then starts overfitting
# same, but with height 200 starts oscillating around batch 20, then the ind error is around 9. 
# With dropout 0.1 the results are bad


#df = df.drop(columns=df.columns[0])
#df.to_csv('../results/RNN_velocity_results.csv')

# %%
#pd.read_csv('../results/RNN_velocity_results.csv', index_col=0)
# Out:
#   training set  n_layers  height  epochs  batch size  learning rate  \
# 0           rr         2     100     500        1000         0.0005
# 1           rr         2     100     500        1000         0.0001
# 2           rr         3      50     500        1000         0.0005
#
#    early stopping  stop loss  Training Error  Test Error  Ind test error  \
# 0             115   0.005931        0.428430    0.102271        4.126604
# 1              36   0.005536        0.457434    0.111018       18.604378
# 2             160   0.013542        0.497549    0.108562       11.480535
#
#    Ind train error  Training time   Total time
# 0        19.038270    2173.341693  2263.469776
# 1        96.249718     707.928417   803.638126
# 2        70.656266    5234.750504  5392.588225

# %%
#save best model
#trained on= gr_set1

u_model.save('../models/RNN_rr_set3_5e.h5')

#### CONTINUE TRAINING ####
#model = load_model('beam_model.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
######################### BATCH TESTING ########################################

n_batches = 1
#d = 8

t0 = time.time()
for iteration in range(n_batches):

    df_D = pd.read_csv('../training_batches/rrD' + str(iteration+1) + '.csv')
    df_F = pd.read_csv('../training_batches/rrF' + str(iteration+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/rrDt' + str(iteration+1) + '.csv')

    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    #if i == 0:
    #    model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    pred_train_all = model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]
    
    pred_test_all = model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]
    
    pred_ind_all = independent_predictions(x_test)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]
    
    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    training_error = get_error(pred_train, y_train[:,0:n_nodes])
    test_error = get_error(pred_test, y_test[:,0:n_nodes])
    ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])
    
    plt.figure(figsize=(16,10))
    #plt.plot(pred_test[:,n_nodes-1], 'x')
    plt.plot(pred_ind[:,n_nodes-1])
    plt.plot(y_test[:, n_nodes-1])
    plt.show()

    
    total_time = time.time() - t0
    
    info = {'Iteration number': iteration+1, 'Training Error': training_error, 'Test Error': test_error, 'Ind test error': ind_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Training Error': 1.7276860353577641, 'Test Error': 0.29846556877570002, 'Ind test error': 18.855915684260651, 'Training time': 0.0, 'Total time': 34.77224016189575}

# %%
#Export results
np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
pred_ind_all = independent_predictions(x_train)
pred_ind = pred_ind_all[:, 0:n_nodes]

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
plt.plot(pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.show()

# %%
DF.shape
# Out:
# (4995, 205)

# %%
df_D.values.shape
# Out:
# (5000, 21)

# %%
plt.plot(y_test_u[50,:])
