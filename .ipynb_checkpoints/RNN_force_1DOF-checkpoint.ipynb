# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
import math
import time

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.utils import np_utils
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping, History, Callback, ReduceLROnPlateau, ModelCheckpoint

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
def prepare_training_data(df_F, df_D, df_Dt, d):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = np.concatenate((df_D.values, df_Dt.values), axis=1)
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def train_test_split(DF, Dy, d, x_scaler, y_scaler, train_portion, set_length, n_sets):

    dim = np.shape(Dy)

    n_nodes = int(dim[1]/2)
    n_y = dim[1]
    x = np.linspace(0,1, n_nodes)

    #Scaling
    DFscaled = x_scaler.transform(DF)
    Dyscaled = y_scaler.transform(Dy)

    #X_train = DFscaled
    #Y_train = Dyscaled

    #Train test split
    #train_portion = 0.8
    n_features = int(DF.shape[1]/d)
    #n_timesteps = len(X_train[:,0])
    
    L = int(set_length*train_portion)
    U = int(set_length*(1-train_portion))
    
    x_train = np.zeros([n_sets*L, n_features*d])
    y_train = np.zeros([n_sets*L, n_y])
    
    x_test = np.zeros([n_sets, U, d, n_features])
    y_test = np.zeros([n_sets, U, n_y])
    
    for set_i in range(n_sets):
        X_i = DFscaled[set_length*set_i:set_length*(set_i+1),:]
        Y_i = Dyscaled[set_length*set_i:set_length*(set_i+1),:]
        x_train[L*set_i:L*(set_i+1),:] = X_i[0:L,:]
        y_train[L*set_i:L*(set_i+1),:] = Y_i[0:L,:]
        
        x_test_m = X_i[L:-1,:]
        y_test_m = Y_i[L:-1,:]
        
        x_test[set_i] = x_test_m.reshape((U, d, n_features))
        y_test[set_i] = y_test_m

    
    #Reshape training data into 3D array as required by the LSTM layer
    #Input shape is: (n_timesteps, d, n_features)
    x_train = x_train.reshape((x_train.shape[0], d, n_features))
    #x_test = x_test.reshape((x_test.shape[0], d, n_features))

    return x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x

# %%
def initialize_model(n_units, x_train, y_train, lr, n_layers):
    model = Sequential()
    
    #Add hidden layers, return_sequences=True if next layer is LSTM, False otherwise
    if n_layers == 1:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=False))
        
    elif n_layers == 2:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        model.add(LSTM(n_units))
    else: 
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        for layer in range(n_layers-1):
            model.add(LSTM(n_units, return_sequences = True))
        model.add(LSTM(n_units))
    
    
    #model.add(Dropout(0.1))
    
    model.add(Dense(len(y_train[0,:]))) #Output Layer
    adam = Adam(lr=lr)
    model.compile(loss='mae', optimizer=adam)
    
    #Define callbacks
    history = History()
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
    callback_list = [earlystop, history]
    return model, callback_list

# %%
def get_error(predictions, ytest):
    #Squared error is integrated numerically in space for each timestep and summed
    error = 0
    for i in range(len(predictions)):
        error += (ytest[i] - predictions[i])**2
    return error

# %%
def independent_predictions(x_test, my_model):

    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known
    for i in range(future_timesteps): 
        pred = my_model.predict(input_i_reshaped) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        input_i[d-1,0] = force[i+1,d-1] #Fill in force for next timestep
        input_i[d-1,1:] = pred[0] #Fill in values that we just predicted

        input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
        
    return preds

# %%
def get_scalers(DF, Dy):
    
    x_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    
    x_scaler.fit_transform(DF)
    y_scaler.fit_transform(Dy)
    
    return x_scaler, y_scaler

# %%
def get_batch(x_train, y_train, batch_size, set_length, n_sets):
    
    set_number = randint(0, n_sets)
    start = random.randint(0,set_length-batch_size)*set_number*set_length
    
    x_batch = x_train[start:start+batch_size]
    y_batch = y_train[start:start+batch_size]
    
    return x_batch, y_batch

# %%
class Ind_pred(Callback):
    
    def on_epoch_end(self, epoch, logs={}):
        
        error = 0
        if epoch > 400 or epoch%10 == 0:
            input_i = np.copy(x_test[0,:,:]) #Initial conditions
            input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

            future_timesteps = len(x_test[:,0,0])-1
            preds = np.zeros([future_timesteps, n_y])

            force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known
            for i in range(future_timesteps): 
                pred = self.model.predict(input_i_reshaped) #Predict next timestep
                preds[i, :] = pred[0] 

                input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
                input_i[d-1,0] = force[i+1,d-1] #Fill in force for next timestep
                input_i[d-1,1:] = pred[0] #Fill in values that we just predicted

                input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer


            for i in range(len(preds[:,0])):
                error += (y_test[i,0] - preds[i,0])**2

        info = {'ind error': error}
        #u_ind_errors.append(error)

        logs['ind_error'] = error

        print(info)
    
    #def on_batch_end(self, batch, logs={}):
    #    print(batch)

# %%
def independent_predictions_pca(x_test, my_model):        
    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    #input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known

    new_step = np.zeros(len(x_test[0,0,:]))
    input_shape = input_i.shape

    for i in range(future_timesteps): 

        pred = my_model.predict(input_i.reshape([1,d,n_features])) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        new_step[0] = force[i+1,d-1] #Fill in force for next timestep
        new_step[1:] = pred[0] #Fill in values that we just predicted


        input_i[d-1,:] = new_step.reshape([1,len(new_step)])
        
    return preds

# %%
#################### MASS IMPORT #############################

#X_train = np.zeros([95,34200,d,n_features]) 
#DF_total = np.zeros()
training_set = 'mass_production_1dof'
d = 10
train_portion = 0.95
n = 4
s = 36000-d-1
DF_total = np.zeros([s*n, 30])
Dy_total = np.zeros([s*n, 2])

for i in range(n):

    iteration = i #5*i+5

    #Import training data
    df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(iteration) + '.csv')
    df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(iteration) + '.csv')
    df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(iteration) + '.csv')

    #Prepare training data
    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    DF_total[i*s:s*(i+1),:] = DF
    Dy_total[i*s:s*(i+1),:] = Dy

# %%
# Get scalers
x_scaler, y_scaler = get_scalers(DF_total, Dy_total)

# %%
#Split into train and test set
x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF_total, Dy_total, d, x_scaler, y_scaler, train_portion, s, n)

# %%
set_length = int(x_train.shape[0]/n)
test_set_length = int(x_test.shape[0]/n)

# %%
x_test.shape
# Out:
# (4, 1799, 10, 3)

# %%
######################### BATCH TRAINING ########################################

n_batches = 1
#d = 10

#Hyperparameter settings
epochs = 100
layers = 1
height = 50
batch_size = 1000
lr = 0.01
u_errors_matrix = []
c_errors_matrix =[]

# %%
############## train_on_batch #####################
t0 = time.time()
bt_model = Sequential()
#u_model.add(LSTM(height, input_shape=(sh1[1], n_features), return_sequences=True))
#u_model.add(LSTM(height, return_sequences=False))
bt_model.add(LSTM(height, input_shape=(d, n_features), return_sequences=False))
#bt_model.add(LSTM(height, return_sequences=False))
#model.add(Dropout(0.1))
bt_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
bt_model.compile(loss='mae', optimizer=adam)
#Define callbacks
ind_pred = Ind_pred()
history = History()
earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=5, min_lr=0.0001, mode='min', verbose=1)
model_cp = ModelCheckpoint('../results/model_checkpoint.h5', monitor='ind_error', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)

#hist = bt_model.fit(x_train, y_train, epochs=epochs, callbacks=[ind_pred, history, reduce_lr], batch_size=batch_size,
#                    verbose=1, shuffle=False)

#bt_ind_errors = []

# %%
batch_size = 1000
n_sets = 4
batch_iterations = int(set_length/batch_size)*n_sets
lowest = 1
since_lowest = 0
patience = 5
losses = np.zeros(batch_iterations)
for tr_set in range(1):
    for epoch in range(epochs):
        for bi in range(batch_iterations):
            
            set_number = random.randint(0, n_sets-1)
            start = set_number*set_length + random.randint(0,set_length-batch_size)

            x_batch = x_train[start:start+batch_size]
            y_batch = y_train[start:start+batch_size]
            hist = bt_model.train_on_batch(x_batch, y_batch)
            
            losses[bi] = hist
            
        
        avg_loss = losses.mean()
        
        if epoch > 200:
            bt_pred_ind_all = independent_predictions(x_test, bt_model)
            bt_pred_ind = bt_pred_ind_all[:, 0]
            bt_ind_error = get_error(bt_pred_ind, y_test_r[0:len(bt_pred_ind),0])

            bt_ind_errors.append(bt_ind_error)
        elif epoch%10 == 0:
            
            test_set_number = random.randint(0, n_sets-1)
            #start = set_number*set_length
            x_test_r = x_test[test_set_number]
            y_test_r = y_test[test_set_number]
            
            bt_pred_ind_all = independent_predictions(x_test_r, bt_model)
            bt_pred_ind = bt_pred_ind_all[:, 0]
            bt_ind_error = get_error(bt_pred_ind, y_test_r[0:len(bt_pred_ind),0])

            bt_ind_errors.append(bt_ind_error)
        else:
            bt_ind_error = 0

        if avg_loss < lowest:
            lowest = avg_loss
            reduce = 'no'
            since_lowest = 0
        else: 
            if since_lowest == patience:
                
                if lr >= 0.0001:
                    lr *= 0.2
                    K.set_value(bt_model.optimizer.lr, lr)
                    reduce = 'yes'
                    since_lowest = 0
                elif lr > 0.00001:
                    K.set_value(bt_model.optimizer.lr, 0.00001)
                    lr = 0.00001
                    reduce = 'yes'
                    since_lowest = 0
            else:
                since_lowest += 1
                reduce = 'no' 
        
        info = {'epoch':epoch, 'loss': avg_loss, 'lr': lr, 'reduce': reduce, 'since_lowest': since_lowest}
        print(info)
        print({'ind_error': bt_ind_error})
        
        
#earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
#callback_list = [earlystop, history]
print({'total time': time.time()-t0})
# Out:
# {'epoch': 0, 'loss': 0.047977931414018661, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 239.5289531476609}
# {'epoch': 1, 'loss': 0.016714907148579025, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 2, 'loss': 0.015262001063948608, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 3, 'loss': 0.013803278886959614, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 4, 'loss': 0.015428472423295984, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 5, 'loss': 0.012275348051095052, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 6, 'loss': 0.011902497951215243, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 7, 'loss': 0.012067288446226431, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 8, 'loss': 0.0088934743047609701, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 9, 'loss': 0.0097628791837076484, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 10, 'loss': 0.009317392046796158, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 27.519295523877926}
# {'epoch': 11, 'loss': 0.008428851027822341, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 12, 'loss': 0.0075418921957915537, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 13, 'loss': 0.0078354766626623183, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 14, 'loss': 0.007701329030918286, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 15, 'loss': 0.0080802971257499471, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 16, 'loss': 0.0077341363939922303, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 17, 'loss': 0.0063512385001077368, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 18, 'loss': 0.0066985561844536707, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 19, 'loss': 0.0060333558032973945, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 20, 'loss': 0.0059337648973964595, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 42.265610603731695}
# {'epoch': 21, 'loss': 0.0063074531893054136, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 22, 'loss': 0.0065244774467667892, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 23, 'loss': 0.0051287717857014603, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 24, 'loss': 0.0063996801019290134, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 25, 'loss': 0.0051244370029855735, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 26, 'loss': 0.0048509518845308132, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 27, 'loss': 0.0053094131923417612, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 28, 'loss': 0.0060953473054242372, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 29, 'loss': 0.0050966408213271811, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 30, 'loss': 0.0044869976203806483, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 128.56654341606173}
# {'epoch': 31, 'loss': 0.0050095726448275589, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 32, 'loss': 0.0053778721630806103, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 33, 'loss': 0.0047950841304983064, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 34, 'loss': 0.004588877343956162, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 35, 'loss': 0.0045540002234595112, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 36, 'loss': 0.0043474044659353025, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 37, 'loss': 0.0048581359399523698, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 38, 'loss': 0.0054446676050942831, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 39, 'loss': 0.0044977222603526622, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 40, 'loss': 0.0042156607275554798, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 71.253204954007799}
# {'epoch': 41, 'loss': 0.0035722442210980635, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 42, 'loss': 0.0049907292542390198, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 43, 'loss': 0.0039835713610313281, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 44, 'loss': 0.0046432884880820945, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 45, 'loss': 0.0041916216595221639, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 46, 'loss': 0.0042669443911804326, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 47, 'loss': 0.0050095011555480167, 'lr': 0.002, 'reduce': 'yes', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 48, 'loss': 0.0016994192898410426, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 49, 'loss': 0.0015578238333760323, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 50, 'loss': 0.0015854292501257185, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 3972.3756106661626}
# {'epoch': 51, 'loss': 0.0015923870669212192, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 52, 'loss': 0.0015284564852824107, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 53, 'loss': 0.0013764547458028093, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 54, 'loss': 0.0018829151299809489, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 55, 'loss': 0.0020511151823858894, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 56, 'loss': 0.001697795841798378, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 57, 'loss': 0.0016297667718711583, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 58, 'loss': 0.0014874976828543689, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 59, 'loss': 0.0015923255469876014, 'lr': 0.0004, 'reduce': 'yes', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 60, 'loss': 0.0010830555068370065, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 20.087655982992487}
# {'epoch': 61, 'loss': 0.00098781571796280332, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 62, 'loss': 0.00094824293645454896, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 63, 'loss': 0.0010016231878099086, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 64, 'loss': 0.00094943089789012447, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 65, 'loss': 0.00097266995918984963, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 66, 'loss': 0.0009265780461325502, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 67, 'loss': 0.00089768378208699524, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 68, 'loss': 0.00092815036965903882, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 69, 'loss': 0.00088638132322504297, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 70, 'loss': 0.00084019489826031904, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 9524.7436850835347}
# {'epoch': 71, 'loss': 0.00084274203554206696, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 72, 'loss': 0.00091665848038460622, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 73, 'loss': 0.00089330786645672666, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 74, 'loss': 0.00085797948807286211, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 75, 'loss': 0.00087022333665278415, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 76, 'loss': 0.00079165411465082262, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 77, 'loss': 0.00087643098103238595, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 78, 'loss': 0.00088304102374583157, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 79, 'loss': 0.0008278997505412382, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 80, 'loss': 0.00086809550917036282, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 7462.7107675813968}
# {'epoch': 81, 'loss': 0.00080420259302413529, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 82, 'loss': 0.00086437379992703963, 'lr': 8e-05, 'reduce': 'yes', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 83, 'loss': 0.0007243404654539464, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 84, 'loss': 0.00073654962034197524, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 85, 'loss': 0.0007281790627423427, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 86, 'loss': 0.00070037388115237905, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 87, 'loss': 0.00073599700194523288, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 88, 'loss': 0.00067896852402447947, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 89, 'loss': 0.00069911036060897028, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 90, 'loss': 0.00068348013027228741, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 10.868319670917193}
# {'epoch': 91, 'loss': 0.00068941661939949403, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 92, 'loss': 0.00075169415932203475, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 93, 'loss': 0.00072983430543578892, 'lr': 8e-05, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 94, 'loss': 0.00072399931506130519, 'lr': 1e-05, 'reduce': 'yes', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 95, 'loss': 0.00070660327657927097, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 96, 'loss': 0.00067455688922029157, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 97, 'loss': 0.00066034494311144744, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 98, 'loss': 0.00067426455087329755, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 99, 'loss': 0.0007067289980648853, 'lr': 1e-05, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'total time': 1111.059776544571}

# %%
#Total ind_error

total_error = 0
#n_sets = 4
errors = []
for j in range(n_sets):

    x_test_r = x_test[j]
    y_test_r = y_test[j]

    bt_pred_ind_all = independent_predictions(x_test_r, bt_model)
    bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
    bt_ind_error = get_error(bt_pred_ind, y_test_r[0:len(bt_pred_ind[:,0]),0:n_nodes])
    total_error += bt_ind_error[0]
    errors.append(bt_ind_error[0])

print(errors)
print(total_error)
# Out:
# [15.245893772226164, 9.0601496293540453, 1805.5503472879313, 8883.8915596298011]
# 10713.7479503

# %%
j = 2
x_test_r = x_test[j]
y_test_r = y_test[j]

bt_pred_ind_all = independent_predictions(x_test_r, bt_model)
bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
bt_ind_error = get_error(bt_pred_ind, y_test_r[0:len(bt_pred_ind[:,0]),0:n_nodes])

# %%
#bt_ind_error = get_error(bt_pred_ind, y_test[0:len(f_pred_ind[:,0]),0:n_nodes])
print(bt_ind_error)
# Out:
# [ 1805.55034729]

# %%
#bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
#bt_ind_error = get_error(bt_pred_ind, y_test[0:len(bt_pred_ind[:,0]),0:n_nodes])
#print(bt_ind_error)

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])

plt.plot(y_test_r[0:500, n_nodes-1])
plt.plot(bt_pred_ind[0:500,n_nodes-1])

plt.show()

# %%
start
# Out:
# 51283

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])
#plt.plot(f_pred_ind[:,n_nodes-1])
plt.plot(x_train[32000:40000,-1, 1])
plt.show()

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])
#plt.plot(f_pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.show()

# %%
##################### UNSEEN DATA ###################

#Select training set
training_set = 'unseen1'
iteration = 0
#d = 10
train_portion = 0.95

#Import training data
df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(iteration) + '.csv')
df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(iteration) + '.csv')
df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(iteration) + '.csv')

#Prepare training data
DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)

#Get global scalers
#x_scaler, y_scaler = get_scalers(DF, Dy)

#Split into train and test set
x_unseen_train, x_unseen_test, y_unseen_train, y_unseen_test, n_nodes, n_features, n_y, x = train_test_split(DF[:,:], Dy[:,:], d, x_scaler, y_scaler, train_portion)
n_features = sh1[1]

# %%
f_pred_ind_all = independent_predictions_pca(x_unseen_test, f_model)
f_pred_ind = f_pred_ind_all[:, 0:n_nodes]

# %%
f_ind_error = get_error(f_pred_ind, y_unseen_test[0:len(f_pred_ind[:,0]),0:n_nodes])
print(f_ind_error)
# Out:
# 461.575430303

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])

plt.plot(y_unseen_test[:1000, n_nodes-1])
plt.plot(f_pred_ind[:1000,n_nodes-1])

plt.show()

# %%
f_model.predict(pca.transform(x_unseen_test[0,:,:]).reshape([1,d,n_features]))
# Out:
# array([[ 0.41883656,  0.41931304,  0.41766015,  0.41867629,  0.42105049,
#          0.42189106,  0.4251999 ,  0.44010538,  0.45728752,  0.46517229,
#          0.53769237,  0.53808057,  0.53931403,  0.5402357 ,  0.54199147,
#          0.54450291,  0.54377806,  0.56265378,  0.52699947,  0.50802404]], dtype=float32)

# %%
len(f_model.get_weights())
# Out:
# 5

# %%
#save best model
#trained on= rr_set1

#f_model.save('../models/lin_white_noise_dt01.h5')

#### CONTINUE TRAINING ####
#f_model = keras.modelload_model('../models/RNN_gr_set1.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
def generate_export(my_model):
    pred_train_all = my_model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]

    pred_test_all = my_model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]

    pred_ind_all = independent_predictions(x_test, my_model)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]

    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    #Export results
    np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
    np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
    np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
    np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
#generate_export(u_model)

# %%
y_test_u = y_scaler.inverse_transform(y_test_r)[:, 0:n_nodes]
bt_pred_ind_u = y_scaler.inverse_transform(bt_pred_ind_all)[:, 0:n_nodes]

# %%
#Export results
#np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", bt_pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
#np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
# one layer, height 500, gives lowest error around 9, but this is while its heavily overfitting
# one layer, height 100, on gr_set1 goes down to about 6 at epoch 40, then starts overfitting
# same, but with height 200 starts oscillating around batch 20, then the ind error is around 9. 
# With dropout 0.1 the results are bad


#df = df.drop(columns=df.columns[0])
#df.to_csv('../results/RNN_velocity_results.csv')

# %%
#pd.read_csv('../results/RNN_velocity_results.csv', index_col=0)
# Out:
#   training set  n_layers  height  epochs  batch size  learning rate  \
# 0           rr         2     100     500        1000         0.0005
# 1           rr         2     100     500        1000         0.0001
# 2           rr         3      50     500        1000         0.0005
#
#    early stopping  stop loss  Training Error  Test Error  Ind test error  \
# 0             115   0.005931        0.428430    0.102271        4.126604
# 1              36   0.005536        0.457434    0.111018       18.604378
# 2             160   0.013542        0.497549    0.108562       11.480535
#
#    Ind train error  Training time   Total time
# 0        19.038270    2173.341693  2263.469776
# 1        96.249718     707.928417   803.638126
# 2        70.656266    5234.750504  5392.588225

# %%
#save best model
#trained on= gr_set1

#u_model.save('../models/RNN_rr_set3_5e.h5')

#### CONTINUE TRAINING ####
#model = load_model('beam_model.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
######################### BATCH TESTING ########################################

n_batches = 1
#d = 8

t0 = time.time()
for iteration in range(n_batches):

    df_D = pd.read_csv('../training_batches/rrD' + str(iteration+1) + '.csv')
    df_F = pd.read_csv('../training_batches/rrF' + str(iteration+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/rrDt' + str(iteration+1) + '.csv')

    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    #if i == 0:
    #    model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    pred_train_all = model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]
    
    pred_test_all = model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]
    
    pred_ind_all = independent_predictions(x_test)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]
    
    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    training_error = get_error(pred_train, y_train[:,0:n_nodes])
    test_error = get_error(pred_test, y_test[:,0:n_nodes])
    ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])
    
    plt.figure(figsize=(16,10))
    #plt.plot(pred_test[:,n_nodes-1], 'x')
    plt.plot(pred_ind[:,n_nodes-1])
    plt.plot(y_test[:, n_nodes-1])
    plt.show()

    
    total_time = time.time() - t0
    
    info = {'Iteration number': iteration+1, 'Training Error': training_error, 'Test Error': test_error, 'Ind test error': ind_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Training Error': 1.7276860353577641, 'Test Error': 0.29846556877570002, 'Ind test error': 18.855915684260651, 'Training time': 0.0, 'Total time': 34.77224016189575}

# %%
#Export results
np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
pred_ind_all = independent_predictions(x_train)
pred_ind = pred_ind_all[:, 0:n_nodes]

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
plt.plot(pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.show()

# %%
DF.shape
# Out:
# (4995, 205)

# %%
df_D.values.shape
# Out:
# (5000, 21)

# %%
plt.plot(y_test_u[50,:])
