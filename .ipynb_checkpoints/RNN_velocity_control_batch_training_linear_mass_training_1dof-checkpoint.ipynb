# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
import math
import time

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.utils import np_utils
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping, History, Callback, ReduceLROnPlateau, ModelCheckpoint
from keras.regularizers import L1L2

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from keras import backend as K

# %%
def prepare_training_data(df_F, df_D, df_Dt, d):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = np.concatenate((df_D.values, df_Dt.values), axis=1)
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def train_test_split(DF, Dy, d, x_scaler, y_scaler, train_portion, set_length, n_sets):

    dim = np.shape(Dy)

    n_nodes = int(dim[1]/2)
    n_y = dim[1]
    x = np.linspace(0,1, n_nodes)

    #Scaling
    DFscaled = x_scaler.transform(DF)
    Dyscaled = y_scaler.transform(Dy)

    #X_train = DFscaled
    #Y_train = Dyscaled

    #Train test split
    #train_portion = 0.8
    n_features = int(DF.shape[1]/d)
    #n_timesteps = len(X_train[:,0])
    
    L = int(set_length*train_portion)
    U = int(set_length*(1-train_portion))
    
    x_train = np.zeros([n_sets*L, n_features*d])
    y_train = np.zeros([n_sets*L, n_y])
    
    x_test = np.zeros([n_sets, U, d, n_features])
    y_test = np.zeros([n_sets, U, n_y])
    
    for set_i in range(n_sets):
        X_i = DFscaled[set_length*set_i:set_length*(set_i+1),:]
        Y_i = Dyscaled[set_length*set_i:set_length*(set_i+1),:]
        x_train[L*set_i:L*(set_i+1),:] = X_i[0:L,:]
        y_train[L*set_i:L*(set_i+1),:] = Y_i[0:L,:]
        
        x_test_m = X_i[L:-1,:]
        y_test_m = Y_i[L:-1,:]
        
        x_test[set_i] = x_test_m.reshape((U, d, n_features))
        y_test[set_i] = y_test_m

    
    #Reshape training data into 3D array as required by the LSTM layer
    #Input shape is: (n_timesteps, d, n_features)
    x_train = x_train.reshape((x_train.shape[0], d, n_features))
    #x_test = x_test.reshape((x_test.shape[0], d, n_features))

    return x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x

# %%
def initialize_model(n_units, x_train, y_train, lr, n_layers):
    model = Sequential()
    
    #Add hidden layers, return_sequences=True if next layer is LSTM, False otherwise
    if n_layers == 1:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=False))
        
    elif n_layers == 2:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        model.add(LSTM(n_units))
    else: 
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        for layer in range(n_layers-1):
            model.add(LSTM(n_units, return_sequences = True))
        model.add(LSTM(n_units))
    
    
    #model.add(Dropout(0.1))
    
    model.add(Dense(len(y_train[0,:]))) #Output Layer
    adam = Adam(lr=lr)
    model.compile(loss='mae', optimizer=adam)
    
    #Define callbacks
    history = History()
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
    callback_list = [earlystop, history]
    return model, callback_list

# %%
def get_error(predictions, ytest):
    #Squared error is integrated numerically in space for each timestep and summed
    error = 0
    for i in range(len(predictions)):
        error += (ytest[i] - predictions[i])**2
    return error

# %%
def independent_predictions(x_test, my_model):

    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known
    for i in range(future_timesteps): 
        pred = my_model.predict(input_i_reshaped) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        input_i[d-1,0] = force[i+1,d-1] #Fill in force for next timestep
        input_i[d-1,1:] = pred[0] #Fill in values that we just predicted

        input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
        
    return preds

# %%
def get_scalers(DF, Dy):
    
    x_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    
    x_scaler.fit_transform(DF)
    y_scaler.fit_transform(Dy)
    
    return x_scaler, y_scaler

# %%
def get_batch(x_train, y_train, batch_size, set_length, n_sets):
    
    set_number = randint(0, n_sets)
    start = random.randint(0,set_length-batch_size)*set_number*set_length
    
    x_batch = x_train[start:start+batch_size]
    y_batch = y_train[start:start+batch_size]
    
    return x_batch, y_batch

# %%
class Ind_pred(Callback):
    
    def on_epoch_end(self, epoch, logs={}):
        
        error = 0
        if epoch > 400 or epoch%10 == 0:
            
            x_test_r = x_test[0]
            y_test_r = y_test[0]
            
            input_i = np.copy(x_test_r[0,:,:]) #Initial conditions
            input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

            future_timesteps = len(x_test_r[:,0,0])-1
            preds = np.zeros([future_timesteps, n_y])

            force = np.copy(x_test_r[:,:,0]) #Loading history for future timesteps, which is known
            for i in range(future_timesteps): 
                pred = self.model.predict(input_i_reshaped) #Predict next timestep
                preds[i, :] = pred[0] 

                input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
                input_i[d-1,0] = force[i+1,d-1] #Fill in force for next timestep
                input_i[d-1,1:] = pred[0] #Fill in values that we just predicted

                input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer


            for i in range(len(preds[:,0])):
                error += (y_test_r[i,0] - preds[i,0])**2

        info = {'ind error': error}
        #u_ind_errors.append(error)

        logs['ind_error'] = error

        print(info)
    
    #def on_batch_end(self, batch, logs={}):
    #    print(batch)

# %%
def independent_predictions_pca(x_test, my_model):        
    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    #input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,0]) #Loading history for future timesteps, which is known

    new_step = np.zeros(len(x_test[0,0,:]))
    input_shape = input_i.shape

    for i in range(future_timesteps): 

        pred = my_model.predict(input_i.reshape([1,d,n_features])) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        new_step[0] = force[i+1,d-1] #Fill in force for next timestep
        new_step[1:] = pred[0] #Fill in values that we just predicted


        input_i[d-1,:] = new_step.reshape([1,len(new_step)])
        
    return preds

# %%
#################### MASS IMPORT #############################

#X_train = np.zeros([95,34200,d,n_features]) 
#DF_total = np.zeros()
training_set = 'mass_production_1dof'
d = 10
train_portion = 0.95
n = 4
s = 36000-d-1
DF_total = np.zeros([s*n, 30])
Dy_total = np.zeros([s*n, 2])

for i in range(n):

    iteration = i #5*i+5

    #Import training data
    df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(iteration) + '.csv')
    df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(iteration) + '.csv')
    df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(iteration) + '.csv')

    #Prepare training data
    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    DF_total[i*s:s*(i+1),:] = DF
    Dy_total[i*s:s*(i+1),:] = Dy

# %%
# Get scalers
x_scaler, y_scaler = get_scalers(DF_total, Dy_total)

# %%
#Split into train and test set
x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF_total, Dy_total, d, x_scaler, y_scaler, train_portion, s, n)

# %%
set_length = int(x_train.shape[0]/n)
test_set_length = int(x_test.shape[0]/n)

# %%
x_test.shape
# Out:
# (4, 1799, 10, 3)

# %%
######################### BATCH TRAINING ########################################

n_batches = 1
#d = 10

#Hyperparameter settings
epochs = 100
layers = 1
height = 50
batch_size = 1000
lr = 0.01
u_errors_matrix = []
c_errors_matrix =[]

# %%
############## train_on_batch #####################
t0 = time.time()
bt_model = Sequential()
#u_model.add(LSTM(height, input_shape=(sh1[1], n_features), return_sequences=True))
#u_model.add(LSTM(height, return_sequences=False))
bt_model.add(LSTM(height, input_shape=(d, n_features), return_sequences=False))#ernel_regularizer=L1L2(0.01, 0.01)))

#bt_model.add(LSTM(height, return_sequences=False))
#model.add(Dropout(0.1))
bt_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
bt_model.compile(loss='mae', optimizer=adam)
#Define callbacks
ind_pred = Ind_pred()
history = History()
earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=5, min_lr=0.0001, mode='min', verbose=1)
model_cp = ModelCheckpoint('../results/model_checkpoint.h5', monitor='ind_error', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)

hist = bt_model.fit(x_train, y_train, epochs=epochs, callbacks=[ind_pred, history, reduce_lr], batch_size=batch_size,
                    verbose=1, shuffle=False)

#bt_ind_errors = []
# Out:
# Epoch 1/100
# 136756/136756 [==============================] - 25s 184us/step - loss: 0.1476
# {'ind error': 32.103792935704611}
# Epoch 2/100
# 136756/136756 [==============================] - 22s 158us/step - loss: 0.0564
# {'ind error': 0}
# Epoch 3/100
# 136756/136756 [==============================] - 24s 177us/step - loss: 0.0499
# {'ind error': 0}
# Epoch 4/100
# 136756/136756 [==============================] - 23s 170us/step - loss: 0.0409
# {'ind error': 0}
# Epoch 5/100
# 136756/136756 [==============================] - 23s 165us/step - loss: 0.0408
# {'ind error': 0}
# Epoch 6/100
# 136756/136756 [==============================] - 23s 165us/step - loss: 0.0380
# {'ind error': 0}
# Epoch 7/100
# 136756/136756 [==============================] - 23s 165us/step - loss: 0.0386
# {'ind error': 0}
# Epoch 8/100
# 136756/136756 [==============================] - 23s 167us/step - loss: 0.0332
# {'ind error': 0}
# Epoch 9/100
# 136756/136756 [==============================] - 24s 174us/step - loss: 0.0341
# {'ind error': 0}
# Epoch 10/100
# 136756/136756 [==============================] - 23s 166us/step - loss: 0.0305
# {'ind error': 0}
# Epoch 11/100
# 136756/136756 [==============================] - 23s 168us/step - loss: 0.0293
# {'ind error': 166.28323097860957}
# Epoch 12/100
# 136756/136756 [==============================] - 23s 168us/step - loss: 0.0283
# {'ind error': 0}
# Epoch 13/100
# 136756/136756 [==============================] - 23s 166us/step - loss: 0.0295
# {'ind error': 0}
# Epoch 14/100
# 136756/136756 [==============================] - 23s 168us/step - loss: 0.0279
# {'ind error': 0}
# Epoch 15/100
# 136756/136756 [==============================] - 23s 166us/step - loss: 0.0281
# {'ind error': 0}
# Epoch 16/100
# 136756/136756 [==============================] - 23s 168us/step - loss: 0.0281
# {'ind error': 0}
# Epoch 17/100
# 136756/136756 [==============================] - 23s 166us/step - loss: 0.0256
# {'ind error': 0}
# Epoch 18/100
# 136756/136756 [==============================] - 23s 172us/step - loss: 0.0252
# {'ind error': 0}
# Epoch 19/100
# 136756/136756 [==============================] - 25s 185us/step - loss: 0.0266
# {'ind error': 0}
# Epoch 20/100
# 136756/136756 [==============================] - 25s 180us/step - loss: 0.0259
# {'ind error': 0}
# Epoch 21/100
# 136756/136756 [==============================] - 21s 154us/step - loss: 0.0261
# {'ind error': 218.90585585493557}
# Epoch 22/100
# 136756/136756 [==============================] - 22s 162us/step - loss: 0.0254
# {'ind error': 0}
# Epoch 23/100
# 136756/136756 [==============================] - 25s 184us/step - loss: 0.0253
# {'ind error': 0}
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 24/100
# 136756/136756 [==============================] - 22s 160us/step - loss: 0.0174
# {'ind error': 0}
# Epoch 25/100
# 136756/136756 [==============================] - 19s 139us/step - loss: 0.0151
# {'ind error': 0}
# Epoch 26/100
# 136756/136756 [==============================] - 24s 173us/step - loss: 0.0140
# {'ind error': 0}
# Epoch 27/100
# 136756/136756 [==============================] - 20s 144us/step - loss: 0.0133
# {'ind error': 0}
# Epoch 28/100
# 136756/136756 [==============================] - 22s 163us/step - loss: 0.0132
# {'ind error': 0}
# Epoch 29/100
# 136756/136756 [==============================] - 23s 170us/step - loss: 0.0129
# {'ind error': 0}
# Epoch 30/100
# 136756/136756 [==============================] - 18s 132us/step - loss: 0.0125
# {'ind error': 0}
# Epoch 31/100
# 136756/136756 [==============================] - 17s 127us/step - loss: 0.0122
# {'ind error': 283.64032594756168}
# Epoch 32/100
# 136756/136756 [==============================] - 20s 145us/step - loss: 0.0120
# {'ind error': 0}
# Epoch 33/100
# 136756/136756 [==============================] - 20s 144us/step - loss: 0.0119
# {'ind error': 0}
# Epoch 34/100
# 136756/136756 [==============================] - 19s 141us/step - loss: 0.0120
# {'ind error': 0}
# Epoch 35/100
#  84000/136756 [=================>............] - ETA: 8s - loss: 0.0129
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-487-e87de4922844> in <module>()
#      18
#      19 hist = bt_model.fit(x_train, y_train, epochs=epochs, callbacks=[ind_pred, history, reduce_lr], batch_size=batch_size,
# ---> 20                     verbose=1, shuffle=False)
#      21
#      22 #bt_ind_errors = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
batch_size = 1000
n_sets = 4
batch_iterations = int(set_length/batch_size)*n_sets
lowest = 1
since_lowest = 0
patience = 5
losses = np.zeros(batch_iterations)
for tr_set in range(1):
    for epoch in range(epochs):
        for bi in range(batch_iterations):
            
            set_number = random.randint(0, n_sets-1)
            start = set_number*set_length + random.randint(0,set_length-batch_size)

            x_batch = x_train[start:start+batch_size]
            y_batch = y_train[start:start+batch_size]
            hist = bt_model.train_on_batch(x_batch, y_batch)
            
            losses[bi] = hist
            
        
        avg_loss = losses.mean()
        
        if epoch > 200:
            bt_pred_ind_all = independent_predictions(x_test, bt_model)
            bt_pred_ind = bt_pred_ind_all[:, 0]
            bt_ind_error = get_error(bt_pred_ind, y_test_r[0:len(bt_pred_ind),0])

            bt_ind_errors.append(bt_ind_error)
        elif epoch%10 == 0:
            
            test_set_number = random.randint(0, n_sets-1)
            #start = set_number*set_length
            x_test_r = x_test[test_set_number]
            y_test_r = y_test[test_set_number]
            
            bt_pred_ind_all = independent_predictions(x_test_r, bt_model)
            bt_pred_ind = bt_pred_ind_all[:, 0]
            bt_ind_error = get_error(bt_pred_ind, y_test_r[0:len(bt_pred_ind),0])

            bt_ind_errors.append(bt_ind_error)
        else:
            bt_ind_error = 0

        if avg_loss < lowest:
            lowest = avg_loss
            reduce = 'no'
            since_lowest = 0
        else: 
            if since_lowest == patience:
                
                if lr >= 0.0001:
                    lr *= 0.2
                    K.set_value(bt_model.optimizer.lr, lr)
                    reduce = 'yes'
                    since_lowest = 0
                elif lr > 0.00001:
                    K.set_value(bt_model.optimizer.lr, 0.00001)
                    lr = 0.00001
                    reduce = 'yes'
                    since_lowest = 0
            else:
                since_lowest += 1
                reduce = 'no' 
        
        info = {'epoch':epoch, 'loss': avg_loss, 'lr': lr, 'reduce': reduce, 'since_lowest': since_lowest}
        print(info)
        print({'ind_error': bt_ind_error})
        
        
#earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
#callback_list = [earlystop, history]
print({'total time': time.time()-t0})
# Out:
# {'epoch': 0, 'loss': 3.4499406713773224, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 28.399213268140798}
# {'epoch': 1, 'loss': 0.045374014948987788, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 2, 'loss': 0.038164062548757476, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 3, 'loss': 0.040259595960378647, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 4, 'loss': 0.038035986232845223, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 5, 'loss': 0.03844406009268235, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 6, 'loss': 0.037399089908884728, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 7, 'loss': 0.03823848667225855, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 8, 'loss': 0.039424670093199783, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 9, 'loss': 0.036222999134813159, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 10, 'loss': 0.034855503095861745, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 233.02801962600876}
# {'epoch': 11, 'loss': 0.034579361186308021, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 12, 'loss': 0.034304807825452262, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 13, 'loss': 0.034039444673587292, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 14, 'loss': 0.034351895768743229, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 15, 'loss': 0.0335900800247841, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 16, 'loss': 0.032623584628762567, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 17, 'loss': 0.034030687420026344, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 18, 'loss': 0.032900111640200895, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 19, 'loss': 0.032546775073141736, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 20, 'loss': 0.034413432223064935, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 61.827761727542381}
# {'epoch': 21, 'loss': 0.032243501367595268, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 22, 'loss': 0.032406669014188295, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 23, 'loss': 0.033419644692912698, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 24, 'loss': 0.032616290934931708, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 25, 'loss': 0.031733205295441783, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 26, 'loss': 0.031936664284919113, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 27, 'loss': 0.031880781383198852, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 28, 'loss': 0.032045410740572738, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 29, 'loss': 0.030546004144365296, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 30, 'loss': 0.03157432370490449, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 21.595680249243394}
# {'epoch': 31, 'loss': 0.031703394741806036, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 32, 'loss': 0.031197263941387918, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 33, 'loss': 0.031324258156339914, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 34, 'loss': 0.031717719688244606, 'lr': 0.01, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 35, 'loss': 0.031398893155924534, 'lr': 0.002, 'reduce': 'yes', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 36, 'loss': 0.0082625946173827871, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 37, 'loss': 0.0059739306863561712, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 38, 'loss': 0.0060243569348719626, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 39, 'loss': 0.005808938750038471, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 40, 'loss': 0.006064637279932332, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 10648.071534492432}
# {'epoch': 41, 'loss': 0.0058713675860096425, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 42, 'loss': 0.0060402339817408257, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 3}
# {'ind_error': 0}
# {'epoch': 43, 'loss': 0.0061115219244076051, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 4}
# {'ind_error': 0}
# {'epoch': 44, 'loss': 0.0059930007760960824, 'lr': 0.002, 'reduce': 'no', 'since_lowest': 5}
# {'ind_error': 0}
# {'epoch': 45, 'loss': 0.0062030082643853828, 'lr': 0.0004, 'reduce': 'yes', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 46, 'loss': 0.0024069004892440073, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 47, 'loss': 0.0021956898674355164, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 48, 'loss': 0.0021710778237320483, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 49, 'loss': 0.0020953433832961738, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 50, 'loss': 0.002076458715772092, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 17462.234251552891}
# {'epoch': 51, 'loss': 0.0020579593812512674, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 52, 'loss': 0.0020300837812315233, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 53, 'loss': 0.0020686185410287339, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 54, 'loss': 0.0020957817417665329, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 55, 'loss': 0.0020040490070481181, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 56, 'loss': 0.0019793713367749553, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 57, 'loss': 0.0020482950640143827, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 0}
# {'epoch': 58, 'loss': 0.0019895101046559457, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 2}
# {'ind_error': 0}
# {'epoch': 59, 'loss': 0.0019351575593806476, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 0}
# {'ind_error': 0}
# {'epoch': 60, 'loss': 0.0019361571852213649, 'lr': 0.0004, 'reduce': 'no', 'since_lowest': 1}
# {'ind_error': 18104.645812196573}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-471-b48d8428e17f> in <module>()
#      16             x_batch = x_train[start:start+batch_size]
#      17             y_batch = y_train[start:start+batch_size]
# ---> 18             hist = bt_model.train_on_batch(x_batch, y_batch)
#      19
#      20             losses[bi] = hist
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\models.py in train_on_batch(self, x, y, class_weight, sample_weight)
#    1104         return self.model.train_on_batch(x, y,
#    1105                                          sample_weight=sample_weight,
# -> 1106                                          class_weight=class_weight)
#    1107
#    1108     def test_on_batch(self, x, y,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1881             ins = x + y + sample_weights
#    1882         self._make_train_function()
# -> 1883         outputs = self.train_function(ins)
#    1884         if len(outputs) == 1:
#    1885             return outputs[0]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Total ind_error

total_error = 0
#n_sets = 4
errors = []
for j in range(n_sets):

    x_test_r = x_test[j]
    y_test_r = y_test[j]

    bt_pred_ind_all = independent_predictions(x_test_r, bt_model)
    bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
    bt_ind_error = get_error(bt_pred_ind, y_test_r[0:len(bt_pred_ind[:,0]),0:n_nodes])
    total_error += bt_ind_error[0]
    errors.append(bt_ind_error[0])

print(errors)
print(total_error)
# Out:
# [157.73514877928326, 137.20610651590246, 152.58221475195739, 116.8624155315722]
# 564.385885579

# %%
j = 2
x_test_r = x_test[j]
y_test_r = y_test[j]

bt_pred_ind_all = independent_predictions(x_test_r, bt_model)
bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
bt_ind_error = get_error(bt_pred_ind, y_test_r[0:len(bt_pred_ind[:,0]),0:n_nodes])

# %%
#bt_ind_error = get_error(bt_pred_ind, y_test[0:len(f_pred_ind[:,0]),0:n_nodes])
print(bt_ind_error)
# Out:
# [ 152.58221475]

# %%
#bt_pred_ind = bt_pred_ind_all[:, 0:n_nodes]
#bt_ind_error = get_error(bt_pred_ind, y_test[0:len(bt_pred_ind[:,0]),0:n_nodes])
#print(bt_ind_error)

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])

plt.plot(y_test_r[0:500, n_nodes-1])
plt.plot(bt_pred_ind[0:500,n_nodes-1])

plt.show()

# %%
st_model = Sequential()
st_model.add(LSTM(height, batch_input_shape=(1,d, n_features), return_sequences=True, stateful=True))
st_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
st_model.compile(loss='mae', optimizer=adam)
st_model.set_weights(bt_model.get_weights())

# %%
#Total ind_error

total_error = 0
#n_sets = 4
errors = []
for j in range(n_sets):

    st_model.reset_states()
    
    x_test_r = x_test[j]
    y_test_r = y_test[j]

    st_pred_ind_all = independent_predictions(x_test_r, st_model)
    st_pred_ind = st_pred_ind_all[:, 0:n_nodes]
    st_ind_error = get_error(st_pred_ind, y_test_r[0:len(st_pred_ind[:,0]),0:n_nodes])
    total_error += st_ind_error[0]
    errors.append(st_ind_error[0])
    
    

print(errors)
print(total_error)
# Out:
# [5919.360340908278, 20791.731693238278, 5756.6006357750821, 5763.3123936548836]
# 38231.0050636

# %%
st_model.reset_states()
j = 2
x_test_r = x_test[j]
y_test_r = y_test[j]

st_pred_ind_all = independent_predictions(x_test_r, st_model)
st_pred_ind = st_pred_ind_all[:, 0:n_nodes]
st_ind_error = get_error(st_pred_ind, y_test_r[0:len(st_pred_ind[:,0]),0:n_nodes])

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])

plt.plot(y_test_r[0:500, n_nodes-1])
plt.plot(st_pred_ind[0:500,n_nodes-1])

plt.show()

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])
#plt.plot(f_pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.show()

# %%
##################### UNSEEN DATA ###################

#Select training set
training_set = 'unseen1'
iteration = 0
#d = 10
train_portion = 0.95

#Import training data
df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(iteration) + '.csv')
df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(iteration) + '.csv')
df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(iteration) + '.csv')

#Prepare training data
DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)

#Get global scalers
#x_scaler, y_scaler = get_scalers(DF, Dy)

#Split into train and test set
x_unseen_train, x_unseen_test, y_unseen_train, y_unseen_test, n_nodes, n_features, n_y, x = train_test_split(DF[:,:], Dy[:,:], d, x_scaler, y_scaler, train_portion)
n_features = sh1[1]

# %%
f_pred_ind_all = independent_predictions_pca(x_unseen_test, f_model)
f_pred_ind = f_pred_ind_all[:, 0:n_nodes]

# %%
f_ind_error = get_error(f_pred_ind, y_unseen_test[0:len(f_pred_ind[:,0]),0:n_nodes])
print(f_ind_error)
# Out:
# 461.575430303

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
#plt.plot(bt_pred_ind[:,n_nodes-1])

plt.plot(y_unseen_test[:1000, n_nodes-1])
plt.plot(f_pred_ind[:1000,n_nodes-1])

plt.show()

# %%
f_model.predict(pca.transform(x_unseen_test[0,:,:]).reshape([1,d,n_features]))
# Out:
# array([[ 0.41883656,  0.41931304,  0.41766015,  0.41867629,  0.42105049,
#          0.42189106,  0.4251999 ,  0.44010538,  0.45728752,  0.46517229,
#          0.53769237,  0.53808057,  0.53931403,  0.5402357 ,  0.54199147,
#          0.54450291,  0.54377806,  0.56265378,  0.52699947,  0.50802404]], dtype=float32)

# %%
len(f_model.get_weights())
# Out:
# 5

# %%
#save best model
#trained on= rr_set1

#f_model.save('../models/lin_white_noise_dt01.h5')

#### CONTINUE TRAINING ####
#f_model = keras.modelload_model('../models/RNN_gr_set1.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
def generate_export(my_model):
    pred_train_all = my_model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]

    pred_test_all = my_model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]

    pred_ind_all = independent_predictions(x_test, my_model)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]

    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    #Export results
    np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
    np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
    np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
    np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
#generate_export(u_model)

# %%
y_test_u = y_scaler.inverse_transform(y_test_r)[:, 0:n_nodes]
bt_pred_ind_u = y_scaler.inverse_transform(bt_pred_ind_all)[:, 0:n_nodes]

# %%
#Export results
#np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", bt_pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
#np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
# one layer, height 500, gives lowest error around 9, but this is while its heavily overfitting
# one layer, height 100, on gr_set1 goes down to about 6 at epoch 40, then starts overfitting
# same, but with height 200 starts oscillating around batch 20, then the ind error is around 9. 
# With dropout 0.1 the results are bad


#df = df.drop(columns=df.columns[0])
#df.to_csv('../results/RNN_velocity_results.csv')

# %%
#pd.read_csv('../results/RNN_velocity_results.csv', index_col=0)
# Out:
#   training set  n_layers  height  epochs  batch size  learning rate  \
# 0           rr         2     100     500        1000         0.0005
# 1           rr         2     100     500        1000         0.0001
# 2           rr         3      50     500        1000         0.0005
#
#    early stopping  stop loss  Training Error  Test Error  Ind test error  \
# 0             115   0.005931        0.428430    0.102271        4.126604
# 1              36   0.005536        0.457434    0.111018       18.604378
# 2             160   0.013542        0.497549    0.108562       11.480535
#
#    Ind train error  Training time   Total time
# 0        19.038270    2173.341693  2263.469776
# 1        96.249718     707.928417   803.638126
# 2        70.656266    5234.750504  5392.588225

# %%
#save best model
#trained on= gr_set1

#u_model.save('../models/RNN_rr_set3_5e.h5')

#### CONTINUE TRAINING ####
#model = load_model('beam_model.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
######################### BATCH TESTING ########################################

n_batches = 1
#d = 8

t0 = time.time()
for iteration in range(n_batches):

    df_D = pd.read_csv('../training_batches/rrD' + str(iteration+1) + '.csv')
    df_F = pd.read_csv('../training_batches/rrF' + str(iteration+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/rrDt' + str(iteration+1) + '.csv')

    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    #if i == 0:
    #    model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    pred_train_all = model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]
    
    pred_test_all = model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]
    
    pred_ind_all = independent_predictions(x_test)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]
    
    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    training_error = get_error(pred_train, y_train[:,0:n_nodes])
    test_error = get_error(pred_test, y_test[:,0:n_nodes])
    ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])
    
    plt.figure(figsize=(16,10))
    #plt.plot(pred_test[:,n_nodes-1], 'x')
    plt.plot(pred_ind[:,n_nodes-1])
    plt.plot(y_test[:, n_nodes-1])
    plt.show()

    
    total_time = time.time() - t0
    
    info = {'Iteration number': iteration+1, 'Training Error': training_error, 'Test Error': test_error, 'Ind test error': ind_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Training Error': 1.7276860353577641, 'Test Error': 0.29846556877570002, 'Ind test error': 18.855915684260651, 'Training time': 0.0, 'Total time': 34.77224016189575}

# %%
#Export results
np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
pred_ind_all = independent_predictions(x_train)
pred_ind = pred_ind_all[:, 0:n_nodes]

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
plt.plot(pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.show()

# %%
DF.shape
# Out:
# (4995, 205)

# %%
df_D.values.shape
# Out:
# (5000, 21)

# %%
plt.plot(y_test_u[50,:])
