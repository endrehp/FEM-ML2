# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import random
import math
import time

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.utils import np_utils
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping, History, Callback, ReduceLROnPlateau, ModelCheckpoint

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA

# %%
def prepare_training_data(df_F, df_D, df_Dt, d):
    
    DF = []
    for i in range(d):
        if i == 0:
            DF = np.concatenate((df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis = 1)
        else:
            DF = np.concatenate((DF, df_F.shift(d-i).values, df_D.shift(d-i).values, df_Dt.shift(d-i).values), axis=1)

    DF = DF[d:,:]
    Dy = np.concatenate((df_D.values, df_Dt.values), axis=1)
    Dy = Dy[d:,:]
    
    return DF, Dy

# %%
def train_test_split(DF, Dy, d, x_scaler, y_scaler):

    dim = np.shape(Dy)

    n_nodes = int(dim[1]/2)
    n_y = dim[1]
    x = np.linspace(0,1, n_nodes)

    #Scaling
    DFscaled = x_scaler.transform(DF)
    Dyscaled = y_scaler.transform(Dy)

    X_train = DFscaled
    Y_train = Dyscaled

    #Train test split
    train_portion = 0.8
    n_timesteps = len(X_train[:,0])
    x_train = X_train[0:int(n_timesteps*train_portion),:]
    x_test = X_train[int(n_timesteps*(train_portion)):,:]
    y_train = Y_train[0:int(n_timesteps*train_portion),:]
    y_test = Y_train[int(n_timesteps*(train_portion)):,:]

    n_features = int(x_train.shape[1]/d)
    
    #Reshape training data into 3D array as required by the LSTM layer
    #Input shape is: (n_timesteps, d, n_features)
    x_train = x_train.reshape((x_train.shape[0], d, n_features))
    x_test = x_test.reshape((x_test.shape[0], d, n_features))

    return x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x

# %%
def initialize_model(n_units, x_train, y_train, lr, n_layers):
    model = Sequential()
    
    #Add hidden layers, return_sequences=True if next layer is LSTM, False otherwise
    if n_layers == 1:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=False))
        
    elif n_layers == 2:
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        model.add(LSTM(n_units))
    else: 
        model.add(LSTM(n_units, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
        for layer in range(n_layers-1):
            model.add(LSTM(n_units, return_sequences = True))
        model.add(LSTM(n_units))
    
    
    #model.add(Dropout(0.1))
    
    model.add(Dense(len(y_train[0,:]))) #Output Layer
    adam = Adam(lr=lr)
    model.compile(loss='mae', optimizer=adam)
    
    #Define callbacks
    history = History()
    earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
    callback_list = [earlystop, history]
    return model, callback_list

# %%
def get_error(predictions, y_test):
    #Squared error is integrated numerically in space for each timestep and summed
    error = 0
    for i in range(len(predictions[:,0])):
        error += np.trapz((y_test[i,:] - predictions[i,:])**2, x)
    return error

# %%
def independent_predictions(x_test, my_model):

    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known
    for i in range(future_timesteps): 
        pred = my_model.predict(input_i_reshaped) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        input_i[d-1,:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
        input_i[d-1,n_nodes:] = pred[0] #Fill in values that we just predicted

        input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
        
    return preds

# %%
def independent_batch(x_batch):

    input_i = np.copy(x_batch[0,:,:]) #Initial conditions
    input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_batch[:,0,0])

    force = np.copy(x_batch[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known
    
    ind_batch = np.zeros([future_timesteps, d, n_features])
    ind_batch[0] = input_i_reshaped[0]
    
    for i in range(future_timesteps): 
        pred = model.predict(input_i_reshaped) #Predict next timestep
        
        if i < future_timesteps - 1:
            input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
            input_i[d-1,:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
            input_i[d-1,n_nodes:] = pred[0] #Fill in values that we just predicted

            input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer
            ind_batch[i+1] = input_i_reshaped[0]
        
    return ind_batch

# %%
def get_scalers(DF, Dy):
    
    x_scaler = MinMaxScaler()
    y_scaler = MinMaxScaler()
    
    x_scaler.fit_transform(DF)
    y_scaler.fit_transform(Dy)
    
    return x_scaler, y_scaler

# %%
def get_batch_scalers(n_batches, training_set):
    
    #Simple version
    for i in range(n_batches):
        
        df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(i+1) + '.csv')
        df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(i+1) + '.csv')
        df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(i+1) + '.csv')
        
        if i == 0:  
            x_range = df_D.values.max() - df_D.values.min()
            imax = i
        
        else:
            new_x_range = df_D.values.max() - df_D.values.min()
            
            if new_x_range > x_range:
                x_range = new_x_range
                imax = i
                
    df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(imax+1) + '.csv')
    df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(imax+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(imax+1) + '.csv')
    
    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    return x_scaler, y_scaler

# %%
#columns = ['training set', 'n_layers', 'height', 'epochs', 'batch size', 'learning rate', 'early stopping', 'stop loss', 'Training Error', 'Test Error',
#           'Ind test error', 'Ind train error', 'Training time', 'Total time']
#df = pd.DataFrame(columns = columns)

#df.to_csv('../results/RNN_velocity_results.csv')

# %%
def get_batch(x_train, y_train, batch_size):
    
    start = random.randint(0,len(x_train)-batch_size)
    
    x_batch = x_train[start:start+batch_size]
    y_batch = y_train[start:start+batch_size]
    
    return x_batch, y_batch

# %%
random.randint(0,100)
# Out:
# 32

# %%
#Select training set
training_set = 'rr'
iteration = 0
d = 10

#Import training data
df_D = pd.read_csv('../training_batches/'+ training_set +'D' + str(iteration+1) + '.csv')
df_F = pd.read_csv('../training_batches/'+ training_set +'F' + str(iteration+1) + '.csv')
df_Dt = pd.read_csv('../training_batches/'+ training_set +'Dt' + str(iteration+1) + '.csv')

#Prepare training data
DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)

#Get global scalers
x_scaler, y_scaler = get_scalers(DF, Dy)

#Split into train and test set
x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF[:,:], Dy[:,:], d, x_scaler, y_scaler)

# %%
Dy.shape
# Out:
# (29990, 10)

# %%
#X = x_train[:,0,:]
#df = pd.DataFrame(X)

#correlation = df.corr()
#plt.figure(figsize=(20,20))
#sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='cubehelix')

#plt.title('Correlation between different fearures')

# %%
####Method 1####
train_shape = x_train.shape
test_shape = x_test.shape

# %%
x_train2 = x_train.reshape([train_shape[0]*train_shape[1],train_shape[2]])
x_test2 = x_test.reshape([test_shape[0]*test_shape[1],test_shape[2]])

# %%
pca = PCA(n_components=8)
pca.fit(x_train2)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0,0.5,'Cumulative explained variance')

# %%
NCOMPONENTS = 5

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(x_train2)
X_pca_test = pca.transform(x_test2)
pca_std = np.std(X_pca_train)

print(x_train2.shape)
print(X_pca_train.shape)
# Out:
# (80000, 15)
# (80000, 5)

# %%
sh1 = X_pca_train.shape
sh2 = X_pca_test.shape
x_train_pca = X_pca_train.reshape([int(sh1[0]/d),d,sh1[1]])
x_test_pca = X_pca_test.reshape([int(sh2[0]/d),d,sh2[1]])

# %%
class Ind_pred(Callback):
    
    def on_epoch_end(self, epoch, logs={}):

        input_i = np.copy(x_test[0,:,:]) #Initial conditions
        #input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

        future_timesteps = len(x_test[:,0,0])-1
        preds = np.zeros([future_timesteps, n_y])

        force = np.copy(x_test[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known
        
        new_step = np.zeros(len(x_test[0,0,:]))
        input_shape = input_i.shape
        
        for i in range(future_timesteps): 
            
            input_i_pca = pca.transform(input_i.reshape([1,input_shape[0]*input_shape[1]]))
            
            pred = self.model.predict(input_i_pca.reshape([1,sh1[1],1])) #Predict next timestep
            preds[i, :] = pred[0] 

            input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
            new_step[:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
            new_step[n_nodes:] = pred[0] #Fill in values that we just predicted
            
            
            input_i[d-1,:] = new_step.reshape([1,len(new_step)])
            
        
        error = 0
        for i in range(len(preds[:,0])):
            error += np.trapz((y_test[i,:n_nodes] - preds[i,:n_nodes])**2, x)
        
        info = {'ind error': error}
        u_ind_errors.append(error)
        
        logs['ind_error'] = error
            
        print(info)
    
    #def on_batch_end(self, batch, logs={}):
    #    print(batch)

# %%
def independent_predictions_pca(x_test, my_model):        
    input_i = np.copy(x_test[0,:,:]) #Initial conditions
    #input_i_reshaped = input_i.reshape((1,d,n_features)) #Reshape to fit LSTM layer

    future_timesteps = len(x_test[:,0,0])-1
    preds = np.zeros([future_timesteps, n_y])

    force = np.copy(x_test[:,:,:(n_nodes)]) #Loading history for future timesteps, which is known

    new_step = np.zeros(len(x_test[0,0,:]))
    input_shape = input_i.shape

    for i in range(future_timesteps): 

        input_i_pca = pca.transform(input_i.reshape([input_shape[0], input_shape[1]]))

        pred = my_model.predict(input_i_pca.reshape([1,d,n_features])) #Predict next timestep
        preds[i, :] = pred[0] 

        input_i[0:d-1,:] = input_i[1:d,:] #Move everything one step backward
        new_step[:n_nodes] = force[i+1,d-1,:] #Fill in force for next timestep
        new_step[n_nodes:] = pred[0] #Fill in values that we just predicted


        input_i[d-1,:] = new_step.reshape([1,len(new_step)])
        
    return preds

# %%
######################### BATCH TRAINING ########################################

n_batches = 1
#d = 10

#Hyperparameter settings
epochs = 500
layers = 1
height = 40
batch_size = 1000
lr = 0.001
u_errors_matrix = []
c_errors_matrix =[]

# %%
n_features = sh1[1]

# %%
u_model = Sequential()
#u_model.add(LSTM(height, input_shape=(sh1[1], n_features), return_sequences=True))
#u_model.add(LSTM(height, return_sequences=False))
u_model.add(LSTM(height, input_shape=(d, n_features), return_sequences=False))
#model.add(Dropout(0.1))
u_model.add(Dense(len(y_train[0,:]))) #Output Layer
adam = Adam(lr=lr)
u_model.compile(loss='mae', optimizer=adam)
#Define callbacks
ind_pred = Ind_pred()
u_ind_errors = []
history = History()
earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=10, verbose=1, mode='min')
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2, patience=20, min_lr=0.0001, mode='min', verbose=1)
model_cp = ModelCheckpoint('../results/model_checkpoint.h5', monitor='ind_error', verbose=1, save_best_only=True, save_weights_only=False, mode='min', period=1)
#hist = u_model.fit(x_train_pca, y_train, epochs=epochs, callbacks=[ind_pred, history, earlystop, reduce_lr, model_cp], batch_size=batch_size, 
#                   verbose=1, shuffle=False)

hist = u_model.fit(x_train_pca, y_train, epochs=epochs, callbacks=[reduce_lr], batch_size=batch_size, 
                   verbose=1, shuffle=False)
#earlystop = EarlyStopping(monitor='loss', min_delta=0.0001, patience=20, verbose=1, mode='auto')
#callback_list = [earlystop, history]
u_errors_matrix.append(u_ind_errors)
# Out:
# Epoch 1/500
# 8000/8000 [==============================] - 1s 159us/step - loss: 0.4889
# Epoch 2/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.4535
# Epoch 3/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.3899
# Epoch 4/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.2629
# Epoch 5/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.1483
# Epoch 6/500
# 8000/8000 [==============================] - 0s 34us/step - loss: 0.0979
# Epoch 7/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0722
# Epoch 8/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0587
# Epoch 9/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.0475
# Epoch 10/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0369
# Epoch 11/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0292
# Epoch 12/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0234
# Epoch 13/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0189
# Epoch 14/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.0159
# Epoch 15/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0135
# Epoch 16/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0119: 0s - loss: 0.01
# Epoch 17/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0108
# Epoch 18/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0102
# Epoch 19/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0097
# Epoch 20/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0094
# Epoch 21/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.0091
# Epoch 22/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0089: 0s - loss: 0.00
# Epoch 23/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0087
# Epoch 24/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0086
# Epoch 25/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0085
# Epoch 26/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0084
# Epoch 27/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.0084
# Epoch 28/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0082
# Epoch 29/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0081
# Epoch 30/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0080
# Epoch 31/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.0079
# Epoch 32/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0077
# Epoch 33/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0075
# Epoch 34/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0074
# Epoch 35/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.0073
# Epoch 36/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0072
# Epoch 37/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0072
# Epoch 38/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0072
# Epoch 39/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.0072
# Epoch 40/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0071
# Epoch 41/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.0070
# Epoch 42/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0069
# Epoch 43/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0068
# Epoch 44/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0067
# Epoch 45/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0067
# Epoch 46/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0067
# Epoch 47/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0067
# Epoch 48/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0066
# Epoch 49/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0066
# Epoch 50/500
# 8000/8000 [==============================] - 0s 35us/step - loss: 0.0064: 0s - loss: 0.00
# Epoch 51/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0063
# Epoch 52/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0063
# Epoch 53/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0064
# Epoch 54/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0064
# Epoch 55/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0064
# Epoch 56/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0063
# Epoch 57/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0061
# Epoch 58/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0060
# Epoch 59/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0061
# Epoch 60/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0062
# Epoch 61/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0061
# Epoch 62/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0060
# Epoch 63/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0060: 0s - loss: 0.005
# Epoch 64/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0061
# Epoch 65/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0061
# Epoch 66/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0061
# Epoch 67/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0059
# Epoch 68/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0060
# Epoch 69/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0060
# Epoch 70/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0060
# Epoch 71/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0058
# Epoch 72/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0057
# Epoch 73/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0057
# Epoch 74/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0058
# Epoch 75/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0058
# Epoch 76/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0061
# Epoch 77/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0057
# Epoch 78/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0056
# Epoch 79/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0056
# Epoch 80/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0056
# Epoch 81/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0057
# Epoch 82/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0060
# Epoch 83/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0058
# Epoch 84/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0057
# Epoch 85/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0055
# Epoch 86/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0053
# Epoch 87/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0054
# Epoch 88/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0056
# Epoch 89/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0056
# Epoch 90/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0054
# Epoch 91/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0053
# Epoch 92/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0054
# Epoch 93/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0055
# Epoch 94/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0058
# Epoch 95/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0054
# Epoch 96/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0055
# Epoch 97/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0055
# Epoch 98/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0056
# Epoch 99/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0057
# Epoch 100/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0057
# Epoch 101/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0058
# Epoch 102/500
# 8000/8000 [==============================] - 0s 48us/step - loss: 0.0058
# Epoch 103/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0057
# Epoch 104/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0057
# Epoch 105/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0057
# Epoch 106/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0057
#
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 107/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0053
# Epoch 108/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0046
# Epoch 109/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0045
# Epoch 110/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0044
# Epoch 111/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0043
# Epoch 112/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0042
# Epoch 113/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0042
# Epoch 114/500
# 8000/8000 [==============================] - 0s 48us/step - loss: 0.0042
# Epoch 115/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0042
# Epoch 116/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0042
# Epoch 117/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0042
# Epoch 118/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 119/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 120/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 121/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0042
# Epoch 122/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0042
# Epoch 123/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0042
# Epoch 124/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0042
# Epoch 125/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0042
# Epoch 126/500
# 8000/8000 [==============================] - 0s 53us/step - loss: 0.0042
# Epoch 127/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0042
# Epoch 128/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0042
# Epoch 129/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0042
# Epoch 130/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0042: 0s - loss: 0.0
# Epoch 131/500
# 8000/8000 [==============================] - 0s 49us/step - loss: 0.0042
# Epoch 132/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0042
#
# Epoch 00132: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 133/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0041
# Epoch 134/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0042
# Epoch 135/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0042
# Epoch 136/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0042
# Epoch 137/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 138/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 139/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0042
# Epoch 140/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 141/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0042
# Epoch 142/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 143/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0042
# Epoch 144/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0042
# Epoch 145/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0042
# Epoch 146/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 147/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0042
# Epoch 148/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0042
# Epoch 149/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0042
# Epoch 150/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 151/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0042
# Epoch 152/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 153/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0042
# Epoch 154/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0042
# Epoch 155/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0042
# Epoch 156/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0042
# Epoch 157/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0042
# Epoch 158/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 159/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 160/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 161/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 162/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 163/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 164/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 165/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0041
# Epoch 166/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 167/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 168/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 169/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 170/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 171/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 172/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 173/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0041
# Epoch 174/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 175/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0041
# Epoch 176/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0041
# Epoch 177/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0041
# Epoch 178/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0041
# Epoch 179/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 180/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0041
# Epoch 181/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 182/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 183/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 184/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0041
# Epoch 185/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 186/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0041
# Epoch 187/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0041
# Epoch 188/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0041
# Epoch 189/500
# 8000/8000 [==============================] - 0s 49us/step - loss: 0.0041
# Epoch 190/500
# 8000/8000 [==============================] - 0s 48us/step - loss: 0.0041
# Epoch 191/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0041
# Epoch 192/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0041
# Epoch 193/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0041
# Epoch 194/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0041
# Epoch 195/500
# 8000/8000 [==============================] - 0s 50us/step - loss: 0.0041
# Epoch 196/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0041
# Epoch 197/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0041
# Epoch 198/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 199/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0041
# Epoch 200/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 201/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 202/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 203/500
# 8000/8000 [==============================] - 0s 48us/step - loss: 0.0041
# Epoch 204/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0041
# Epoch 205/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 206/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0041
# Epoch 207/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 208/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 209/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0041
# Epoch 210/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0041
# Epoch 211/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0041
# Epoch 212/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0041
# Epoch 213/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0041
# Epoch 214/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0041
# Epoch 215/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0041
# Epoch 216/500
# 8000/8000 [==============================] - 0s 59us/step - loss: 0.0041
# Epoch 217/500
# 8000/8000 [==============================] - 0s 50us/step - loss: 0.0041
# Epoch 218/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0041
# Epoch 219/500
# 8000/8000 [==============================] - 0s 53us/step - loss: 0.0041
# Epoch 220/500
# 8000/8000 [==============================] - 0s 53us/step - loss: 0.0041
# Epoch 221/500
# 8000/8000 [==============================] - 1s 74us/step - loss: 0.0041
# Epoch 222/500
# 8000/8000 [==============================] - 0s 56us/step - loss: 0.0040
# Epoch 223/500
# 8000/8000 [==============================] - 0s 50us/step - loss: 0.0040
# Epoch 224/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0040
# Epoch 225/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0040
# Epoch 226/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 227/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0040
# Epoch 228/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 229/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 230/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 231/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 232/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 233/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0040
# Epoch 234/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0040
# Epoch 235/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 236/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 237/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 238/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 239/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0040
# Epoch 240/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0040
# Epoch 241/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 242/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 243/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 244/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 245/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 246/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0040
# Epoch 247/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0040
# Epoch 248/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0040
# Epoch 249/500
# 8000/8000 [==============================] - 1s 67us/step - loss: 0.0040: 0s - loss: 0.00
# Epoch 250/500
# 8000/8000 [==============================] - 0s 60us/step - loss: 0.0040
# Epoch 251/500
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.0040
# Epoch 252/500
# 8000/8000 [==============================] - 1s 77us/step - loss: 0.0040
# Epoch 253/500
# 8000/8000 [==============================] - 1s 72us/step - loss: 0.0040
# Epoch 254/500
# 8000/8000 [==============================] - 1s 67us/step - loss: 0.0040
# Epoch 255/500
# 8000/8000 [==============================] - 0s 57us/step - loss: 0.0040
# Epoch 256/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0040
# Epoch 257/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0040
# Epoch 258/500
# 8000/8000 [==============================] - 0s 49us/step - loss: 0.0040
# Epoch 259/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0040
# Epoch 260/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0040
# Epoch 261/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0040
# Epoch 262/500
# 8000/8000 [==============================] - 0s 52us/step - loss: 0.0040
# Epoch 263/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0040
# Epoch 264/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0040
# Epoch 265/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0040
# Epoch 266/500
# 8000/8000 [==============================] - 0s 49us/step - loss: 0.0040
# Epoch 267/500
# 8000/8000 [==============================] - 0s 47us/step - loss: 0.0040
# Epoch 268/500
# 8000/8000 [==============================] - 1s 68us/step - loss: 0.0040: 0s - loss: 0.00
# Epoch 269/500
# 8000/8000 [==============================] - 1s 75us/step - loss: 0.0040: 0s - loss: 0.
# Epoch 270/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0040
# Epoch 271/500
# 8000/8000 [==============================] - 0s 48us/step - loss: 0.0040
# Epoch 272/500
# 8000/8000 [==============================] - 0s 48us/step - loss: 0.0040
# Epoch 273/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0040
# Epoch 274/500
# 8000/8000 [==============================] - 0s 50us/step - loss: 0.0040
# Epoch 275/500
# 8000/8000 [==============================] - 0s 49us/step - loss: 0.0040: 0s - loss: 0.0
# Epoch 276/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0040
# Epoch 277/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0040
# Epoch 278/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0040
# Epoch 279/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0040
# Epoch 280/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0040
# Epoch 281/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0040
# Epoch 282/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0040
# Epoch 283/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0040
# Epoch 284/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0040
# Epoch 285/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0040
# Epoch 286/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0040
# Epoch 287/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0040
# Epoch 288/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0040
# Epoch 289/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0040
# Epoch 290/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 291/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 292/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 293/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 294/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 295/500
# 8000/8000 [==============================] - 0s 43us/step - loss: 0.0039
# Epoch 296/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0039
# Epoch 297/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0039
# Epoch 298/500
# 8000/8000 [==============================] - 0s 46us/step - loss: 0.0039
# Epoch 299/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0039
# Epoch 300/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 301/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 302/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 303/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0039
# Epoch 304/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0039
# Epoch 305/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 306/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 307/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 308/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 309/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 310/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 311/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0039
# Epoch 312/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 313/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 314/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 315/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 316/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 317/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 318/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0039
# Epoch 319/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0039
# Epoch 320/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0039
# Epoch 321/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 322/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 323/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0039
# Epoch 324/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 325/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0039
# Epoch 326/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 327/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 328/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 329/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 330/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 331/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 332/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 333/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 334/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 335/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 336/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 337/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 338/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 339/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 340/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 341/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 342/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 343/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 344/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0039
# Epoch 345/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 346/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 347/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 348/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 349/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 350/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 351/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 352/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 353/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 354/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0039
# Epoch 355/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 356/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 357/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 358/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0039
# Epoch 359/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 360/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0039
# Epoch 361/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 362/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0038
# Epoch 363/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 364/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 365/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 366/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 367/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0038
# Epoch 368/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 369/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0038
# Epoch 370/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0038
# Epoch 371/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0038
# Epoch 372/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 373/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 374/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 375/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 376/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 377/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 378/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0038
# Epoch 379/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0038
# Epoch 380/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 381/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 382/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 383/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 384/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 385/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 386/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0038
# Epoch 387/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 388/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0038
# Epoch 389/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0038
# Epoch 390/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 391/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0038
# Epoch 392/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 393/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 394/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 395/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 396/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0038
# Epoch 397/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 398/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 399/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 400/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 401/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 402/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 403/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 404/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 405/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0038
# Epoch 406/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0038
# Epoch 407/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 408/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 409/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 410/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 411/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 412/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 413/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 414/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 415/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0038
# Epoch 416/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0038
# Epoch 417/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0038
# Epoch 418/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 419/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 420/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0038
# Epoch 421/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 422/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0038
# Epoch 423/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 424/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 425/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 426/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 427/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 428/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0038
# Epoch 429/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 430/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 431/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0038
# Epoch 432/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 433/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0037
# Epoch 434/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 435/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 436/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 437/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0037
# Epoch 438/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 439/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0037
# Epoch 440/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 441/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 442/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 443/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 444/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0037
# Epoch 445/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0037
# Epoch 446/500
# 8000/8000 [==============================] - ETA: 0s - loss: 0.003 - 0s 37us/step - loss: 0.0037
# Epoch 447/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 448/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 449/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0037
# Epoch 450/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 451/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0037
# Epoch 452/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 453/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 454/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 455/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 456/500
# 8000/8000 [==============================] - 0s 39us/step - loss: 0.0037
# Epoch 457/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 458/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 459/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 460/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 461/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 462/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 463/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 464/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 465/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 466/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 467/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0037
# Epoch 468/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0037
# Epoch 469/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 470/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 471/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 472/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 473/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0037
# Epoch 474/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 475/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 476/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 477/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 478/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 479/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 480/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 481/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 482/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 483/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 484/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 485/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 486/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 487/500
# 8000/8000 [==============================] - 0s 38us/step - loss: 0.0037
# Epoch 488/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 489/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 490/500
# 8000/8000 [==============================] - 0s 40us/step - loss: 0.0037
# Epoch 491/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 492/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0037
# Epoch 493/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 494/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037
# Epoch 495/500
# 8000/8000 [==============================] - 0s 41us/step - loss: 0.0037
# Epoch 496/500
# 8000/8000 [==============================] - 0s 44us/step - loss: 0.0037
# Epoch 497/500
# 8000/8000 [==============================] - 0s 45us/step - loss: 0.0037
# Epoch 498/500
# 8000/8000 [==============================] - 0s 42us/step - loss: 0.0037
# Epoch 499/500
# 8000/8000 [==============================] - 0s 36us/step - loss: 0.0037
# Epoch 500/500
# 8000/8000 [==============================] - 0s 37us/step - loss: 0.0037

# %%
pred_ind_all = independent_predictions_pca(x_test, u_model)

# %%
pred_ind = pred_ind_all[:, 0:n_nodes]
ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])

# %%
print(ind_error)
# Out:
# 9.70730629766

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
plt.plot(pred_ind[:,n_nodes-1])
plt.plot(y_test[:, n_nodes-1])
plt.show()

# %%
plt.plot(hist.history['loss'][20:500])

# %%
#save best model
#trained on= rr_set1

#u_model.save('../models/pca_RNN_gr_set1.h5')

#### CONTINUE TRAINING ####
#model = load_model('../models/RNN_gr_set1.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
def generate_export(my_model):
    pred_train_all = my_model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]

    pred_test_all = my_model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]

    pred_ind_all = independent_predictions(x_test, my_model)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]

    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    #Export results
    np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
    np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
    np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
    np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
generate_export(u_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-c444d0737e2c> in <module>()
# ----> 1 generate_export(u_model)
#
# <ipython-input-136-50e79082a532> in generate_export(my_model)
#       1 def generate_export(my_model):
# ----> 2     pred_train_all = my_model.predict(x_train)
#       3     pred_train = pred_train_all[:, 0:n_nodes]
#       4     pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]
#       5
#
# ~/anaconda3/lib/python3.6/site-packages/keras/models.py in predict(self, x, batch_size, verbose, steps)
#    1023             self.build()
#    1024         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1025                                   steps=steps)
#    1026
#    1027     def predict_on_batch(self, x):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1815         x = _standardize_input_data(x, self._feed_input_names,
#    1816                                     self._feed_input_shapes,
# -> 1817                                     check_batch_axis=False)
#    1818         if self.stateful:
#    1819             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     121                             ': expected ' + names[i] + ' to have shape ' +
#     122                             str(shape) + ' but got array with shape ' +
# --> 123                             str(data_shape))
#     124     return data
#     125
#
# ValueError: Error when checking : expected lstm_18_input to have shape (4, 1) but got array with shape (10, 60)

# %%
y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]

# %%
#Export results
#np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
#np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
# one layer, height 500, gives lowest error around 9, but this is while its heavily overfitting
# one layer, height 100, on gr_set1 goes down to about 6 at epoch 40, then starts overfitting
# same, but with height 200 starts oscillating around batch 20, then the ind error is around 9. 
# With dropout 0.1 the results are bad


#df = df.drop(columns=df.columns[0])
#df.to_csv('../results/RNN_velocity_results.csv')

# %%
#pd.read_csv('../results/RNN_velocity_results.csv', index_col=0)
# Out:
#   training set  n_layers  height  epochs  batch size  learning rate  \
# 0           rr         2     100     500        1000         0.0005
# 1           rr         2     100     500        1000         0.0001
# 2           rr         3      50     500        1000         0.0005
#
#    early stopping  stop loss  Training Error  Test Error  Ind test error  \
# 0             115   0.005931        0.428430    0.102271        4.126604
# 1              36   0.005536        0.457434    0.111018       18.604378
# 2             160   0.013542        0.497549    0.108562       11.480535
#
#    Ind train error  Training time   Total time
# 0        19.038270    2173.341693  2263.469776
# 1        96.249718     707.928417   803.638126
# 2        70.656266    5234.750504  5392.588225

# %%
#save best model
#trained on= gr_set1

u_model.save('../models/RNN_rr_set3_5e.h5')

#### CONTINUE TRAINING ####
#model = load_model('beam_model.h5')

#model.fit(x_train, y_train, epochs=100, verbose=1)

#model.save('beam_model.h5')

#del(model)

# %%
######################### BATCH TESTING ########################################

n_batches = 1
#d = 8

t0 = time.time()
for iteration in range(n_batches):

    df_D = pd.read_csv('../training_batches/rrD' + str(iteration+1) + '.csv')
    df_F = pd.read_csv('../training_batches/rrF' + str(iteration+1) + '.csv')
    df_Dt = pd.read_csv('../training_batches/rrDt' + str(iteration+1) + '.csv')

    DF, Dy = prepare_training_data(df_F, df_D, df_Dt, d)
    
    #if i == 0:
    #    x_scaler, y_scaler = get_scalers(DF, Dy)
    
    x_train, x_test, y_train, y_test, n_nodes, n_features, n_y, x = train_test_split(DF, Dy, d, x_scaler, y_scaler)
    
    ts = time.time()
    #if i == 0:
    #    model, callback_list = initialize_model(100, x_train, y_train)
    
    #model.fit(x_train, y_train, epochs=100, callbacks=callback_list, batch_size=len(x_train), verbose=0, shuffle=False)
    
    training_time = time.time() - ts
    
    pred_train_all = model.predict(x_train)
    pred_train = pred_train_all[:, 0:n_nodes]
    pred_train_u = y_scaler.inverse_transform(pred_train_all)[:, 0:n_nodes]
    
    pred_test_all = model.predict(x_test)
    pred_test = pred_test_all[:, 0:n_nodes]
    pred_test_u = y_scaler.inverse_transform(pred_test_all)[:, 0:n_nodes]
    
    pred_ind_all = independent_predictions(x_test)
    pred_ind = pred_ind_all[:, 0:n_nodes]
    pred_ind_u = y_scaler.inverse_transform(pred_ind_all)[:, 0:n_nodes]
    
    y_test_u = y_scaler.inverse_transform(y_test)[:, 0:n_nodes]
    
    training_error = get_error(pred_train, y_train[:,0:n_nodes])
    test_error = get_error(pred_test, y_test[:,0:n_nodes])
    ind_error = get_error(pred_ind, y_test[0:len(pred_ind[:,0]),0:n_nodes])
    
    plt.figure(figsize=(16,10))
    #plt.plot(pred_test[:,n_nodes-1], 'x')
    plt.plot(pred_ind[:,n_nodes-1])
    plt.plot(y_test[:, n_nodes-1])
    plt.show()

    
    total_time = time.time() - t0
    
    info = {'Iteration number': iteration+1, 'Training Error': training_error, 'Test Error': test_error, 'Ind test error': ind_error,
            'Training time': training_time, 'Total time': total_time}
    print(info)
# Out:
# {'Iteration number': 1, 'Training Error': 1.7276860353577641, 'Test Error': 0.29846556877570002, 'Ind test error': 18.855915684260651, 'Training time': 0.0, 'Total time': 34.77224016189575}

# %%
#Export results
np.savetxt("../results/predictions.csv", pred_test_u, delimiter=",")
np.savetxt("../results/preds.csv", pred_ind_u, delimiter=",")
np.savetxt("../results/y_test.csv", y_test_u, delimiter=",")
np.savetxt("../results/y_train.csv", y_test_u, delimiter=",")

# %%
pred_ind_all = independent_predictions(x_train)
pred_ind = pred_ind_all[:, 0:n_nodes]

# %%
plt.figure(figsize=(16,10))
#plt.plot(pred_test[:,n_nodes-1], 'x')
plt.plot(pred_ind[:,n_nodes-1])
plt.plot(y_train[:, n_nodes-1])
plt.show()

# %%
DF.shape
# Out:
# (4995, 205)

# %%
df_D.values.shape
# Out:
# (5000, 21)

# %%
plt.plot(y_test_u[50,:])
